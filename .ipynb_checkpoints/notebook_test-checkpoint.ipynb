# %%
import numpy as np
import matplotlib.pyplot as plt
from skimage.transform import resize # from scipy.misc import imresize
from tqdm import tqdm
import nibabel

# %%
def read_train_exam(exam_nb):
    image = nibabel.load('../chaos/train/%02d-T2SPIR-src.nii.gz'%(exam_nb))
    mask = nibabel.load('../chaos/train/%02d-T2SPIR-mask.nii.gz'%(exam_nb))
    return image, mask

def read_test_exam(exam_nb):
    image = nibabel.load('../chaos/test/%02d-T2SPIR-src.nii.gz'%(exam_nb))
    return image

# %%
img_rows,img_cols = 256,256
def preprocess(image):
    #shape (slide,256,256)
    image_ = np.ndarray((image.shape[2],img_rows,img_cols,1))
    for i in range(image.shape[2]):
        image_[i,:,:,0] = resize(image.get_data()[:,:,i],(img_rows,img_cols),mode='reflect',preserve_range=True,
                               anti_aliasing=True)            
    #print(image_.shape)
    return image_

# %%
image_1, mask_1 = read_train_exam(2)

# %%
print("before scale {},{},".format(np.unique(mask_1.get_data()),np.unique(image_1.get_data())))
# Out:
# before scale [0 1 2 3 4],[   0    1    2 ... 1474 1501 1503],

# %%
print("after scale {},{}".format(np.unique(preprocess(mask_1)),np.unique(preprocess(image_1))))
# Out:
# after scale [0.       0.015625 0.015625 ... 3.984375 3.984375 4.      ],[0.00000000e+00 1.56250000e-02 1.56250000e-02 ... 1.45790625e+03
#  1.46843750e+03 1.48428125e+03]

# %%
def mask_to_channels(mask,init,classes):
    #get mask for each class
    img = np.asarray([np.where(mask == i,1,0 ) for i in range(init,classes)])
    img = np.swapaxes(img,0,-1)#new shape (row,col,class)
    print(img.shape)
    return img

# %%
test = mask_1.get_data()[:,:,15]
img = mask_to_channels(test,0,5)
for i in range(0,5):
    plt.subplot(1,5,i+1)
    plt.imshow(img[:,:,i])
plt.show()

# %%
def create_data_train(train_ids = [1,2,3,5,8,10,13,19],background = 0):
    for idx, train_id in tqdm(enumerate(train_ids)):
        image, mask = read_train_exam(train_id)     
        image = preprocess(image)
        mask = preprocess(mask) 
        #transform le mask
        if background:
            #create mask for 5 classess
            mask = mask_to_channels(mask,0,5)[0]
        else:
            mask = mask_to_channels(mask,1,5)[0]            
       
        if idx > 0:
            train_data = np.concatenate((train_data, image),axis=0)
            train_mask = np.concatenate((train_mask, mask),axis=0)
        else:
            train_data = image
            train_mask = mask
    print("Final shape {},{}".format(train_data.shape,train_mask.shape))    
    np.savez_compressed('./dataset/imgs_train_{}'.format(background), imgs=train_data)
    np.savez_compressed('./dataset/imgs_mask_train_{}'.format(background), imgs_mask=train_mask)

# %%
#dataset training without background
create_data_train()
# Out:
# 1it [00:00,  3.35it/s]
# (1, 36, 256, 256, 4)
# 2it [00:00,  3.18it/s]
# (1, 26, 256, 256, 4)
# 3it [00:01,  2.44it/s]
# (1, 30, 256, 256, 4)
# 4it [00:01,  2.46it/s]
# (1, 30, 256, 256, 4)
# 5it [00:02,  2.29it/s]
# (1, 32, 256, 256, 4)
# (1, 36, 256, 256, 4)
# 6it [00:02,  2.14it/s]
# (1, 30, 256, 256, 4)
# 7it [00:03,  1.94it/s]
# (1, 30, 256, 256, 4)
# 8it [00:04,  1.71it/s]
# Final shape (250, 256, 256, 1),(250, 256, 256, 4)

# %%
#dataset training without background
create_data_train(background=1)
# Out:
# 1it [00:00,  3.06it/s]
# (1, 36, 256, 256, 5)
# 2it [00:00,  2.92it/s]
# (1, 26, 256, 256, 5)
# 3it [00:01,  2.61it/s]
# (1, 30, 256, 256, 5)
# 4it [00:01,  2.50it/s]
# (1, 30, 256, 256, 5)
# (1, 32, 256, 256, 5)
# 5it [00:02,  2.23it/s]
# (1, 36, 256, 256, 5)
# 6it [00:02,  2.03it/s]
# (1, 30, 256, 256, 5)
# 7it [00:03,  1.84it/s]
# (1, 30, 256, 256, 5)
# 8it [00:04,  1.68it/s]
# Final shape (250, 256, 256, 1),(250, 256, 256, 5)

# %% [markdown]
# ### plot images

# %%
img = np.load('./dataset/imgs_train_0.npz')['imgs']
img_mask = np.load('./dataset/imgs_mask_train_0.npz')['imgs_mask']

# %%
img[:,:,:].shape
# Out:
# (250, 256, 256, 1)

# %%
img[:,:,:,0].shape
# Out:
# (250, 256, 256)

# %%
#plot random samples from data
def plot_random_images(data,mask,size,id):
    index = np.random.choice(range(data.shape[0]),size)
    plt.figure(figsize=(20, 15))
    for i,x in enumerate(index):
        plt.subplot(1, len(index), i+1)
        plt.imshow(data[x,:,:,0], cmap='gray', interpolation='nearest')
        plt.imshow(mask[x,:,:,id], cmap='jet', alpha=0.5)
    plt.show()

# %%
#plot random samples from training data
print("Training data")
plot_random_images(img,img_mask,5,1)
# Out:
# Training data

# %%
plot_random_images(img,img_mask,5,3)

# %%
print(np.unique(img))
# Out:
# [0.00000000e+00 1.00974196e-28 1.51461294e-28 ... 2.02000000e+03
#  2.04100000e+03 2.04300000e+03]

# %%
imgs_train = img.astype('float32')
mean = np.mean(imgs_train)  # mean for data centering
std = np.std(imgs_train)  # std for data normalization

imgs_train -= mean
imgs_train /= std

# %%
print(np.unique(imgs_train))
# Out:
# [-0.53052306 -0.53049946 -0.53047585 ... 11.664149   11.790925
#  11.8029995 ]

# %% [markdown]
# ### test

# %%
def get_data_test(test_ids = [21,22,32,39]):
    for idx, test_id in tqdm(enumerate(test_ids)):
        image = read_test_exam(test_id)     
        image = preprocess(image)
        print("img {}".format(image.shape))
        if idx > 0:
            test_data = np.concatenate((test_data, image),axis=0)
        else:
            test_data = image
    print("Final shape {}".format(test_data.shape))    
    np.savez_compressed('./dataset/imgs_test', imgs=test_data)

# %%
get_data_test()
# Out:
# 2it [00:00,  8.78it/s]
# img (31, 256, 256, 1)
# img (33, 256, 256, 1)
# 4it [00:00,  8.10it/s]
# img (39, 256, 256, 1)
# img (26, 256, 256, 1)
# Final shape (129, 256, 256, 1)

# %% [markdown]
# # MODEL

# %%
#version tf1
from keras.models import Model
from keras.layers import Input, concatenate, Conv2D, MaxPooling2D, Conv2DTranspose
from keras.optimizers import Adam,
from keras.callbacks import ModelCheckpoint
from keras import backend as K


from data import load_train_data, load_test_data

K.set_image_data_format('channels_last')  # TF dimension ordering in this code
# Out:
# Using TensorFlow backend.

# %%
img_rows = 256
img_cols = 256

# %%
smooth = 1.
#batch 32!
def dice_coef_(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)

def dice_coef(y_true, y_pred):
    dice_liver = dice_coef_(y_true[0,:,:,0],y_pred[0,:,:,0])
    dice_rkidney = dice_coef_(y_true[0,:,:,1], y_pred[0,:,:,1])
    dice_lkidney = dice_coef_(y_true[0,:,:,2], y_pred[0,:,:,2])
    dice_spleen = dice_coef_(y_true[0,:,:,3], y_pred[0,:,:,3])
    print(dice_liver)
    #return dice_liver + (dice_rkidney+dice_lkidney)+dice_spleen
    return dice_liver+dice_rkidney+dice_lkidney+dice_spleen

def dice_coef_loss(y_true, y_pred):  
    return -dice_coef(y_true, y_pred)

# %%
def get_unet():
    inputs = Input((img_rows, img_cols, 1))
    conv1 = Conv2D(32, (3, 3), activation='relu', padding='same')(inputs)
    conv1 = Conv2D(32, (3, 3), activation='relu', padding='same')(conv1)
    pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)

    conv2 = Conv2D(64, (3, 3), activation='relu', padding='same')(pool1)
    conv2 = Conv2D(64, (3, 3), activation='relu', padding='same')(conv2)
    pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)

    conv3 = Conv2D(128, (3, 3), activation='relu', padding='same')(pool2)
    conv3 = Conv2D(128, (3, 3), activation='relu', padding='same')(conv3)
    pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)

    conv4 = Conv2D(256, (3, 3), activation='relu', padding='same')(pool3)
    conv4 = Conv2D(256, (3, 3), activation='relu', padding='same')(conv4)
    pool4 = MaxPooling2D(pool_size=(2, 2))(conv4)

    conv5 = Conv2D(512, (3, 3), activation='relu', padding='same')(pool4)
    conv5 = Conv2D(512, (3, 3), activation='relu', padding='same')(conv5)

    up6 = concatenate([Conv2DTranspose(256, (2, 2), strides=(2, 2), padding='same')(conv5), conv4], axis=3)
    conv6 = Conv2D(256, (3, 3), activation='relu', padding='same')(up6)
    conv6 = Conv2D(256, (3, 3), activation='relu', padding='same')(conv6)

    up7 = concatenate([Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same')(conv6), conv3], axis=3)
    conv7 = Conv2D(128, (3, 3), activation='relu', padding='same')(up7)
    conv7 = Conv2D(128, (3, 3), activation='relu', padding='same')(conv7)

    up8 = concatenate([Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(conv7), conv2], axis=3)
    conv8 = Conv2D(64, (3, 3), activation='relu', padding='same')(up8)
    conv8 = Conv2D(64, (3, 3), activation='relu', padding='same')(conv8)

    up9 = concatenate([Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same')(conv8), conv1], axis=3)
    conv9 = Conv2D(32, (3, 3), activation='relu', padding='same')(up9)
    conv9 = Conv2D(32, (3, 3), activation='relu', padding='same')(conv9)

    conv10 = Conv2D(4,(1, 1), activation='sigmoid')(conv9)

    model = Model(inputs=[inputs], outputs=[conv10])
    sgd = SGD(learning_rate=0.01, momentum=0.0, nesterov=False)
    model.compile(optimizer=Adam(lr=1e-5), loss=dice_coef_loss, metrics=[dice_coef])

    return model

# %%
from data import load_train_data, load_test_data

# %% [markdown]
# # training

# %%
print('Loading and preprocessing train data...')
print('-'*30)
imgs_train, imgs_mask_train = load_train_data()
name = 'model_test_dice-80.h5'

checkpoint = ModelCheckpoint(name, verbose=1, save_best_only=True, save_weights_only=True)
model = get_unet()
model.summary()
# Out:
# Loading and preprocessing train data...
# ------------------------------
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_14 (InputLayer)           (None, 256, 256, 1)  0
# __________________________________________________________________________________________________
# conv2d_248 (Conv2D)             (None, 256, 256, 32) 320         input_14[0][0]
# __________________________________________________________________________________________________
# conv2d_249 (Conv2D)             (None, 256, 256, 32) 9248        conv2d_248[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_53 (MaxPooling2D) (None, 128, 128, 32) 0           conv2d_249[0][0]
# __________________________________________________________________________________________________
# conv2d_250 (Conv2D)             (None, 128, 128, 64) 18496       max_pooling2d_53[0][0]
# __________________________________________________________________________________________________
# conv2d_251 (Conv2D)             (None, 128, 128, 64) 36928       conv2d_250[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_54 (MaxPooling2D) (None, 64, 64, 64)   0           conv2d_251[0][0]
# __________________________________________________________________________________________________
# conv2d_252 (Conv2D)             (None, 64, 64, 128)  73856       max_pooling2d_54[0][0]
# __________________________________________________________________________________________________
# conv2d_253 (Conv2D)             (None, 64, 64, 128)  147584      conv2d_252[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_55 (MaxPooling2D) (None, 32, 32, 128)  0           conv2d_253[0][0]
# __________________________________________________________________________________________________
# conv2d_254 (Conv2D)             (None, 32, 32, 256)  295168      max_pooling2d_55[0][0]
# __________________________________________________________________________________________________
# conv2d_255 (Conv2D)             (None, 32, 32, 256)  590080      conv2d_254[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_56 (MaxPooling2D) (None, 16, 16, 256)  0           conv2d_255[0][0]
# __________________________________________________________________________________________________
# conv2d_256 (Conv2D)             (None, 16, 16, 512)  1180160     max_pooling2d_56[0][0]
# __________________________________________________________________________________________________
# conv2d_257 (Conv2D)             (None, 16, 16, 512)  2359808     conv2d_256[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_53 (Conv2DTran (None, 32, 32, 256)  524544      conv2d_257[0][0]
# __________________________________________________________________________________________________
# concatenate_53 (Concatenate)    (None, 32, 32, 512)  0           conv2d_transpose_53[0][0]
#                                                                  conv2d_255[0][0]
# __________________________________________________________________________________________________
# conv2d_258 (Conv2D)             (None, 32, 32, 256)  1179904     concatenate_53[0][0]
# __________________________________________________________________________________________________
# conv2d_259 (Conv2D)             (None, 32, 32, 256)  590080      conv2d_258[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_54 (Conv2DTran (None, 64, 64, 128)  131200      conv2d_259[0][0]
# __________________________________________________________________________________________________
# concatenate_54 (Concatenate)    (None, 64, 64, 256)  0           conv2d_transpose_54[0][0]
#                                                                  conv2d_253[0][0]
# __________________________________________________________________________________________________
# conv2d_260 (Conv2D)             (None, 64, 64, 128)  295040      concatenate_54[0][0]
# __________________________________________________________________________________________________
# conv2d_261 (Conv2D)             (None, 64, 64, 128)  147584      conv2d_260[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_55 (Conv2DTran (None, 128, 128, 64) 32832       conv2d_261[0][0]
# __________________________________________________________________________________________________
# concatenate_55 (Concatenate)    (None, 128, 128, 128 0           conv2d_transpose_55[0][0]
#                                                                  conv2d_251[0][0]
# __________________________________________________________________________________________________
# conv2d_262 (Conv2D)             (None, 128, 128, 64) 73792       concatenate_55[0][0]
# __________________________________________________________________________________________________
# conv2d_263 (Conv2D)             (None, 128, 128, 64) 36928       conv2d_262[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_56 (Conv2DTran (None, 256, 256, 32) 8224        conv2d_263[0][0]
# __________________________________________________________________________________________________
# concatenate_56 (Concatenate)    (None, 256, 256, 64) 0           conv2d_transpose_56[0][0]
#                                                                  conv2d_249[0][0]
# __________________________________________________________________________________________________
# conv2d_264 (Conv2D)             (None, 256, 256, 32) 18464       concatenate_56[0][0]
# __________________________________________________________________________________________________
# conv2d_265 (Conv2D)             (None, 256, 256, 32) 9248        conv2d_264[0][0]
# __________________________________________________________________________________________________
# conv2d_266 (Conv2D)             (None, 256, 256, 4)  132         conv2d_265[0][0]
# ==================================================================================================
# Total params: 7,759,620
# Trainable params: 7,759,620
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
imgs_train = imgs_train.astype('float32')
mean = np.mean(imgs_train)  # mean for data centering
#std = np.std(imgs_train)  # std for data normalization
#imgs_train -= mean
#imgs_train /= std
print("normalize")
#np.savez_compressed('scaler',mean=mean,std=std)

results = model.fit(imgs_train, imgs_mask_train, batch_size=32, epochs=100, callbacks=[checkpoint]
                   ,shuffle=True,
              validation_split=0.2)
# Out:
# normalize
# Train on 200 samples, validate on 50 samples
# Epoch 1/100
# 200/200 [==============================] - 5s 27ms/step - loss: -0.0092 - mean_absolute_error: 0.4728 - val_loss: -0.0062 - val_mean_absolute_error: 0.4789
#
# Epoch 00001: val_loss improved from inf to -0.00616, saving model to model_test_dice-80.h5
# Epoch 2/100
# 200/200 [==============================] - 3s 17ms/step - loss: -0.0094 - mean_absolute_error: 0.4788 - val_loss: -0.0064 - val_mean_absolute_error: 0.4865
#
# Epoch 00002: val_loss improved from -0.00616 to -0.00638, saving model to model_test_dice-80.h5
# Epoch 3/100
# 200/200 [==============================] - 4s 18ms/step - loss: -0.0097 - mean_absolute_error: 0.4861 - val_loss: -0.0065 - val_mean_absolute_error: 0.4909
#
# Epoch 00003: val_loss improved from -0.00638 to -0.00645, saving model to model_test_dice-80.h5
# Epoch 4/100
# 200/200 [==============================] - 4s 18ms/step - loss: -0.0098 - mean_absolute_error: 0.4878 - val_loss: -0.0065 - val_mean_absolute_error: 0.4895
#
# Epoch 00004: val_loss improved from -0.00645 to -0.00648, saving model to model_test_dice-80.h5
# Epoch 5/100
# 200/200 [==============================] - 3s 17ms/step - loss: -0.0099 - mean_absolute_error: 0.4848 - val_loss: -0.0065 - val_mean_absolute_error: 0.4852
#
# Epoch 00005: val_loss improved from -0.00648 to -0.00653, saving model to model_test_dice-80.h5
# Epoch 6/100
# 200/200 [==============================] - 3s 17ms/step - loss: -0.0100 - mean_absolute_error: 0.4794 - val_loss: -0.0066 - val_mean_absolute_error: 0.4792
#
# Epoch 00006: val_loss improved from -0.00653 to -0.00659, saving model to model_test_dice-80.h5
# Epoch 7/100
# 200/200 [==============================] - 3s 17ms/step - loss: -0.0100 - mean_absolute_error: 0.4723 - val_loss: -0.0066 - val_mean_absolute_error: 0.4724
#
# Epoch 00007: val_loss improved from -0.00659 to -0.00664, saving model to model_test_dice-80.h5
# Epoch 8/100
# 200/200 [==============================] - 4s 18ms/step - loss: -0.0101 - mean_absolute_error: 0.4658 - val_loss: -0.0067 - val_mean_absolute_error: 0.4686
#
# Epoch 00008: val_loss improved from -0.00664 to -0.00669, saving model to model_test_dice-80.h5
# Epoch 9/100
# 200/200 [==============================] - 4s 18ms/step - loss: -0.0102 - mean_absolute_error: 0.4622 - val_loss: -0.0067 - val_mean_absolute_error: 0.4657
#
# Epoch 00009: val_loss improved from -0.00669 to -0.00673, saving model to model_test_dice-80.h5
# Epoch 10/100
# 200/200 [==============================] - 3s 17ms/step - loss: -0.0103 - mean_absolute_error: 0.4585 - val_loss: -0.0068 - val_mean_absolute_error: 0.4613
#
# Epoch 00010: val_loss improved from -0.00673 to -0.00678, saving model to model_test_dice-80.h5
# Epoch 11/100
# 200/200 [==============================] - 4s 18ms/step - loss: -0.0103 - mean_absolute_error: 0.4523 - val_loss: -0.0068 - val_mean_absolute_error: 0.4548
#
# Epoch 00011: val_loss improved from -0.00678 to -0.00684, saving model to model_test_dice-80.h5
# Epoch 12/100
# 200/200 [==============================] - 4s 18ms/step - loss: -0.0104 - mean_absolute_error: 0.4463 - val_loss: -0.0069 - val_mean_absolute_error: 0.4508
#
# Epoch 00012: val_loss improved from -0.00684 to -0.00689, saving model to model_test_dice-80.h5
# Epoch 13/100
# 200/200 [==============================] - 4s 18ms/step - loss: -0.0105 - mean_absolute_error: 0.4419 - val_loss: -0.0069 - val_mean_absolute_error: 0.4475
#
# Epoch 00013: val_loss improved from -0.00689 to -0.00694, saving model to model_test_dice-80.h5
# Epoch 14/100
# 200/200 [==============================] - 4s 18ms/step - loss: -0.0106 - mean_absolute_error: 0.4385 - val_loss: -0.0070 - val_mean_absolute_error: 0.4439
#
# Epoch 00014: val_loss improved from -0.00694 to -0.00700, saving model to model_test_dice-80.h5
# Epoch 15/100
# 200/200 [==============================] - 4s 18ms/step - loss: -0.0107 - mean_absolute_error: 0.4320 - val_loss: -0.0071 - val_mean_absolute_error: 0.4357
#
# Epoch 00015: val_loss improved from -0.00700 to -0.00707, saving model to model_test_dice-80.h5
# Epoch 16/100
# 200/200 [==============================] - 4s 18ms/step - loss: -0.0108 - mean_absolute_error: 0.4238 - val_loss: -0.0072 - val_mean_absolute_error: 0.4297
#
# Epoch 00016: val_loss improved from -0.00707 to -0.00716, saving model to model_test_dice-80.h5
# Epoch 17/100
# 200/200 [==============================] - 4s 18ms/step - loss: -0.0110 - mean_absolute_error: 0.4167 - val_loss: -0.0073 - val_mean_absolute_error: 0.4207
#
# Epoch 00017: val_loss improved from -0.00716 to -0.00728, saving model to model_test_dice-80.h5
# Epoch 18/100
# 200/200 [==============================] - 4s 18ms/step - loss: -0.0112 - mean_absolute_error: 0.4038 - val_loss: -0.0075 - val_mean_absolute_error: 0.4053
#
# Epoch 00018: val_loss improved from -0.00728 to -0.00747, saving model to model_test_dice-80.h5
# Epoch 19/100
# 200/200 [==============================] - 4s 18ms/step - loss: -0.0115 - mean_absolute_error: 0.3869 - val_loss: -0.0078 - val_mean_absolute_error: 0.3840
#
# Epoch 00019: val_loss improved from -0.00747 to -0.00779, saving model to model_test_dice-80.h5
# Epoch 20/100
# 200/200 [==============================] - 4s 18ms/step - loss: -0.0122 - mean_absolute_error: 0.3552 - val_loss: -0.0084 - val_mean_absolute_error: 0.3486
#
# Epoch 00020: val_loss improved from -0.00779 to -0.00844, saving model to model_test_dice-80.h5
# Epoch 21/100
# 200/200 [==============================] - 4s 18ms/step - loss: -0.0136 - mean_absolute_error: 0.3155 - val_loss: -0.0097 - val_mean_absolute_error: 0.2859
#
# Epoch 00021: val_loss improved from -0.00844 to -0.00971, saving model to model_test_dice-80.h5
# Epoch 22/100
# 200/200 [==============================] - 4s 18ms/step - loss: -0.0162 - mean_absolute_error: 0.2580 - val_loss: -0.0121 - val_mean_absolute_error: 0.2380
#
# Epoch 00022: val_loss improved from -0.00971 to -0.01206, saving model to model_test_dice-80.h5
# Epoch 23/100
# 200/200 [==============================] - 4s 18ms/step - loss: -0.0215 - mean_absolute_error: 0.1990 - val_loss: -0.0189 - val_mean_absolute_error: 0.2037
#
# Epoch 00023: val_loss improved from -0.01206 to -0.01886, saving model to model_test_dice-80.h5
# Epoch 24/100
# 200/200 [==============================] - 4s 18ms/step - loss: -0.0319 - mean_absolute_error: 0.1695 - val_loss: -0.0302 - val_mean_absolute_error: 0.1539
#
# Epoch 00024: val_loss improved from -0.01886 to -0.03016, saving model to model_test_dice-80.h5
# Epoch 25/100
# 200/200 [==============================] - 4s 18ms/step - loss: -0.0429 - mean_absolute_error: 0.1337 - val_loss: -0.0408 - val_mean_absolute_error: 0.1092
#
# Epoch 00025: val_loss improved from -0.03016 to -0.04080, saving model to model_test_dice-80.h5
# Epoch 26/100
# 200/200 [==============================] - 4s 18ms/step - loss: -0.0582 - mean_absolute_error: 0.0937 - val_loss: -0.0548 - val_mean_absolute_error: 0.0772
#
# Epoch 00026: val_loss improved from -0.04080 to -0.05480, saving model to model_test_dice-80.h5
# Epoch 27/100
# 200/200 [==============================] - 4s 18ms/step - loss: -0.0782 - mean_absolute_error: 0.0672 - val_loss: -0.0764 - val_mean_absolute_error: 0.0570
#
# Epoch 00027: val_loss improved from -0.05480 to -0.07642, saving model to model_test_dice-80.h5
# Epoch 28/100
# 200/200 [==============================] - 4s 18ms/step - loss: -0.1039 - mean_absolute_error: 0.0486 - val_loss: -0.1015 - val_mean_absolute_error: 0.0433
#
# Epoch 00028: val_loss improved from -0.07642 to -0.10147, saving model to model_test_dice-80.h5
# Epoch 29/100
# 200/200 [==============================] - 4s 18ms/step - loss: -0.1296 - mean_absolute_error: 0.0370 - val_loss: -0.1287 - val_mean_absolute_error: 0.0311
#
# Epoch 00029: val_loss improved from -0.10147 to -0.12867, saving model to model_test_dice-80.h5
# Epoch 30/100
# 200/200 [==============================] - 4s 18ms/step - loss: -0.1540 - mean_absolute_error: 0.0294 - val_loss: -0.1474 - val_mean_absolute_error: 0.0267
#
# Epoch 00030: val_loss improved from -0.12867 to -0.14738, saving model to model_test_dice-80.h5
# Epoch 31/100
# 200/200 [==============================] - 4s 18ms/step - loss: -0.1714 - mean_absolute_error: 0.0257 - val_loss: -0.1644 - val_mean_absolute_error: 0.0226
#
# Epoch 00031: val_loss improved from -0.14738 to -0.16444, saving model to model_test_dice-80.h5
# Epoch 32/100
# 200/200 [==============================] - 4s 18ms/step - loss: -0.1867 - mean_absolute_error: 0.0232 - val_loss: -0.1779 - val_mean_absolute_error: 0.0215
#
# Epoch 00032: val_loss improved from -0.16444 to -0.17788, saving model to model_test_dice-80.h5
# Epoch 33/100
# 200/200 [==============================] - 4s 18ms/step - loss: -0.1989 - mean_absolute_error: 0.0212 - val_loss: -0.1736 - val_mean_absolute_error: 0.0237
#
# Epoch 00033: val_loss did not improve from -0.17788
# Epoch 34/100
# 200/200 [==============================] - 4s 18ms/step - loss: -0.1958 - mean_absolute_error: 0.0218 - val_loss: -0.1911 - val_mean_absolute_error: 0.0203
#
# Epoch 00034: val_loss improved from -0.17788 to -0.19107, saving model to model_test_dice-80.h5
# Epoch 35/100
# 200/200 [==============================] - 4s 18ms/step - loss: -0.2102 - mean_absolute_error: 0.0213 - val_loss: -0.2013 - val_mean_absolute_error: 0.0176
#
# Epoch 00035: val_loss improved from -0.19107 to -0.20134, saving model to model_test_dice-80.h5
# Epoch 36/100
# 200/200 [==============================] - 4s 18ms/step - loss: -0.2186 - mean_absolute_error: 0.0198 - val_loss: -0.2019 - val_mean_absolute_error: 0.0163
#
# Epoch 00036: val_loss improved from -0.20134 to -0.20192, saving model to model_test_dice-80.h5
# Epoch 37/100
# 200/200 [==============================] - 4s 18ms/step - loss: -0.2249 - mean_absolute_error: 0.0189 - val_loss: -0.2132 - val_mean_absolute_error: 0.0167
#
# Epoch 00037: val_loss improved from -0.20192 to -0.21317, saving model to model_test_dice-80.h5
# Epoch 38/100
# 200/200 [==============================] - 4s 18ms/step - loss: -0.2305 - mean_absolute_error: 0.0179 - val_loss: -0.2131 - val_mean_absolute_error: 0.0160
#
# Epoch 00038: val_loss did not improve from -0.21317
# Epoch 39/100
# 200/200 [==============================] - 4s 18ms/step - loss: -0.2361 - mean_absolute_error: 0.0173 - val_loss: -0.2213 - val_mean_absolute_error: 0.0167
#
# Epoch 00039: val_loss improved from -0.21317 to -0.22131, saving model to model_test_dice-80.h5
# Epoch 40/100
# 200/200 [==============================] - 4s 18ms/step - loss: -0.2402 - mean_absolute_error: 0.0169 - val_loss: -0.2275 - val_mean_absolute_error: 0.0160
#
# Epoch 00040: val_loss improved from -0.22131 to -0.22750, saving model to model_test_dice-80.h5
# Epoch 41/100
# 200/200 [==============================] - 4s 18ms/step - loss: -0.2466 - mean_absolute_error: 0.0169 - val_loss: -0.2366 - val_mean_absolute_error: 0.0149
#
# Epoch 00041: val_loss improved from -0.22750 to -0.23659, saving model to model_test_dice-80.h5
# Epoch 42/100
# 200/200 [==============================] - 4s 18ms/step - loss: -0.2559 - mean_absolute_error: 0.0158 - val_loss: -0.2408 - val_mean_absolute_error: 0.0147
#
# Epoch 00042: val_loss improved from -0.23659 to -0.24085, saving model to model_test_dice-80.h5
# Epoch 43/100
# 200/200 [==============================] - 4s 18ms/step - loss: -0.2597 - mean_absolute_error: 0.0156 - val_loss: -0.2449 - val_mean_absolute_error: 0.0139
#
# Epoch 00043: val_loss improved from -0.24085 to -0.24491, saving model to model_test_dice-80.h5
# Epoch 44/100
# 200/200 [==============================] - 4s 18ms/step - loss: -0.2661 - mean_absolute_error: 0.0150 - val_loss: -0.2484 - val_mean_absolute_error: 0.0143
#
# Epoch 00044: val_loss improved from -0.24491 to -0.24842, saving model to model_test_dice-80.h5
# Epoch 45/100
# 200/200 [==============================] - 4s 18ms/step - loss: -0.2707 - mean_absolute_error: 0.0145 - val_loss: -0.2539 - val_mean_absolute_error: 0.0133
#
# Epoch 00045: val_loss improved from -0.24842 to -0.25392, saving model to model_test_dice-80.h5
# Epoch 46/100
# 200/200 [==============================] - 4s 18ms/step - loss: -0.2755 - mean_absolute_error: 0.0143 - val_loss: -0.2523 - val_mean_absolute_error: 0.0124
#
# Epoch 00046: val_loss did not improve from -0.25392
# Epoch 47/100
# 200/200 [==============================] - 4s 18ms/step - loss: -0.2730 - mean_absolute_error: 0.0148 - val_loss: -0.2463 - val_mean_absolute_error: 0.0119
#
# Epoch 00047: val_loss did not improve from -0.25392
# Epoch 48/100
# 200/200 [==============================] - 4s 18ms/step - loss: -0.2713 - mean_absolute_error: 0.0144 - val_loss: -0.2582 - val_mean_absolute_error: 0.0134
#
# Epoch 00048: val_loss improved from -0.25392 to -0.25816, saving model to model_test_dice-80.h5
# Epoch 49/100
# 200/200 [==============================] - 4s 18ms/step - loss: -0.2774 - mean_absolute_error: 0.0137 - val_loss: -0.2610 - val_mean_absolute_error: 0.0135
#
# Epoch 00049: val_loss improved from -0.25816 to -0.26100, saving model to model_test_dice-80.h5
# Epoch 50/100
# 200/200 [==============================] - 4s 18ms/step - loss: -0.2833 - mean_absolute_error: 0.0138 - val_loss: -0.2573 - val_mean_absolute_error: 0.0136
#
# Epoch 00050: val_loss did not improve from -0.26100
# Epoch 51/100
# 200/200 [==============================] - 4s 18ms/step - loss: -0.2840 - mean_absolute_error: 0.0138 - val_loss: -0.2669 - val_mean_absolute_error: 0.0131
#
# Epoch 00051: val_loss improved from -0.26100 to -0.26690, saving model to model_test_dice-80.h5
# Epoch 52/100
# 200/200 [==============================] - 4s 18ms/step - loss: -0.2918 - mean_absolute_error: 0.0136 - val_loss: -0.2684 - val_mean_absolute_error: 0.0129
#
# Epoch 00052: val_loss improved from -0.26690 to -0.26842, saving model to model_test_dice-80.h5
# Epoch 53/100
# 200/200 [==============================] - 4s 18ms/step - loss: -0.2913 - mean_absolute_error: 0.0137 - val_loss: -0.2677 - val_mean_absolute_error: 0.0127
#
# Epoch 00053: val_loss did not improve from -0.26842
# Epoch 54/100
# 200/200 [==============================] - 4s 18ms/step - loss: -0.2943 - mean_absolute_error: 0.0135 - val_loss: -0.2713 - val_mean_absolute_error: 0.0126
#
# Epoch 00054: val_loss improved from -0.26842 to -0.27129, saving model to model_test_dice-80.h5
# Epoch 55/100
# 200/200 [==============================] - 4s 18ms/step - loss: -0.3005 - mean_absolute_error: 0.0132 - val_loss: -0.2756 - val_mean_absolute_error: 0.0125
#
# Epoch 00055: val_loss improved from -0.27129 to -0.27558, saving model to model_test_dice-80.h5
# Epoch 56/100
# 200/200 [==============================] - 4s 18ms/step - loss: -0.2996 - mean_absolute_error: 0.0133 - val_loss: -0.2756 - val_mean_absolute_error: 0.0120
#
# Epoch 00056: val_loss improved from -0.27558 to -0.27560, saving model to model_test_dice-80.h5
# Epoch 57/100
# 200/200 [==============================] - 4s 18ms/step - loss: -0.2959 - mean_absolute_error: 0.0131 - val_loss: -0.2730 - val_mean_absolute_error: 0.0131
#
# Epoch 00057: val_loss did not improve from -0.27560
# Epoch 58/100
# 200/200 [==============================] - 4s 18ms/step - loss: -0.2945 - mean_absolute_error: 0.0137 - val_loss: -0.2702 - val_mean_absolute_error: 0.0126
#
# Epoch 00058: val_loss did not improve from -0.27560
# Epoch 59/100
# 200/200 [==============================] - 4s 18ms/step - loss: -0.3016 - mean_absolute_error: 0.0132 - val_loss: -0.2742 - val_mean_absolute_error: 0.0125
#
# Epoch 00059: val_loss did not improve from -0.27560
# Epoch 60/100
# 200/200 [==============================] - 4s 18ms/step - loss: -0.3005 - mean_absolute_error: 0.0135 - val_loss: -0.2619 - val_mean_absolute_error: 0.0115
#
# Epoch 00060: val_loss did not improve from -0.27560
# Epoch 61/100
# 200/200 [==============================] - 4s 18ms/step - loss: -0.3004 - mean_absolute_error: 0.0129 - val_loss: -0.2766 - val_mean_absolute_error: 0.0123
#
# Epoch 00061: val_loss improved from -0.27560 to -0.27664, saving model to model_test_dice-80.h5
# Epoch 62/100
# 200/200 [==============================] - 4s 18ms/step - loss: -0.3054 - mean_absolute_error: 0.0131 - val_loss: -0.2741 - val_mean_absolute_error: 0.0127
#
# Epoch 00062: val_loss did not improve from -0.27664
# Epoch 63/100
# 200/200 [==============================] - 4s 18ms/step - loss: -0.3048 - mean_absolute_error: 0.0129 - val_loss: -0.2751 - val_mean_absolute_error: 0.0130
#
# Epoch 00063: val_loss did not improve from -0.27664
# Epoch 64/100
# 200/200 [==============================] - 4s 18ms/step - loss: -0.3091 - mean_absolute_error: 0.0128 - val_loss: -0.2802 - val_mean_absolute_error: 0.0123
#
# Epoch 00064: val_loss improved from -0.27664 to -0.28024, saving model to model_test_dice-80.h5
# Epoch 65/100
# 200/200 [==============================] - 4s 18ms/step - loss: -0.3118 - mean_absolute_error: 0.0131 - val_loss: -0.2785 - val_mean_absolute_error: 0.0115
#
# Epoch 00065: val_loss did not improve from -0.28024
# Epoch 66/100
# 200/200 [==============================] - 4s 18ms/step - loss: -0.3116 - mean_absolute_error: 0.0126 - val_loss: -0.2826 - val_mean_absolute_error: 0.0124
#
# Epoch 00066: val_loss improved from -0.28024 to -0.28264, saving model to model_test_dice-80.h5
# Epoch 67/100
# 200/200 [==============================] - 4s 18ms/step - loss: -0.3118 - mean_absolute_error: 0.0127 - val_loss: -0.2813 - val_mean_absolute_error: 0.0124
#
# Epoch 00067: val_loss did not improve from -0.28264
# Epoch 68/100
# 200/200 [==============================] - 4s 18ms/step - loss: -0.3137 - mean_absolute_error: 0.0125 - val_loss: -0.2808 - val_mean_absolute_error: 0.0127
#
# Epoch 00068: val_loss did not improve from -0.28264
# Epoch 69/100
# 200/200 [==============================] - 4s 18ms/step - loss: -0.3145 - mean_absolute_error: 0.0127 - val_loss: -0.2819 - val_mean_absolute_error: 0.0124
#
# Epoch 00069: val_loss did not improve from -0.28264
# Epoch 70/100
# 200/200 [==============================] - 4s 18ms/step - loss: -0.3157 - mean_absolute_error: 0.0128 - val_loss: -0.2813 - val_mean_absolute_error: 0.0116
#
# Epoch 00070: val_loss did not improve from -0.28264
# Epoch 71/100
# 200/200 [==============================] - 4s 18ms/step - loss: -0.3179 - mean_absolute_error: 0.0125 - val_loss: -0.2880 - val_mean_absolute_error: 0.0115
#
# Epoch 00071: val_loss improved from -0.28264 to -0.28799, saving model to model_test_dice-80.h5
# Epoch 72/100
# 200/200 [==============================] - 4s 18ms/step - loss: -0.3166 - mean_absolute_error: 0.0128 - val_loss: -0.2798 - val_mean_absolute_error: 0.0111
#
# Epoch 00072: val_loss did not improve from -0.28799
# Epoch 73/100
# 200/200 [==============================] - 4s 18ms/step - loss: -0.3147 - mean_absolute_error: 0.0126 - val_loss: -0.2866 - val_mean_absolute_error: 0.0121
#
# Epoch 00073: val_loss did not improve from -0.28799
# Epoch 74/100
# 200/200 [==============================] - 4s 18ms/step - loss: -0.3215 - mean_absolute_error: 0.0123 - val_loss: -0.2881 - val_mean_absolute_error: 0.0120
#
# Epoch 00074: val_loss improved from -0.28799 to -0.28814, saving model to model_test_dice-80.h5
# Epoch 75/100
# 200/200 [==============================] - 4s 18ms/step - loss: -0.3226 - mean_absolute_error: 0.0124 - val_loss: -0.2860 - val_mean_absolute_error: 0.0116
#
# Epoch 00075: val_loss did not improve from -0.28814
# Epoch 76/100
# 200/200 [==============================] - 4s 18ms/step - loss: -0.3244 - mean_absolute_error: 0.0123 - val_loss: -0.2892 - val_mean_absolute_error: 0.0114
#
# Epoch 00076: val_loss improved from -0.28814 to -0.28925, saving model to model_test_dice-80.h5
# Epoch 77/100
# 200/200 [==============================] - 4s 18ms/step - loss: -0.3222 - mean_absolute_error: 0.0122 - val_loss: -0.2905 - val_mean_absolute_error: 0.0117
#
# Epoch 00077: val_loss improved from -0.28925 to -0.29048, saving model to model_test_dice-80.h5
# Epoch 78/100
# 200/200 [==============================] - 4s 18ms/step - loss: -0.3256 - mean_absolute_error: 0.0121 - val_loss: -0.2887 - val_mean_absolute_error: 0.0119
#
# Epoch 00078: val_loss did not improve from -0.29048
# Epoch 79/100
# 200/200 [==============================] - 4s 18ms/step - loss: -0.3237 - mean_absolute_error: 0.0121 - val_loss: -0.2880 - val_mean_absolute_error: 0.0121
#
# Epoch 00079: val_loss did not improve from -0.29048
# Epoch 80/100
# 200/200 [==============================] - 4s 18ms/step - loss: -0.3235 - mean_absolute_error: 0.0125 - val_loss: -0.2874 - val_mean_absolute_error: 0.0114
#
# Epoch 00080: val_loss did not improve from -0.29048
# Epoch 81/100
# 200/200 [==============================] - 4s 18ms/step - loss: -0.3282 - mean_absolute_error: 0.0120 - val_loss: -0.2934 - val_mean_absolute_error: 0.0116
#
# Epoch 00081: val_loss improved from -0.29048 to -0.29343, saving model to model_test_dice-80.h5
# Epoch 82/100
# 200/200 [==============================] - 4s 18ms/step - loss: -0.3287 - mean_absolute_error: 0.0119 - val_loss: -0.2896 - val_mean_absolute_error: 0.0121
#
# Epoch 00082: val_loss did not improve from -0.29343
# Epoch 83/100
# 200/200 [==============================] - 4s 18ms/step - loss: -0.3281 - mean_absolute_error: 0.0122 - val_loss: -0.2883 - val_mean_absolute_error: 0.0121
#
# Epoch 00083: val_loss did not improve from -0.29343
# Epoch 84/100
# 200/200 [==============================] - 4s 18ms/step - loss: -0.3294 - mean_absolute_error: 0.0120 - val_loss: -0.2934 - val_mean_absolute_error: 0.0115
#
# Epoch 00084: val_loss did not improve from -0.29343
# Epoch 85/100
# 200/200 [==============================] - 4s 18ms/step - loss: -0.3301 - mean_absolute_error: 0.0119 - val_loss: -0.2913 - val_mean_absolute_error: 0.0119
#
# Epoch 00085: val_loss did not improve from -0.29343
# Epoch 86/100
# 200/200 [==============================] - 4s 18ms/step - loss: -0.3315 - mean_absolute_error: 0.0119 - val_loss: -0.2883 - val_mean_absolute_error: 0.0115
#
# Epoch 00086: val_loss did not improve from -0.29343
# Epoch 87/100
# 200/200 [==============================] - 4s 18ms/step - loss: -0.3299 - mean_absolute_error: 0.0117 - val_loss: -0.2891 - val_mean_absolute_error: 0.0123
#
# Epoch 00087: val_loss did not improve from -0.29343
# Epoch 88/100
# 200/200 [==============================] - 4s 18ms/step - loss: -0.3301 - mean_absolute_error: 0.0122 - val_loss: -0.2920 - val_mean_absolute_error: 0.0110
#
# Epoch 00088: val_loss did not improve from -0.29343
# Epoch 89/100
# 200/200 [==============================] - 4s 18ms/step - loss: -0.3333 - mean_absolute_error: 0.0120 - val_loss: -0.2951 - val_mean_absolute_error: 0.0112
#
# Epoch 00089: val_loss improved from -0.29343 to -0.29512, saving model to model_test_dice-80.h5
# Epoch 90/100
# 200/200 [==============================] - 4s 18ms/step - loss: -0.3334 - mean_absolute_error: 0.0118 - val_loss: -0.2932 - val_mean_absolute_error: 0.0110
#
# Epoch 00090: val_loss did not improve from -0.29512
# Epoch 91/100
# 200/200 [==============================] - 4s 18ms/step - loss: -0.3342 - mean_absolute_error: 0.0120 - val_loss: -0.2952 - val_mean_absolute_error: 0.0111
#
# Epoch 00091: val_loss improved from -0.29512 to -0.29523, saving model to model_test_dice-80.h5
# Epoch 92/100
# 200/200 [==============================] - 4s 18ms/step - loss: -0.3372 - mean_absolute_error: 0.0117 - val_loss: -0.2958 - val_mean_absolute_error: 0.0110
#
# Epoch 00092: val_loss improved from -0.29523 to -0.29583, saving model to model_test_dice-80.h5
# Epoch 93/100
# 200/200 [==============================] - 4s 18ms/step - loss: -0.3356 - mean_absolute_error: 0.0118 - val_loss: -0.2940 - val_mean_absolute_error: 0.0110
#
# Epoch 00093: val_loss did not improve from -0.29583
# Epoch 94/100
# 200/200 [==============================] - 4s 18ms/step - loss: -0.3385 - mean_absolute_error: 0.0117 - val_loss: -0.2981 - val_mean_absolute_error: 0.0112
#
# Epoch 00094: val_loss improved from -0.29583 to -0.29815, saving model to model_test_dice-80.h5
# Epoch 95/100
# 200/200 [==============================] - 4s 18ms/step - loss: -0.3388 - mean_absolute_error: 0.0116 - val_loss: -0.2979 - val_mean_absolute_error: 0.0115
#
# Epoch 00095: val_loss did not improve from -0.29815
# Epoch 96/100
# 200/200 [==============================] - 4s 18ms/step - loss: -0.3393 - mean_absolute_error: 0.0117 - val_loss: -0.2956 - val_mean_absolute_error: 0.0110
#
# Epoch 00096: val_loss did not improve from -0.29815
# Epoch 97/100
# 200/200 [==============================] - 4s 18ms/step - loss: -0.3426 - mean_absolute_error: 0.0115 - val_loss: -0.2969 - val_mean_absolute_error: 0.0116
#
# Epoch 00097: val_loss did not improve from -0.29815
# Epoch 98/100
# 200/200 [==============================] - 4s 18ms/step - loss: -0.3416 - mean_absolute_error: 0.0116 - val_loss: -0.2964 - val_mean_absolute_error: 0.0112
#
# Epoch 00098: val_loss did not improve from -0.29815
# Epoch 99/100
# 200/200 [==============================] - 4s 18ms/step - loss: -0.3382 - mean_absolute_error: 0.0114 - val_loss: -0.2977 - val_mean_absolute_error: 0.0114
#
# Epoch 00099: val_loss did not improve from -0.29815
# Epoch 100/100
# 200/200 [==============================] - 4s 18ms/step - loss: -0.3429 - mean_absolute_error: 0.0115 - val_loss: -0.2952 - val_mean_absolute_error: 0.0114
#
# Epoch 00100: val_loss did not improve from -0.29815

# %% [markdown]
# ## name = 'model_test_dice-80.h5'

# %%
#meme poids
plt.figure(figsize=(8, 8))
plt.title("Learning curve")
plt.plot(results.history["loss"], label="loss")
plt.plot(results.history["val_loss"], label="val_loss")
plt.plot( np.argmin(results.history["val_loss"]), np.min(results.history["val_loss"]), marker="x", color="r", label="best model")
plt.xlabel("Epochs")
plt.ylabel("log_loss")
plt.legend();

# %% [markdown]
# # evaluation

# %%
model.load_weights(name)

# %%
name
# Out:
# 'model_test_dice-80.h5'

# %%
id = 180
test = imgs_train[id,:,:,:]
test -= mean
test /= std
y_pred = model.predict(test.reshape(1,256,256,1))

# %% [markdown]
# # results

# %%
plt.figure(figsize=(20, 15))

for i in range(4):
    plt.subplot(1,4,i+1)
    plt.imshow(imgs_train[id,:,:,0])
    slice_ = y_pred[0,:,:,i]
    print(slice_.min(), slice_.max())
    plt.imshow(slice_,vmin = slice_.min(), vmax= slice_.max(),cmap='jet', alpha=0.5)
plt.show()
# Out:
# 2.3094259e-07 0.52212054
# 2.2894564e-10 0.45021996
# 5.1491753e-07 0.4705276
# 2.199451e-08 0.4783751

# %% [markdown]
# # real

# %%
plt.figure(figsize=(20, 15))
for i in range(4):
    plt.subplot(1,4,i+1)
    slice_ = imgs_mask_train[id,:,:,i]
    plt.imshow(imgs_train[id,:,:,0])
    plt.imshow(slice_, cmap='jet', alpha=0.5)    
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# # image test

# %%
imgs_test = load_test_data()
imgs_test -= mean
imgs_test /= std

# %%
mask_predicts = model.predict(imgs_test)

# %%
idx = 10
plt.figure(figsize=(20, 15))
for i in range(4):
    plt.subplot(1,4,i+1)
    plt.imshow(imgs_test[idx,:,:,0])
    slice_ = mask_predicts[idx,:,:,i]
    plt.imshow(slice_,vmin = slice_.min(), vmax= slice_.max(),cmap='jet', alpha=0.5)
plt.show()

# %%
idx = 20
plt.figure(figsize=(20, 15))
for i in range(4):
    plt.subplot(1,4,i+1)
    plt.imshow(imgs_test[idx,:,:,0])
    slice_ = mask_predicts[idx,:,:,i]
    plt.imshow(slice_,vmin = slice_.min(), vmax= slice_.max(),cmap='jet', alpha=0.5)
plt.show()
