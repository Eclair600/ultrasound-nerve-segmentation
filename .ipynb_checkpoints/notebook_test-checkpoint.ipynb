# %%
import numpy as np
import matplotlib.pyplot as plt
from skimage.transform import resize # from scipy.misc import imresize
from tqdm import tqdm
import nibabel

# %%
def read_train_exam(exam_nb):
    image = nibabel.load('../chaos/train/%02d-T2SPIR-src.nii.gz'%(exam_nb))
    mask = nibabel.load('../chaos/train/%02d-T2SPIR-mask.nii.gz'%(exam_nb))
    return image, mask

def read_test_exam(exam_nb):
    image = nibabel.load('../chaos/test/%02d-T2SPIR-src.nii.gz'%(exam_nb))
    return image

# %%
img_rows,img_cols = 256,256
def preprocess(image):
    #shape (slide,256,256)
    image_ = np.ndarray((image.shape[2],img_rows,img_cols,1))
    for i in range(image.shape[2]):
        image_[i,:,:,0] = resize(image.get_data()[:,:,i],(img_rows,img_cols),mode='reflect',preserve_range=True,
                               anti_aliasing=True)            
    #print(image_.shape)
    return image_

# %%
image_1, mask_1 = read_train_exam(2)

# %%
print("before scale {},{},".format(np.unique(mask_1.get_data()),np.unique(image_1.get_data())))
# Out:
# before scale [0 1 2 3 4],[   0    1    2 ... 1474 1501 1503],

# %%
print("after scale {},{}".format(np.unique(preprocess(mask_1)),np.unique(preprocess(image_1))))
# Out:
# after scale [0.       0.015625 0.015625 ... 3.984375 3.984375 4.      ],[0.00000000e+00 1.56250000e-02 1.56250000e-02 ... 1.45790625e+03
#  1.46843750e+03 1.48428125e+03]

# %%
def mask_to_channels(mask,init,classes):
    #get mask for each class
    img = np.asarray([np.where(mask == i,1,0 ) for i in range(init,classes)])
    img = np.swapaxes(img,0,-1)#new shape (row,col,class)
    print(img.shape)
    return img

# %%
test = mask_1.get_data()[:,:,15]
img = mask_to_channels(test,0,5)
for i in range(0,5):
    plt.subplot(1,5,i+1)
    plt.imshow(img[:,:,i])
plt.show()

# %%
def create_data_train(train_ids = [1,2,3,5,8,10,13,19],background = 0):
    for idx, train_id in tqdm(enumerate(train_ids)):
        image, mask = read_train_exam(train_id)     
        image = preprocess(image)
        mask = preprocess(mask) 
        #transform le mask
        if background:
            #create mask for 5 classess
            mask = mask_to_channels(mask,0,5)[0]
        else:
            mask = mask_to_channels(mask,1,5)[0]            
       
        if idx > 0:
            train_data = np.concatenate((train_data, image),axis=0)
            train_mask = np.concatenate((train_mask, mask),axis=0)
        else:
            train_data = image
            train_mask = mask
    print("Final shape {},{}".format(train_data.shape,train_mask.shape))    
    np.savez_compressed('./dataset/imgs_train_{}'.format(background), imgs=train_data)
    np.savez_compressed('./dataset/imgs_mask_train_{}'.format(background), imgs_mask=train_mask)

# %%
#dataset training without background
create_data_train()
# Out:
# 1it [00:00,  3.35it/s]
# (1, 36, 256, 256, 4)
# 2it [00:00,  3.18it/s]
# (1, 26, 256, 256, 4)
# 3it [00:01,  2.44it/s]
# (1, 30, 256, 256, 4)
# 4it [00:01,  2.46it/s]
# (1, 30, 256, 256, 4)
# 5it [00:02,  2.29it/s]
# (1, 32, 256, 256, 4)
# (1, 36, 256, 256, 4)
# 6it [00:02,  2.14it/s]
# (1, 30, 256, 256, 4)
# 7it [00:03,  1.94it/s]
# (1, 30, 256, 256, 4)
# 8it [00:04,  1.71it/s]
# Final shape (250, 256, 256, 1),(250, 256, 256, 4)

# %%
#dataset training without background
create_data_train(background=1)
# Out:
# 1it [00:00,  3.06it/s]
# (1, 36, 256, 256, 5)
# 2it [00:00,  2.92it/s]
# (1, 26, 256, 256, 5)
# 3it [00:01,  2.61it/s]
# (1, 30, 256, 256, 5)
# 4it [00:01,  2.50it/s]
# (1, 30, 256, 256, 5)
# (1, 32, 256, 256, 5)
# 5it [00:02,  2.23it/s]
# (1, 36, 256, 256, 5)
# 6it [00:02,  2.03it/s]
# (1, 30, 256, 256, 5)
# 7it [00:03,  1.84it/s]
# (1, 30, 256, 256, 5)
# 8it [00:04,  1.68it/s]
# Final shape (250, 256, 256, 1),(250, 256, 256, 5)

# %% [markdown]
# ### plot images

# %%
img = np.load('./dataset/imgs_train_0.npz')['imgs']
img_mask = np.load('./dataset/imgs_mask_train_0.npz')['imgs_mask']

# %%
img[:,:,:].shape
# Out:
# (250, 256, 256, 1)

# %%
img[:,:,:,0].shape
# Out:
# (250, 256, 256)

# %%
#plot random samples from data
def plot_random_images(data,mask,size,id):
    index = np.random.choice(range(data.shape[0]),size)
    plt.figure(figsize=(20, 15))
    for i,x in enumerate(index):
        plt.subplot(1, len(index), i+1)
        plt.imshow(data[x,:,:,0], cmap='gray', interpolation='nearest')
        plt.imshow(mask[x,:,:,id], cmap='jet', alpha=0.5)
    plt.show()

# %%
#plot random samples from training data
print("Training data")
plot_random_images(img,img_mask,5,1)
# Out:
# Training data

# %%
plot_random_images(img,img_mask,5,3)

# %%
print(np.unique(img))
# Out:
# [0.00000000e+00 1.00974196e-28 1.51461294e-28 ... 2.02000000e+03
#  2.04100000e+03 2.04300000e+03]

# %%
imgs_train = img.astype('float32')
mean = np.mean(imgs_train)  # mean for data centering
std = np.std(imgs_train)  # std for data normalization

imgs_train -= mean
imgs_train /= std

# %%
print(np.unique(imgs_train))
# Out:
# [-0.53052306 -0.53049946 -0.53047585 ... 11.664149   11.790925
#  11.8029995 ]

# %% [markdown]
# ### test

# %%
def get_data_test(test_ids = [21,22,32,39]):
    for idx, test_id in tqdm(enumerate(test_ids)):
        image = read_test_exam(test_id)     
        image = preprocess(image)
        print("img {}".format(image.shape))
        if idx > 0:
            test_data = np.concatenate((test_data, image),axis=0)
        else:
            test_data = image
    print("Final shape {}".format(test_data.shape))    
    np.savez_compressed('./dataset/imgs_test', imgs=test_data)

# %%
get_data_test()
# Out:
# 2it [00:00,  8.78it/s]
# img (31, 256, 256, 1)
# img (33, 256, 256, 1)
# 4it [00:00,  8.10it/s]
# img (39, 256, 256, 1)
# img (26, 256, 256, 1)
# Final shape (129, 256, 256, 1)

# %% [markdown]
# # MODEL

# %%
#version tf1
from keras.models import Model
from keras.layers import Input, concatenate, Activation,Conv2D, MaxPooling2D, Conv2DTranspose,BatchNormalization,Dropout
from keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint
from keras import backend as K


from data import load_train_data, load_test_data

K.set_image_data_format('channels_last')  # TF dimension ordering in this code

# %%
img_rows = 256
img_cols = 256

# %%
smooth = 1.
#batch 32!
def dice_coef_(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)
def dice_coef(y_true, y_pred):
    dice_liver = dice_coef_(y_true[0,:,:,0],y_pred[0,:,:,0])
    dice_rkidney = dice_coef_(y_true[0,:,:,1], y_pred[0,:,:,1])
    dice_lkidney = dice_coef_(y_true[0,:,:,2], y_pred[0,:,:,2])
    dice_spleen = dice_coef_(y_true[0,:,:,3], y_pred[0,:,:,3])
    #return dice_liver + (dice_rkidney+dice_lkidney)+dice_spleen
    return dice_liver + 10*dice_rkidney + 10*dice_lkidney +5*dice_spleen
def dice_coef_loss(y_true, y_pred):  
    return -dice_coef_(y_true, y_pred)

# %%
def get_unet():
    inputs = Input((img_rows, img_cols, 1))
    conv1 = Conv2D(32, (3, 3), activation='relu', padding='same')(inputs)
    conv1 = Conv2D(32, (3, 3), activation='relu', padding='same')(conv1)
    pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)

    conv2 = Conv2D(64, (3, 3), activation='relu', padding='same')(pool1)
    conv2 = Conv2D(64, (3, 3), activation='relu', padding='same')(conv2)
    pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)

    conv3 = Conv2D(128, (3, 3), activation='relu', padding='same')(pool2)
    conv3 = Conv2D(128, (3, 3), activation='relu', padding='same')(conv3)
    pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)

    conv4 = Conv2D(256, (3, 3), activation='relu', padding='same')(pool3)
    conv4 = Conv2D(256, (3, 3), activation='relu', padding='same')(conv4)
    pool4 = MaxPooling2D(pool_size=(2, 2))(conv4)

    conv5 = Conv2D(512, (3, 3), activation='relu', padding='same')(pool4)
    conv5 = Conv2D(512, (3, 3), activation='relu', padding='same')(conv5)

    up6 = concatenate([Conv2DTranspose(256, (2, 2), strides=(2, 2), padding='same')(conv5), conv4], axis=3)
    conv6 = Conv2D(256, (3, 3), activation='relu', padding='same')(up6)
    conv6 = Conv2D(256, (3, 3), activation='relu', padding='same')(conv6)

    up7 = concatenate([Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same')(conv6), conv3], axis=3)
    conv7 = Conv2D(128, (3, 3), activation='relu', padding='same')(up7)
    conv7 = Conv2D(128, (3, 3), activation='relu', padding='same')(conv7)

    up8 = concatenate([Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(conv7), conv2], axis=3)
    conv8 = Conv2D(64, (3, 3), activation='relu', padding='same')(up8)
    conv8 = Conv2D(64, (3, 3), activation='relu', padding='same')(conv8)

    up9 = concatenate([Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same')(conv8), conv1], axis=3)
    conv9 = Conv2D(32, (3, 3), activation='relu', padding='same')(up9)
    conv9 = Conv2D(32, (3, 3), activation='relu', padding='same')(conv9)
    conv9 = Conv2D(4, (3,3), activation='relu', padding='same')(conv9)
    
    conv10 = Conv2D(4, (1,1), activation='softmax')(conv9)
    loss_function = 'categorical_crossentropy'
    model = Model(inputs=[inputs], outputs=[conv10])
    model.compile(optimizer=Adam(lr=1e-4), loss=loss_function, metrics=[dice_coef_])
    model.summary()
    return model

# %%
from data import load_train_data, load_test_data

# %% [markdown]
# # training

# %%
print('Loading and preprocessing train data...')
print('-'*30)
imgs_train, imgs_mask_train = load_train_data()
name = 'model_softmax.h5'

checkpoint = ModelCheckpoint(name, verbose=1, save_best_only=True, save_weights_only=True)
model = get_unet()

imgs_train = imgs_train.astype('float32')
mean = np.mean(imgs_train)  # mean for data centering
std = np.std(imgs_train)  # std for data normalization
imgs_train -= mean
imgs_train /= std
print("normalize")
np.savez_compressed('scaler',mean=mean,std=std)

results = model.fit(imgs_train, imgs_mask_train, batch_size=32, epochs=100, callbacks=[checkpoint]
                   ,shuffle=True,
              validation_split=0.2)
# Out:
# Loading and preprocessing train data...
# ------------------------------
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 256, 256, 1)  0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 256, 256, 32) 320         input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 256, 256, 32) 9248        conv2d_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 128, 128, 32) 0           conv2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 128, 128, 64) 18496       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 128, 128, 64) 36928       conv2d_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 64, 64, 64)   0           conv2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 64, 64, 128)  73856       max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 64, 64, 128)  147584      conv2d_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 32, 32, 128)  0           conv2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 32, 32, 256)  295168      max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 32, 32, 256)  590080      conv2d_7[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 16, 16, 256)  0           conv2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 16, 16, 512)  1180160     max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 16, 16, 512)  2359808     conv2d_9[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 32, 32, 256)  524544      conv2d_10[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 32, 32, 512)  0           conv2d_transpose_1[0][0]
#                                                                  conv2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 32, 32, 256)  1179904     concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 32, 32, 256)  590080      conv2d_11[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 64, 64, 128)  131200      conv2d_12[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 64, 64, 256)  0           conv2d_transpose_2[0][0]
#                                                                  conv2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 64, 64, 128)  295040      concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 64, 64, 128)  147584      conv2d_13[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_3 (Conv2DTrans (None, 128, 128, 64) 32832       conv2d_14[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 128, 128, 128 0           conv2d_transpose_3[0][0]
#                                                                  conv2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 128, 128, 64) 73792       concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 128, 128, 64) 36928       conv2d_15[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_4 (Conv2DTrans (None, 256, 256, 32) 8224        conv2d_16[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 256, 256, 64) 0           conv2d_transpose_4[0][0]
#                                                                  conv2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 256, 256, 32) 18464       concatenate_4[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 256, 256, 32) 9248        conv2d_17[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 256, 256, 4)  1156        conv2d_18[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 256, 256, 4)  20          conv2d_19[0][0]
# ==================================================================================================
# Total params: 7,760,664
# Trainable params: 7,760,664
# Non-trainable params: 0
# __________________________________________________________________________________________________
# normalize
# Train on 200 samples, validate on 50 samples
# Epoch 1/100
# 200/200 [==============================] - 26s 131ms/step - loss: 0.0635 - dice_coef_: 0.0223 - val_loss: 0.0587 - val_dice_coef_: 0.0214
#
# Epoch 00001: val_loss improved from inf to 0.05874, saving model to model_softmax.h5
# Epoch 2/100
# 200/200 [==============================] - 4s 19ms/step - loss: 0.0627 - dice_coef_: 0.0227 - val_loss: 0.0573 - val_dice_coef_: 0.0222
#
# Epoch 00002: val_loss improved from 0.05874 to 0.05725, saving model to model_softmax.h5
# Epoch 3/100
# 200/200 [==============================] - 4s 19ms/step - loss: 0.0614 - dice_coef_: 0.0235 - val_loss: 0.0548 - val_dice_coef_: 0.0238
#
# Epoch 00003: val_loss improved from 0.05725 to 0.05476, saving model to model_softmax.h5
# Epoch 4/100
# 200/200 [==============================] - 4s 19ms/step - loss: 0.0591 - dice_coef_: 0.0253 - val_loss: 0.0495 - val_dice_coef_: 0.0284
#
# Epoch 00004: val_loss improved from 0.05476 to 0.04954, saving model to model_softmax.h5
# Epoch 5/100
# 200/200 [==============================] - 4s 19ms/step - loss: 0.0568 - dice_coef_: 0.0308 - val_loss: 0.0445 - val_dice_coef_: 0.0373
#
# Epoch 00005: val_loss improved from 0.04954 to 0.04449, saving model to model_softmax.h5
# Epoch 6/100
# 200/200 [==============================] - 4s 19ms/step - loss: 0.0552 - dice_coef_: 0.0354 - val_loss: 0.0424 - val_dice_coef_: 0.0365
#
# Epoch 00006: val_loss improved from 0.04449 to 0.04241, saving model to model_softmax.h5
# Epoch 7/100
# 200/200 [==============================] - 4s 19ms/step - loss: 0.0505 - dice_coef_: 0.0374 - val_loss: 0.0309 - val_dice_coef_: 0.0541
#
# Epoch 00007: val_loss improved from 0.04241 to 0.03095, saving model to model_softmax.h5
# Epoch 8/100
# 200/200 [==============================] - 4s 19ms/step - loss: 0.0431 - dice_coef_: 0.0459 - val_loss: 0.0226 - val_dice_coef_: 0.0578
#
# Epoch 00008: val_loss improved from 0.03095 to 0.02257, saving model to model_softmax.h5
# Epoch 9/100
# 200/200 [==============================] - 4s 19ms/step - loss: 0.0335 - dice_coef_: 0.0539 - val_loss: 0.0163 - val_dice_coef_: 0.0670
#
# Epoch 00009: val_loss improved from 0.02257 to 0.01633, saving model to model_softmax.h5
# Epoch 10/100
# 200/200 [==============================] - 4s 19ms/step - loss: 0.0279 - dice_coef_: 0.0611 - val_loss: 0.0155 - val_dice_coef_: 0.0663
#
# Epoch 00010: val_loss improved from 0.01633 to 0.01553, saving model to model_softmax.h5
# Epoch 11/100
# 200/200 [==============================] - 4s 19ms/step - loss: 0.0244 - dice_coef_: 0.0640 - val_loss: 0.0156 - val_dice_coef_: 0.0662
#
# Epoch 00011: val_loss did not improve from 0.01553
# Epoch 12/100
# 200/200 [==============================] - 4s 19ms/step - loss: 0.0230 - dice_coef_: 0.0659 - val_loss: 0.0152 - val_dice_coef_: 0.0665
#
# Epoch 00012: val_loss improved from 0.01553 to 0.01522, saving model to model_softmax.h5
# Epoch 13/100
# 200/200 [==============================] - 4s 19ms/step - loss: 0.0228 - dice_coef_: 0.0657 - val_loss: 0.0138 - val_dice_coef_: 0.0682
#
# Epoch 00013: val_loss improved from 0.01522 to 0.01384, saving model to model_softmax.h5
# Epoch 14/100
# 200/200 [==============================] - 4s 19ms/step - loss: 0.0217 - dice_coef_: 0.0665 - val_loss: 0.0135 - val_dice_coef_: 0.0685
#
# Epoch 00014: val_loss improved from 0.01384 to 0.01352, saving model to model_softmax.h5
# Epoch 15/100
# 200/200 [==============================] - 4s 19ms/step - loss: 0.0212 - dice_coef_: 0.0667 - val_loss: 0.0131 - val_dice_coef_: 0.0692
#
# Epoch 00015: val_loss improved from 0.01352 to 0.01313, saving model to model_softmax.h5
# Epoch 16/100
# 200/200 [==============================] - 4s 20ms/step - loss: 0.0208 - dice_coef_: 0.0672 - val_loss: 0.0133 - val_dice_coef_: 0.0689
#
# Epoch 00016: val_loss did not improve from 0.01313
# Epoch 17/100
# 200/200 [==============================] - 4s 19ms/step - loss: 0.0204 - dice_coef_: 0.0676 - val_loss: 0.0131 - val_dice_coef_: 0.0692
#
# Epoch 00017: val_loss improved from 0.01313 to 0.01307, saving model to model_softmax.h5
# Epoch 18/100
# 200/200 [==============================] - 4s 19ms/step - loss: 0.0202 - dice_coef_: 0.0677 - val_loss: 0.0128 - val_dice_coef_: 0.0699
#
# Epoch 00018: val_loss improved from 0.01307 to 0.01284, saving model to model_softmax.h5
# Epoch 19/100
# 200/200 [==============================] - 4s 20ms/step - loss: 0.0203 - dice_coef_: 0.0675 - val_loss: 0.0127 - val_dice_coef_: 0.0698
#
# Epoch 00019: val_loss improved from 0.01284 to 0.01269, saving model to model_softmax.h5
# Epoch 20/100
# 200/200 [==============================] - 4s 19ms/step - loss: 0.0199 - dice_coef_: 0.0680 - val_loss: 0.0127 - val_dice_coef_: 0.0699
#
# Epoch 00020: val_loss improved from 0.01269 to 0.01267, saving model to model_softmax.h5
# Epoch 21/100
# 200/200 [==============================] - 4s 20ms/step - loss: 0.0198 - dice_coef_: 0.0683 - val_loss: 0.0127 - val_dice_coef_: 0.0696
#
# Epoch 00021: val_loss did not improve from 0.01267
# Epoch 22/100
# 200/200 [==============================] - 4s 20ms/step - loss: 0.0196 - dice_coef_: 0.0683 - val_loss: 0.0126 - val_dice_coef_: 0.0699
#
# Epoch 00022: val_loss improved from 0.01267 to 0.01260, saving model to model_softmax.h5
# Epoch 23/100
# 200/200 [==============================] - 4s 19ms/step - loss: 0.0194 - dice_coef_: 0.0684 - val_loss: 0.0128 - val_dice_coef_: 0.0693
#
# Epoch 00023: val_loss did not improve from 0.01260
# Epoch 24/100
# 200/200 [==============================] - 4s 19ms/step - loss: 0.0193 - dice_coef_: 0.0685 - val_loss: 0.0146 - val_dice_coef_: 0.0669
#
# Epoch 00024: val_loss did not improve from 0.01260
# Epoch 25/100
# 200/200 [==============================] - 4s 19ms/step - loss: 0.0198 - dice_coef_: 0.0680 - val_loss: 0.0125 - val_dice_coef_: 0.0698
#
# Epoch 00025: val_loss improved from 0.01260 to 0.01252, saving model to model_softmax.h5
# Epoch 26/100
# 200/200 [==============================] - 4s 19ms/step - loss: 0.0199 - dice_coef_: 0.0683 - val_loss: 0.0130 - val_dice_coef_: 0.0690
#
# Epoch 00026: val_loss did not improve from 0.01252
# Epoch 27/100
# 200/200 [==============================] - 4s 19ms/step - loss: 0.0195 - dice_coef_: 0.0686 - val_loss: 0.0130 - val_dice_coef_: 0.0689
#
# Epoch 00027: val_loss did not improve from 0.01252
# Epoch 28/100
# 200/200 [==============================] - 4s 19ms/step - loss: 0.0190 - dice_coef_: 0.0687 - val_loss: 0.0124 - val_dice_coef_: 0.0701
#
# Epoch 00028: val_loss improved from 0.01252 to 0.01244, saving model to model_softmax.h5
# Epoch 29/100
# 200/200 [==============================] - 4s 20ms/step - loss: 0.0189 - dice_coef_: 0.0693 - val_loss: 0.0124 - val_dice_coef_: 0.0700
#
# Epoch 00029: val_loss improved from 0.01244 to 0.01238, saving model to model_softmax.h5
# Epoch 30/100
# 200/200 [==============================] - 4s 20ms/step - loss: 0.0186 - dice_coef_: 0.0690 - val_loss: 0.0124 - val_dice_coef_: 0.0697
#
# Epoch 00030: val_loss improved from 0.01238 to 0.01236, saving model to model_softmax.h5
# Epoch 31/100
# 200/200 [==============================] - 4s 20ms/step - loss: 0.0183 - dice_coef_: 0.0689 - val_loss: 0.0121 - val_dice_coef_: 0.0704
#
# Epoch 00031: val_loss improved from 0.01236 to 0.01206, saving model to model_softmax.h5
# Epoch 32/100
# 200/200 [==============================] - 4s 20ms/step - loss: 0.0180 - dice_coef_: 0.0698 - val_loss: 0.0124 - val_dice_coef_: 0.0698
#
# Epoch 00032: val_loss did not improve from 0.01206
# Epoch 33/100
# 200/200 [==============================] - 4s 19ms/step - loss: 0.0174 - dice_coef_: 0.0706 - val_loss: 0.0132 - val_dice_coef_: 0.0690
#
# Epoch 00033: val_loss did not improve from 0.01206
# Epoch 34/100
# 200/200 [==============================] - 4s 20ms/step - loss: 0.0169 - dice_coef_: 0.0710 - val_loss: 0.0117 - val_dice_coef_: 0.0706
#
# Epoch 00034: val_loss improved from 0.01206 to 0.01167, saving model to model_softmax.h5
# Epoch 35/100
# 200/200 [==============================] - 4s 20ms/step - loss: 0.0165 - dice_coef_: 0.0708 - val_loss: 0.0120 - val_dice_coef_: 0.0714
#
# Epoch 00035: val_loss did not improve from 0.01167
# Epoch 36/100
# 200/200 [==============================] - 4s 19ms/step - loss: 0.0154 - dice_coef_: 0.0730 - val_loss: 0.0125 - val_dice_coef_: 0.0693
#
# Epoch 00036: val_loss did not improve from 0.01167
# Epoch 37/100
# 200/200 [==============================] - 4s 19ms/step - loss: 0.0148 - dice_coef_: 0.0730 - val_loss: 0.0114 - val_dice_coef_: 0.0717
#
# Epoch 00037: val_loss improved from 0.01167 to 0.01142, saving model to model_softmax.h5
# Epoch 38/100
# 200/200 [==============================] - 4s 19ms/step - loss: 0.0138 - dice_coef_: 0.0738 - val_loss: 0.0193 - val_dice_coef_: 0.0720
#
# Epoch 00038: val_loss did not improve from 0.01142
# Epoch 39/100
# 200/200 [==============================] - 4s 19ms/step - loss: 0.0188 - dice_coef_: 0.0699 - val_loss: 0.0107 - val_dice_coef_: 0.0717
#
# Epoch 00039: val_loss improved from 0.01142 to 0.01067, saving model to model_softmax.h5
# Epoch 40/100
# 200/200 [==============================] - 4s 20ms/step - loss: 0.0148 - dice_coef_: 0.0740 - val_loss: 0.0113 - val_dice_coef_: 0.0706
#
# Epoch 00040: val_loss did not improve from 0.01067
# Epoch 41/100
# 200/200 [==============================] - 4s 20ms/step - loss: 0.0140 - dice_coef_: 0.0735 - val_loss: 0.0104 - val_dice_coef_: 0.0721
#
# Epoch 00041: val_loss improved from 0.01067 to 0.01040, saving model to model_softmax.h5
# Epoch 42/100
# 200/200 [==============================] - 4s 20ms/step - loss: 0.0138 - dice_coef_: 0.0740 - val_loss: 0.0108 - val_dice_coef_: 0.0724
#
# Epoch 00042: val_loss did not improve from 0.01040
# Epoch 43/100
# 200/200 [==============================] - 4s 20ms/step - loss: 0.0131 - dice_coef_: 0.0748 - val_loss: 0.0093 - val_dice_coef_: 0.0735
#
# Epoch 00043: val_loss improved from 0.01040 to 0.00934, saving model to model_softmax.h5
# Epoch 44/100
# 200/200 [==============================] - 4s 20ms/step - loss: 0.0127 - dice_coef_: 0.0749 - val_loss: 0.0102 - val_dice_coef_: 0.0734
#
# Epoch 00044: val_loss did not improve from 0.00934
# Epoch 45/100
# 200/200 [==============================] - 4s 19ms/step - loss: 0.0125 - dice_coef_: 0.0754 - val_loss: 0.0119 - val_dice_coef_: 0.0739
#
# Epoch 00045: val_loss did not improve from 0.00934
# Epoch 46/100
# 200/200 [==============================] - 4s 20ms/step - loss: 0.0129 - dice_coef_: 0.0750 - val_loss: 0.0171 - val_dice_coef_: 0.0725
#
# Epoch 00046: val_loss did not improve from 0.00934
# Epoch 47/100
# 200/200 [==============================] - 4s 20ms/step - loss: 0.0147 - dice_coef_: 0.0736 - val_loss: 0.0090 - val_dice_coef_: 0.0731
#
# Epoch 00047: val_loss improved from 0.00934 to 0.00897, saving model to model_softmax.h5
# Epoch 48/100
# 200/200 [==============================] - 4s 20ms/step - loss: 0.0132 - dice_coef_: 0.0748 - val_loss: 0.0095 - val_dice_coef_: 0.0728
#
# Epoch 00048: val_loss did not improve from 0.00897
# Epoch 49/100
# 200/200 [==============================] - 4s 20ms/step - loss: 0.0127 - dice_coef_: 0.0750 - val_loss: 0.0113 - val_dice_coef_: 0.0735
#
# Epoch 00049: val_loss did not improve from 0.00897
# Epoch 50/100
# 200/200 [==============================] - 4s 20ms/step - loss: 0.0126 - dice_coef_: 0.0752 - val_loss: 0.0085 - val_dice_coef_: 0.0739
#
# Epoch 00050: val_loss improved from 0.00897 to 0.00845, saving model to model_softmax.h5
# Epoch 51/100
# 200/200 [==============================] - 4s 20ms/step - loss: 0.0125 - dice_coef_: 0.0755 - val_loss: 0.0085 - val_dice_coef_: 0.0737
#
# Epoch 00051: val_loss did not improve from 0.00845
# Epoch 52/100
# 200/200 [==============================] - 4s 20ms/step - loss: 0.0124 - dice_coef_: 0.0754 - val_loss: 0.0084 - val_dice_coef_: 0.0743
#
# Epoch 00052: val_loss improved from 0.00845 to 0.00844, saving model to model_softmax.h5
# Epoch 53/100
# 200/200 [==============================] - 4s 20ms/step - loss: 0.0121 - dice_coef_: 0.0758 - val_loss: 0.0083 - val_dice_coef_: 0.0739
#
# Epoch 00053: val_loss improved from 0.00844 to 0.00835, saving model to model_softmax.h5
# Epoch 54/100
# 200/200 [==============================] - 4s 20ms/step - loss: 0.0120 - dice_coef_: 0.0758 - val_loss: 0.0083 - val_dice_coef_: 0.0745
#
# Epoch 00054: val_loss improved from 0.00835 to 0.00828, saving model to model_softmax.h5
# Epoch 55/100
# 200/200 [==============================] - 4s 20ms/step - loss: 0.0118 - dice_coef_: 0.0761 - val_loss: 0.0083 - val_dice_coef_: 0.0741
#
# Epoch 00055: val_loss did not improve from 0.00828
# Epoch 56/100
# 200/200 [==============================] - 4s 20ms/step - loss: 0.0117 - dice_coef_: 0.0761 - val_loss: 0.0083 - val_dice_coef_: 0.0745
#
# Epoch 00056: val_loss did not improve from 0.00828
# Epoch 57/100
# 200/200 [==============================] - 4s 20ms/step - loss: 0.0117 - dice_coef_: 0.0759 - val_loss: 0.0081 - val_dice_coef_: 0.0747
#
# Epoch 00057: val_loss improved from 0.00828 to 0.00815, saving model to model_softmax.h5
# Epoch 58/100
# 200/200 [==============================] - 4s 19ms/step - loss: 0.0116 - dice_coef_: 0.0762 - val_loss: 0.0088 - val_dice_coef_: 0.0737
#
# Epoch 00058: val_loss did not improve from 0.00815
# Epoch 59/100
# 200/200 [==============================] - 4s 20ms/step - loss: 0.0116 - dice_coef_: 0.0762 - val_loss: 0.0083 - val_dice_coef_: 0.0747
#
# Epoch 00059: val_loss did not improve from 0.00815
# Epoch 60/100
# 200/200 [==============================] - 4s 20ms/step - loss: 0.0117 - dice_coef_: 0.0761 - val_loss: 0.0082 - val_dice_coef_: 0.0746
#
# Epoch 00060: val_loss did not improve from 0.00815
# Epoch 61/100
# 200/200 [==============================] - 4s 20ms/step - loss: 0.0115 - dice_coef_: 0.0764 - val_loss: 0.0086 - val_dice_coef_: 0.0742
#
# Epoch 00061: val_loss did not improve from 0.00815
# Epoch 62/100
# 200/200 [==============================] - 4s 20ms/step - loss: 0.0114 - dice_coef_: 0.0763 - val_loss: 0.0083 - val_dice_coef_: 0.0750
#
# Epoch 00062: val_loss did not improve from 0.00815
# Epoch 63/100
# 200/200 [==============================] - 4s 19ms/step - loss: 0.0114 - dice_coef_: 0.0765 - val_loss: 0.0086 - val_dice_coef_: 0.0741
#
# Epoch 00063: val_loss did not improve from 0.00815
# Epoch 64/100
# 200/200 [==============================] - 4s 20ms/step - loss: 0.0114 - dice_coef_: 0.0763 - val_loss: 0.0086 - val_dice_coef_: 0.0750
#
# Epoch 00064: val_loss did not improve from 0.00815
# Epoch 65/100
# 200/200 [==============================] - 4s 19ms/step - loss: 0.0114 - dice_coef_: 0.0765 - val_loss: 0.0084 - val_dice_coef_: 0.0741
#
# Epoch 00065: val_loss did not improve from 0.00815
# Epoch 66/100
# 200/200 [==============================] - 4s 20ms/step - loss: 0.0113 - dice_coef_: 0.0764 - val_loss: 0.0102 - val_dice_coef_: 0.0750
#
# Epoch 00066: val_loss did not improve from 0.00815
# Epoch 67/100
# 200/200 [==============================] - 4s 20ms/step - loss: 0.0113 - dice_coef_: 0.0764 - val_loss: 0.0082 - val_dice_coef_: 0.0741
#
# Epoch 00067: val_loss did not improve from 0.00815
# Epoch 68/100
# 200/200 [==============================] - 4s 20ms/step - loss: 0.0113 - dice_coef_: 0.0764 - val_loss: 0.0090 - val_dice_coef_: 0.0751
#
# Epoch 00068: val_loss did not improve from 0.00815
# Epoch 69/100
# 200/200 [==============================] - 4s 20ms/step - loss: 0.0113 - dice_coef_: 0.0765 - val_loss: 0.0081 - val_dice_coef_: 0.0746
#
# Epoch 00069: val_loss improved from 0.00815 to 0.00808, saving model to model_softmax.h5
# Epoch 70/100
# 200/200 [==============================] - 4s 20ms/step - loss: 0.0112 - dice_coef_: 0.0764 - val_loss: 0.0085 - val_dice_coef_: 0.0749
#
# Epoch 00070: val_loss did not improve from 0.00808
# Epoch 71/100
# 200/200 [==============================] - 4s 19ms/step - loss: 0.0112 - dice_coef_: 0.0765 - val_loss: 0.0087 - val_dice_coef_: 0.0747
#
# Epoch 00071: val_loss did not improve from 0.00808
# Epoch 72/100
# 200/200 [==============================] - 4s 20ms/step - loss: 0.0112 - dice_coef_: 0.0765 - val_loss: 0.0083 - val_dice_coef_: 0.0747
#
# Epoch 00072: val_loss did not improve from 0.00808
# Epoch 73/100
# 200/200 [==============================] - 4s 20ms/step - loss: 0.0111 - dice_coef_: 0.0766 - val_loss: 0.0087 - val_dice_coef_: 0.0748
#
# Epoch 00073: val_loss did not improve from 0.00808
# Epoch 74/100
# 200/200 [==============================] - 4s 20ms/step - loss: 0.0111 - dice_coef_: 0.0766 - val_loss: 0.0084 - val_dice_coef_: 0.0748
#
# Epoch 00074: val_loss did not improve from 0.00808
# Epoch 75/100
# 200/200 [==============================] - 4s 20ms/step - loss: 0.0111 - dice_coef_: 0.0766 - val_loss: 0.0083 - val_dice_coef_: 0.0749
#
# Epoch 00075: val_loss did not improve from 0.00808
# Epoch 76/100
# 200/200 [==============================] - 4s 20ms/step - loss: 0.0111 - dice_coef_: 0.0766 - val_loss: 0.0082 - val_dice_coef_: 0.0750
#
# Epoch 00076: val_loss did not improve from 0.00808
# Epoch 77/100
# 200/200 [==============================] - 4s 20ms/step - loss: 0.0111 - dice_coef_: 0.0766 - val_loss: 0.0090 - val_dice_coef_: 0.0748
#
# Epoch 00077: val_loss did not improve from 0.00808
# Epoch 78/100
# 200/200 [==============================] - 4s 20ms/step - loss: 0.0110 - dice_coef_: 0.0766 - val_loss: 0.0083 - val_dice_coef_: 0.0749
#
# Epoch 00078: val_loss did not improve from 0.00808
# Epoch 79/100
# 200/200 [==============================] - 4s 20ms/step - loss: 0.0110 - dice_coef_: 0.0768 - val_loss: 0.0087 - val_dice_coef_: 0.0748
#
# Epoch 00079: val_loss did not improve from 0.00808
# Epoch 80/100
# 200/200 [==============================] - 4s 20ms/step - loss: 0.0110 - dice_coef_: 0.0767 - val_loss: 0.0083 - val_dice_coef_: 0.0749
#
# Epoch 00080: val_loss did not improve from 0.00808
# Epoch 81/100
# 200/200 [==============================] - 4s 20ms/step - loss: 0.0110 - dice_coef_: 0.0767 - val_loss: 0.0088 - val_dice_coef_: 0.0749
#
# Epoch 00081: val_loss did not improve from 0.00808
# Epoch 82/100
# 200/200 [==============================] - 4s 20ms/step - loss: 0.0110 - dice_coef_: 0.0768 - val_loss: 0.0086 - val_dice_coef_: 0.0748
#
# Epoch 00082: val_loss did not improve from 0.00808
# Epoch 83/100
# 200/200 [==============================] - 4s 19ms/step - loss: 0.0110 - dice_coef_: 0.0767 - val_loss: 0.0085 - val_dice_coef_: 0.0750
#
# Epoch 00083: val_loss did not improve from 0.00808
# Epoch 84/100
# 200/200 [==============================] - 4s 19ms/step - loss: 0.0110 - dice_coef_: 0.0766 - val_loss: 0.0085 - val_dice_coef_: 0.0748
#
# Epoch 00084: val_loss did not improve from 0.00808
# Epoch 85/100
# 200/200 [==============================] - 4s 19ms/step - loss: 0.0110 - dice_coef_: 0.0768 - val_loss: 0.0086 - val_dice_coef_: 0.0751
#
# Epoch 00085: val_loss did not improve from 0.00808
# Epoch 86/100
# 200/200 [==============================] - 4s 20ms/step - loss: 0.0110 - dice_coef_: 0.0767 - val_loss: 0.0083 - val_dice_coef_: 0.0748
#
# Epoch 00086: val_loss did not improve from 0.00808
# Epoch 87/100
# 200/200 [==============================] - 4s 20ms/step - loss: 0.0110 - dice_coef_: 0.0768 - val_loss: 0.0085 - val_dice_coef_: 0.0751
#
# Epoch 00087: val_loss did not improve from 0.00808
# Epoch 88/100
# 200/200 [==============================] - 4s 20ms/step - loss: 0.0110 - dice_coef_: 0.0768 - val_loss: 0.0084 - val_dice_coef_: 0.0748
#
# Epoch 00088: val_loss did not improve from 0.00808
# Epoch 89/100
# 200/200 [==============================] - 4s 20ms/step - loss: 0.0109 - dice_coef_: 0.0768 - val_loss: 0.0084 - val_dice_coef_: 0.0751
#
# Epoch 00089: val_loss did not improve from 0.00808
# Epoch 90/100
# 200/200 [==============================] - 4s 20ms/step - loss: 0.0109 - dice_coef_: 0.0768 - val_loss: 0.0087 - val_dice_coef_: 0.0750
#
# Epoch 00090: val_loss did not improve from 0.00808
# Epoch 91/100
# 200/200 [==============================] - 4s 20ms/step - loss: 0.0109 - dice_coef_: 0.0768 - val_loss: 0.0085 - val_dice_coef_: 0.0750
#
# Epoch 00091: val_loss did not improve from 0.00808
# Epoch 92/100
# 200/200 [==============================] - 4s 20ms/step - loss: 0.0109 - dice_coef_: 0.0767 - val_loss: 0.0089 - val_dice_coef_: 0.0750
#
# Epoch 00092: val_loss did not improve from 0.00808
# Epoch 93/100
# 200/200 [==============================] - 4s 20ms/step - loss: 0.0109 - dice_coef_: 0.0768 - val_loss: 0.0084 - val_dice_coef_: 0.0749
#
# Epoch 00093: val_loss did not improve from 0.00808
# Epoch 94/100
# 200/200 [==============================] - 4s 20ms/step - loss: 0.0109 - dice_coef_: 0.0767 - val_loss: 0.0086 - val_dice_coef_: 0.0751
#
# Epoch 00094: val_loss did not improve from 0.00808
# Epoch 95/100
# 200/200 [==============================] - 4s 20ms/step - loss: 0.0109 - dice_coef_: 0.0767 - val_loss: 0.0084 - val_dice_coef_: 0.0750
#
# Epoch 00095: val_loss did not improve from 0.00808
# Epoch 96/100
# 200/200 [==============================] - 4s 20ms/step - loss: 0.0109 - dice_coef_: 0.0766 - val_loss: 0.0084 - val_dice_coef_: 0.0751
#
# Epoch 00096: val_loss did not improve from 0.00808
# Epoch 97/100
# 200/200 [==============================] - 4s 19ms/step - loss: 0.0109 - dice_coef_: 0.0767 - val_loss: 0.0088 - val_dice_coef_: 0.0749
#
# Epoch 00097: val_loss did not improve from 0.00808
# Epoch 98/100
# 200/200 [==============================] - 4s 20ms/step - loss: 0.0109 - dice_coef_: 0.0768 - val_loss: 0.0089 - val_dice_coef_: 0.0748
#
# Epoch 00098: val_loss did not improve from 0.00808
# Epoch 99/100
# 200/200 [==============================] - 4s 20ms/step - loss: 0.0109 - dice_coef_: 0.0768 - val_loss: 0.0092 - val_dice_coef_: 0.0749
#
# Epoch 00099: val_loss did not improve from 0.00808
# Epoch 100/100
# 200/200 [==============================] - 4s 19ms/step - loss: 0.0109 - dice_coef_: 0.0768 - val_loss: 0.0088 - val_dice_coef_: 0.0749
#
# Epoch 00100: val_loss did not improve from 0.00808

# %% [markdown]
# ## name = 'model_softmax.h5'

# %%
plt.subplot(211)
plt.plot(results.history['loss'], label='train')
plt.plot(results.history['val_loss'], label='val')
plt.title('loss')
plt.legend()

plt.subplot(212)
plt.plot(results.history['dice_coef_'], label='train')
plt.plot(results.history['val_dice_coef_'], label='val')
plt.title('acc')
plt.legend()

# %% [markdown]
# # evaluation

# %%
name
# Out:
# 'model_softmax.h5'

# %%
imgs_train, imgs_mask_train = load_train_data()

# %%
model = get_unet()
model.load_weights(name)
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            (None, 256, 256, 1)  0
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 256, 256, 32) 320         input_3[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 256, 256, 32) 9248        conv2d_41[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_9 (MaxPooling2D)  (None, 128, 128, 32) 0           conv2d_42[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 128, 128, 64) 18496       max_pooling2d_9[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 128, 128, 64) 36928       conv2d_43[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_10 (MaxPooling2D) (None, 64, 64, 64)   0           conv2d_44[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 64, 64, 128)  73856       max_pooling2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 64, 64, 128)  147584      conv2d_45[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_11 (MaxPooling2D) (None, 32, 32, 128)  0           conv2d_46[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 32, 32, 256)  295168      max_pooling2d_11[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 32, 32, 256)  590080      conv2d_47[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_12 (MaxPooling2D) (None, 16, 16, 256)  0           conv2d_48[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, 16, 16, 512)  1180160     max_pooling2d_12[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, 16, 16, 512)  2359808     conv2d_49[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_9 (Conv2DTrans (None, 32, 32, 256)  524544      conv2d_50[0][0]
# __________________________________________________________________________________________________
# concatenate_9 (Concatenate)     (None, 32, 32, 512)  0           conv2d_transpose_9[0][0]
#                                                                  conv2d_48[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, 32, 32, 256)  1179904     concatenate_9[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, 32, 32, 256)  590080      conv2d_51[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_10 (Conv2DTran (None, 64, 64, 128)  131200      conv2d_52[0][0]
# __________________________________________________________________________________________________
# concatenate_10 (Concatenate)    (None, 64, 64, 256)  0           conv2d_transpose_10[0][0]
#                                                                  conv2d_46[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, 64, 64, 128)  295040      concatenate_10[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, 64, 64, 128)  147584      conv2d_53[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_11 (Conv2DTran (None, 128, 128, 64) 32832       conv2d_54[0][0]
# __________________________________________________________________________________________________
# concatenate_11 (Concatenate)    (None, 128, 128, 128 0           conv2d_transpose_11[0][0]
#                                                                  conv2d_44[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, 128, 128, 64) 73792       concatenate_11[0][0]
# __________________________________________________________________________________________________
# conv2d_56 (Conv2D)              (None, 128, 128, 64) 36928       conv2d_55[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_12 (Conv2DTran (None, 256, 256, 32) 8224        conv2d_56[0][0]
# __________________________________________________________________________________________________
# concatenate_12 (Concatenate)    (None, 256, 256, 64) 0           conv2d_transpose_12[0][0]
#                                                                  conv2d_42[0][0]
# __________________________________________________________________________________________________
# conv2d_57 (Conv2D)              (None, 256, 256, 32) 18464       concatenate_12[0][0]
# __________________________________________________________________________________________________
# conv2d_58 (Conv2D)              (None, 256, 256, 32) 9248        conv2d_57[0][0]
# __________________________________________________________________________________________________
# conv2d_59 (Conv2D)              (None, 256, 256, 4)  1156        conv2d_58[0][0]
# __________________________________________________________________________________________________
# conv2d_60 (Conv2D)              (None, 256, 256, 4)  20          conv2d_59[0][0]
# ==================================================================================================
# Total params: 7,760,664
# Trainable params: 7,760,664
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
id = 190


test = imgs_train[id,:,:,:]
test -= mean
test /= std
y_pred = model.predict(test.reshape(1,256,256,1))

# %% [markdown]
# # results

# %%
plt.figure(figsize=(20, 15))

for i in range(4):
    plt.subplot(1,4,i+1)
    plt.imshow(imgs_train[id,:,:,0])
    slice_ = y_pred[0,:,:,i]
    x = np.sum(y_pred, axis = 3)[0]
    print(slice_.min(), slice_.max())
    m = slice_.mean()
    plt.imshow(slice_,vmin=0,vmax=1, alpha=0.7)
plt.show()
# Out:
# 8.8219085e-06 1.0
# 2.7946756e-18 0.25867796
# 1.2664942e-21 0.25472263
# 2.0169212e-23 0.9999379

# %% [markdown]
# # real

# %%
plt.figure(figsize=(20, 15))
for i in range(4):
    plt.subplot(1,4,i+1)
    slice_ = imgs_mask_train[id,:,:,i]
    plt.imshow(imgs_train[id,:,:,0])
    plt.imshow(slice_, alpha=0.7)    
plt.show()

# %% [markdown]
# # image test

# %%
imgs_test = load_test_data()
imgs_test -= mean
imgs_test /= std

# %%
mask_predicts = model.predict(imgs_test)

# %%
idx = 10
plt.figure(figsize=(20, 15))
for i in range(4):
    plt.subplot(1,4,i+1)
    plt.imshow(imgs_test[idx,:,:,0])
    slice_ = mask_predicts[idx,:,:,i]
    plt.imshow(slice_,vmin = slice_.min(), vmax= slice_.max(),cmap='jet', alpha=0.5)
plt.show()

# %%
idx = 20
plt.figure(figsize=(20, 15))
for i in range(4):
    plt.subplot(1,4,i+1)
    plt.imshow(imgs_test[idx,:,:,0])
    slice_ = mask_predicts[idx,:,:,i]
    plt.imshow(slice_,vmin = slice_.min(), vmax= slice_.max(),cmap='jet', alpha=0.5)
plt.show()

# %% [markdown]
# =======
# # 2. dropout and pooling

# %% [markdown]
# https://github.com/hlamba28/UNET-TGS/blob/master/TGS%20UNET.ipynb

# %% [markdown]
# > of “training hard enough”.
#
# > When training a deep neural network, our biggest concern is nearly always overfitting — and in order to combat overfitting, we introduce regularization techniques (discussed in Reason #1 above). We apply regularization in the form of:
#
#     Dropout
#     L2 weight decay
#     Reducing model capacity (i.e., a more shallow model)
#
# >We also tend to be a bit more conservative with our learning rate to ensure our model doesn’t overshoot areas of lower loss in the loss landscape.

# %%
def get_unet_reg(dropout = 0.3):
    inputs = Input((img_rows, img_cols, 1))
    
    conv1 = Conv2D(32, (3, 3), activation='relu', padding='same')(inputs)
    conv1 = Conv2D(32, (3, 3), activation='relu', padding='same')(conv1)
    pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)
    pool1 = Dropout(dropout)(pool1)
    
    conv2 = Conv2D(64, (3, 3), activation='relu', padding='same')(pool1)
    conv2 = Conv2D(64, (3, 3), activation='relu', padding='same')(conv2)
    pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)
    pool2 = Dropout(dropout)(pool2)
    
    conv3 = Conv2D(128, (3, 3), activation='relu', padding='same')(pool2)
    conv3 = Conv2D(128, (3, 3), activation='relu', padding='same')(conv3)
    pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)
    pool3 = Dropout(dropout)(pool3)
    
    conv4 = Conv2D(256, (3, 3), activation='relu', padding='same')(pool3)
    conv4 = Conv2D(256, (3, 3), activation='relu', padding='same')(conv4)
    pool4 = MaxPooling2D(pool_size=(2, 2))(conv4)
    pool4 = Dropout(dropout)(pool4)
    
    conv5 = Conv2D(512, (3, 3), activation='relu', padding='same')(pool4)
    conv5 = Conv2D(512, (3, 3), activation='relu', padding='same')(conv5)
    up6 = concatenate([Conv2DTranspose(256, (2, 2), strides=(2, 2), padding='same')(conv5), conv4], axis=3)
    up6 = Dropout(dropout)(up6)

    conv6 = Conv2D(256, (3, 3), activation='relu', padding='same')(up6)
    conv6 = Conv2D(256, (3, 3), activation='relu', padding='same')(conv6)
    up7 = concatenate([Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same')(conv6), conv3], axis=3)
    up7 = Dropout(dropout)(up7)
    
    conv7 = Conv2D(128, (3, 3), activation='relu', padding='same')(up7)
    conv7 = Conv2D(128, (3, 3), activation='relu', padding='same')(conv7)
    up8 = concatenate([Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(conv7), conv2], axis=3)
    up8 = Dropout(dropout)(up8)
    
    conv8 = Conv2D(64, (3, 3), activation='relu', padding='same')(up8)
    conv8 = Conv2D(64, (3, 3), activation='relu', padding='same')(conv8)
    up9 = concatenate([Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same')(conv8), conv1], axis=3)
    up9 = Dropout(dropout)(up9)
    
    conv9 = Conv2D(32, (3, 3), activation='relu', padding='same')(up9)
    conv9 = Conv2D(32, (3, 3), activation='relu', padding='same')(conv9)
    conv10 = Conv2D(4, (1,1), activation='softmax')(conv9)
    
    loss_function = 'categorical_crossentropy'
    model = Model(inputs=[inputs], outputs=[conv10])
    model.compile(optimizer=Adam(lr=1e-4), loss=loss_function, metrics=[dice_coef_])
    model.summary()
    return model

# %% [markdown]
# ### Traininng new model

# %%
name = 'model_softmax_reg.h5'

checkpoint = ModelCheckpoint(name, verbose=1, save_best_only=True, save_weights_only=True)
model = get_unet_reg()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_9 (InputLayer)            (None, 256, 256, 1)  0
# __________________________________________________________________________________________________
# conv2d_116 (Conv2D)             (None, 256, 256, 32) 320         input_9[0][0]
# __________________________________________________________________________________________________
# conv2d_117 (Conv2D)             (None, 256, 256, 32) 9248        conv2d_116[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_25 (MaxPooling2D) (None, 128, 128, 32) 0           conv2d_117[0][0]
# __________________________________________________________________________________________________
# dropout_49 (Dropout)            (None, 128, 128, 32) 0           max_pooling2d_25[0][0]
# __________________________________________________________________________________________________
# conv2d_118 (Conv2D)             (None, 128, 128, 64) 18496       dropout_49[0][0]
# __________________________________________________________________________________________________
# conv2d_119 (Conv2D)             (None, 128, 128, 64) 36928       conv2d_118[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_26 (MaxPooling2D) (None, 64, 64, 64)   0           conv2d_119[0][0]
# __________________________________________________________________________________________________
# dropout_50 (Dropout)            (None, 64, 64, 64)   0           max_pooling2d_26[0][0]
# __________________________________________________________________________________________________
# conv2d_120 (Conv2D)             (None, 64, 64, 128)  73856       dropout_50[0][0]
# __________________________________________________________________________________________________
# conv2d_121 (Conv2D)             (None, 64, 64, 128)  147584      conv2d_120[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_27 (MaxPooling2D) (None, 32, 32, 128)  0           conv2d_121[0][0]
# __________________________________________________________________________________________________
# dropout_51 (Dropout)            (None, 32, 32, 128)  0           max_pooling2d_27[0][0]
# __________________________________________________________________________________________________
# conv2d_122 (Conv2D)             (None, 32, 32, 256)  295168      dropout_51[0][0]
# __________________________________________________________________________________________________
# conv2d_123 (Conv2D)             (None, 32, 32, 256)  590080      conv2d_122[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_28 (MaxPooling2D) (None, 16, 16, 256)  0           conv2d_123[0][0]
# __________________________________________________________________________________________________
# dropout_52 (Dropout)            (None, 16, 16, 256)  0           max_pooling2d_28[0][0]
# __________________________________________________________________________________________________
# conv2d_124 (Conv2D)             (None, 16, 16, 512)  1180160     dropout_52[0][0]
# __________________________________________________________________________________________________
# conv2d_125 (Conv2D)             (None, 16, 16, 512)  2359808     conv2d_124[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_25 (Conv2DTran (None, 32, 32, 256)  524544      conv2d_125[0][0]
# __________________________________________________________________________________________________
# concatenate_25 (Concatenate)    (None, 32, 32, 512)  0           conv2d_transpose_25[0][0]
#                                                                  conv2d_123[0][0]
# __________________________________________________________________________________________________
# dropout_53 (Dropout)            (None, 32, 32, 512)  0           concatenate_25[0][0]
# __________________________________________________________________________________________________
# conv2d_126 (Conv2D)             (None, 32, 32, 256)  1179904     dropout_53[0][0]
# __________________________________________________________________________________________________
# conv2d_127 (Conv2D)             (None, 32, 32, 256)  590080      conv2d_126[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_26 (Conv2DTran (None, 64, 64, 128)  131200      conv2d_127[0][0]
# __________________________________________________________________________________________________
# concatenate_26 (Concatenate)    (None, 64, 64, 256)  0           conv2d_transpose_26[0][0]
#                                                                  conv2d_121[0][0]
# __________________________________________________________________________________________________
# dropout_54 (Dropout)            (None, 64, 64, 256)  0           concatenate_26[0][0]
# __________________________________________________________________________________________________
# conv2d_128 (Conv2D)             (None, 64, 64, 128)  295040      dropout_54[0][0]
# __________________________________________________________________________________________________
# conv2d_129 (Conv2D)             (None, 64, 64, 128)  147584      conv2d_128[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_27 (Conv2DTran (None, 128, 128, 64) 32832       conv2d_129[0][0]
# __________________________________________________________________________________________________
# concatenate_27 (Concatenate)    (None, 128, 128, 128 0           conv2d_transpose_27[0][0]
#                                                                  conv2d_119[0][0]
# __________________________________________________________________________________________________
# dropout_55 (Dropout)            (None, 128, 128, 128 0           concatenate_27[0][0]
# __________________________________________________________________________________________________
# conv2d_130 (Conv2D)             (None, 128, 128, 64) 73792       dropout_55[0][0]
# __________________________________________________________________________________________________
# conv2d_131 (Conv2D)             (None, 128, 128, 64) 36928       conv2d_130[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_28 (Conv2DTran (None, 256, 256, 32) 8224        conv2d_131[0][0]
# __________________________________________________________________________________________________
# concatenate_28 (Concatenate)    (None, 256, 256, 64) 0           conv2d_transpose_28[0][0]
#                                                                  conv2d_117[0][0]
# __________________________________________________________________________________________________
# dropout_56 (Dropout)            (None, 256, 256, 64) 0           concatenate_28[0][0]
# __________________________________________________________________________________________________
# conv2d_132 (Conv2D)             (None, 256, 256, 32) 18464       dropout_56[0][0]
# __________________________________________________________________________________________________
# conv2d_133 (Conv2D)             (None, 256, 256, 32) 9248        conv2d_132[0][0]
# __________________________________________________________________________________________________
# conv2d_134 (Conv2D)             (None, 256, 256, 4)  132         conv2d_133[0][0]
# ==================================================================================================
# Total params: 7,759,620
# Trainable params: 7,759,620
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
print('Loading and preprocessing train data...')
print('-'*30)
imgs_train, imgs_mask_train = load_train_data()


imgs_train = imgs_train.astype('float32')
mean = np.mean(imgs_train)  # mean for data centering
std = np.std(imgs_train)  # std for data normalization
imgs_train -= mean
imgs_train /= std
print("normalize")
np.savez_compressed('scaler',mean=mean,std=std)

results = model.fit(imgs_train, imgs_mask_train, batch_size=32, epochs=40, callbacks=[checkpoint]
                   ,shuffle=True,
              validation_split=0.2)
# Out:
# Loading and preprocessing train data...
# ------------------------------
# normalize
# Train on 200 samples, validate on 50 samples
# Epoch 1/40
# 200/200 [==============================] - 8s 40ms/step - loss: 0.0622 - dice_coef_: 0.0234 - val_loss: 0.0549 - val_dice_coef_: 0.0239
#
# Epoch 00001: val_loss improved from inf to 0.05488, saving model to model_softmax_reg.h5
# Epoch 2/40
# 200/200 [==============================] - 4s 22ms/step - loss: 0.0602 - dice_coef_: 0.0250 - val_loss: 0.0514 - val_dice_coef_: 0.0269
#
# Epoch 00002: val_loss improved from 0.05488 to 0.05136, saving model to model_softmax_reg.h5
# Epoch 3/40
# 200/200 [==============================] - 4s 22ms/step - loss: 0.0585 - dice_coef_: 0.0284 - val_loss: 0.0480 - val_dice_coef_: 0.0309
#
# Epoch 00003: val_loss improved from 0.05136 to 0.04803, saving model to model_softmax_reg.h5
# Epoch 4/40
# 200/200 [==============================] - 4s 21ms/step - loss: 0.0575 - dice_coef_: 0.0296 - val_loss: 0.0482 - val_dice_coef_: 0.0298
#
# Epoch 00004: val_loss did not improve from 0.04803
# Epoch 5/40
# 200/200 [==============================] - 4s 21ms/step - loss: 0.0551 - dice_coef_: 0.0341 - val_loss: 0.0414 - val_dice_coef_: 0.0374
#
# Epoch 00005: val_loss improved from 0.04803 to 0.04139, saving model to model_softmax_reg.h5
# Epoch 6/40
#  32/200 [===>..........................] - ETA: 3s - loss: 0.0568 - dice_coef_: 0.0471
# ---------------------------------------------------------------------------
# ResourceExhaustedError                    Traceback (most recent call last)
# <ipython-input-29-3cce250d5b8c> in <module>
#      14 results = model.fit(imgs_train, imgs_mask_train, batch_size=32, epochs=40, callbacks=[checkpoint]
#      15                    ,shuffle=True,
# ---> 16               validation_split=0.2)
#
# /opt/campux/virtualenv/deeplearning/lib/python3.6/site-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#    1037                                         initial_epoch=initial_epoch,
#    1038                                         steps_per_epoch=steps_per_epoch,
# -> 1039                                         validation_steps=validation_steps)
#    1040
#    1041     def evaluate(self, x=None, y=None,
#
# /opt/campux/virtualenv/deeplearning/lib/python3.6/site-packages/keras/engine/training_arrays.py in fit_loop(model, f, ins, out_labels, batch_size, epochs, verbose, callbacks, val_f, val_ins, shuffle, callback_metrics, initial_epoch, steps_per_epoch, validation_steps)
#     197                     ins_batch[i] = ins_batch[i].toarray()
#     198
# --> 199                 outs = f(ins_batch)
#     200                 outs = to_list(outs)
#     201                 for l, o in zip(out_labels, outs):
#
# /opt/campux/virtualenv/deeplearning/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2713                 return self._legacy_call(inputs)
#    2714
# -> 2715             return self._call(inputs)
#    2716         else:
#    2717             if py_any(is_tensor(x) for x in inputs):
#
# /opt/campux/virtualenv/deeplearning/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in _call(self, inputs)
#    2673             fetched = self._callable_fn(*array_vals, run_metadata=self.run_metadata)
#    2674         else:
# -> 2675             fetched = self._callable_fn(*array_vals)
#    2676         return fetched[:len(self.outputs)]
#    2677
#
# /opt/campux/virtualenv/deeplearning/lib/python3.6/site-packages/tensorflow/python/client/session.py in __call__(self, *args)
#    1452         else:
#    1453           return tf_session.TF_DeprecatedSessionRunCallable(
# -> 1454               self._session._session, self._handle, args, status, None)
#    1455
#    1456     def __del__(self):
#
# /opt/campux/virtualenv/deeplearning/lib/python3.6/site-packages/tensorflow/python/framework/errors_impl.py in __exit__(self, type_arg, value_arg, traceback_arg)
#     517             None, None,
#     518             compat.as_text(c_api.TF_Message(self.status.status)),
# --> 519             c_api.TF_GetCode(self.status.status))
#     520     # Delete the underlying status object from memory otherwise it stays alive
#     521     # as there is a reference to status from this from the traceback due to
#
# ResourceExhaustedError: OOM when allocating tensor with shape[32,64,256,256] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# 	 [[Node: training_6/Adam/gradients/conv2d_132/convolution_grad/Conv2DBackpropInput = Conv2DBackpropInput[T=DT_FLOAT, _class=["loc:@training_6/Adam/gradients/dropout_56/cond/Merge_grad/cond_grad"], data_format="NCHW", dilations=[1, 1, 1, 1], padding="SAME", strides=[1, 1, 1, 1], use_cudnn_on_gpu=true, _device="/job:localhost/replica:0/task:0/device:GPU:0"](training_6/Adam/gradients/conv2d_132/convolution_grad/ShapeN, conv2d_132/kernel/read, training_6/Adam/gradients/conv2d_132/Relu_grad/ReluGrad)]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info.

# %%
plt.subplot(211)
plt.plot(results.history['loss'], label='train')
plt.plot(results.history['val_loss'], label='val')
plt.title('loss')
plt.legend()

plt.subplot(212)
plt.plot(results.history['dice_coef_'], label='train')
plt.plot(results.history['val_dice_coef_'], label='val')
plt.title('acc')
plt.legend()
