# %%
import numpy as np
import matplotlib.pyplot as plt
from skimage.transform import resize # from scipy.misc import imresize
from tqdm import tqdm
import nibabel

# %%
def read_train_exam(exam_nb):
    image = nibabel.load('../chaos/train/%02d-T2SPIR-src.nii.gz'%(exam_nb))
    mask = nibabel.load('../chaos/train/%02d-T2SPIR-mask.nii.gz'%(exam_nb))
    return image, mask

def read_test_exam(exam_nb):
    image = nibabel.load('../chaos/test/%02d-T2SPIR-src.nii.gz'%(exam_nb))
    return image

# %%
img_rows,img_cols = 256,256
def preprocess(image):
    #shape (slide,256,256)
    image_ = np.ndarray((image.shape[2],img_rows,img_cols,1))
    for i in range(image.shape[2]):
        image_[i,:,:,0] = resize(image.get_data()[:,:,i],(img_rows,img_cols),mode='reflect',preserve_range=True,
                               anti_aliasing=True)            
    #print(image_.shape)
    return image_

# %%
image_1, mask_1 = read_train_exam(2)

# %%
print("before scale {},{},".format(np.unique(mask_1.get_data()),np.unique(image_1.get_data())))
# Out:
# before scale [0 1 2 3 4],[   0    1    2 ... 1474 1501 1503],

# %%
print("after scale {},{}".format(np.unique(preprocess(mask_1)),np.unique(preprocess(image_1))))
# Out:
# after scale [0.       0.015625 0.015625 ... 3.984375 3.984375 4.      ],[0.00000000e+00 1.56250000e-02 1.56250000e-02 ... 1.45790625e+03
#  1.46843750e+03 1.48428125e+03]

# %%
def mask_to_channels(mask,init,classes):
    #get mask for each class
    img = np.asarray([np.where(mask == i,1,0 ) for i in range(init,classes)])
    img = np.swapaxes(img,0,-1)#new shape (row,col,class)
    print(img.shape)
    return img

# %%
test = mask_1.get_data()[:,:,15]
img = mask_to_channels(test,0,5)
for i in range(0,5):
    plt.subplot(1,5,i+1)
    plt.imshow(img[:,:,i])
plt.show()
# Out:
# (320, 320, 5)

# %%
def create_data_train(train_ids,name, background = 0):
    
    for idx, train_id in tqdm(enumerate(train_ids)):
        image, mask = read_train_exam(train_id)     
        image = preprocess(image)
        mask = preprocess(mask) 
        print(train_id)
        #transform le mask
        if background:
            #create mask for 5 classess
            mask = mask_to_channels(mask,0,5)[0]
        else:
            mask = mask_to_channels(mask,1,5)[0]            
       
        if idx > 0:
            train_data = np.concatenate((train_data, image),axis=0)
            train_mask = np.concatenate((train_mask, mask),axis=0)
        else:
            train_data = image
            train_mask = mask
    print("Final shape {},{}".format(train_data.shape,train_mask.shape))    
    np.savez_compressed('./dataset/imgs_{}'.format(name), imgs=train_data)
    np.savez_compressed('./dataset/imgs_mask_{}'.format(name), imgs_mask=train_mask)

# %%
train_sujets = [1,2,3,5,8]
validation_sujets = [10,13,19]

# %%
#dataset training training data
create_data_train(train_sujets,"train_data")
# Out:
# 1it [00:00,  3.25it/s]
# 1
# (1, 36, 256, 256, 4)
# 2it [00:00,  3.11it/s]
# 2
# (1, 26, 256, 256, 4)
# 3it [00:01,  2.68it/s]
# 3
# (1, 30, 256, 256, 4)
# 5
# (1, 30, 256, 256, 4)
# 4it [00:01,  2.58it/s]
# 8
# (1, 32, 256, 256, 4)
# 5it [00:02,  2.28it/s]
# Final shape (154, 256, 256, 1),(154, 256, 256, 4)

# %%
#dataset training validation data
create_data_train(validation_sujets,"validation_data")
# Out:
# 1it [00:00,  3.15it/s]
# 10
# (1, 36, 256, 256, 4)
# 2it [00:00,  2.92it/s]
# 13
# (1, 30, 256, 256, 4)
# 3it [00:01,  2.69it/s]
# 19
# (1, 30, 256, 256, 4)
# Final shape (96, 256, 256, 1),(96, 256, 256, 4)

# %% [markdown]
# ### plot images

# %%
img = np.load('./dataset/imgs_train_data.npz')['imgs']
img_mask = np.load('./dataset/imgs_mask_train_data.npz')['imgs_mask']

# %%
img_mask[:,:,:].shape
# Out:
# (154, 256, 256, 4)

# %%
img[:,:,:,0].shape
# Out:
# (154, 256, 256)

# %%
#plot random samples from data
def plot_random_images(data,mask):
    index = np.random.choice(range(data.shape[0]),1)[0]
    plt.figure(figsize=(20, 15))
    c = mask.shape[3]
    #image
    plt.subplot(1, c + 1, 1)
    plt.imshow(data[index,:,:,0], cmap='gray', interpolation='nearest')
   
    for i in range(c): 
        plt.subplot(1, c + 1, i+2)
        plt.imshow(mask[index,:,:,i])
    plt.show()

# %%
#plot random samples from training data
print("Training data")
plot_random_images(img,img_mask)
# Out:
# Training data

# %%
plot_random_images(img,img_mask)

# %%
print(np.unique(img))
# Out:
# [0.00000000e+00 1.00974196e-28 1.51461294e-28 ... 1.93000000e+03
#  1.93500000e+03 1.97900000e+03]

# %%
imgs_train = img.astype('float32')
mean = np.mean(imgs_train)  # mean for data centering
std = np.std(imgs_train)  # std for data normalization

imgs_train -= mean
imgs_train /= std

# %%
print(np.unique(imgs_train))
# Out:
# [-0.542792   -0.54276794 -0.5427438  ... 11.364295   11.395143
#  11.666599  ]

# %% [markdown]
# # MODEL

# %%
#version tf1
from keras.models import Model
from keras.layers import Input, concatenate,Conv2D, MaxPooling2D, Conv2DTranspose,Dropout
from keras.optimizers import Adam,SGD
from keras.callbacks import ModelCheckpoint
from keras import backend as K

K.set_image_data_format('channels_last')  # TF dimension ordering in this code

# %%
img_rows = 256
img_cols = 256

# %%
smooth = 1.
#batch 32!
def dice_coef_(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)

def dice_coef_loss(y_true, y_pred):  
    return -dice_coef_(y_true, y_pred)

# %%
def get_unet():
    inputs = Input((img_rows, img_cols, 1))
    conv1 = Conv2D(32, (3, 3), activation='relu', padding='same')(inputs)
    conv1 = Conv2D(32, (3, 3), activation='relu', padding='same')(conv1)
    pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)

    conv2 = Conv2D(64, (3, 3), activation='relu', padding='same')(pool1)
    conv2 = Conv2D(64, (3, 3), activation='relu', padding='same')(conv2)
    pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)

    conv3 = Conv2D(128, (3, 3), activation='relu', padding='same')(pool2)
    conv3 = Conv2D(128, (3, 3), activation='relu', padding='same')(conv3)
    pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)

    conv4 = Conv2D(256, (3, 3), activation='relu', padding='same')(pool3)
    conv4 = Conv2D(256, (3, 3), activation='relu', padding='same')(conv4)
    pool4 = MaxPooling2D(pool_size=(2, 2))(conv4)

    conv5 = Conv2D(512, (3, 3), activation='relu', padding='same')(pool4)
    conv5 = Conv2D(512, (3, 3), activation='relu', padding='same')(conv5)

    up6 = concatenate([Conv2DTranspose(256, (2, 2), strides=(2, 2), padding='same')(conv5), conv4], axis=3)
    conv6 = Conv2D(256, (3, 3), activation='relu', padding='same')(up6)
    conv6 = Conv2D(256, (3, 3), activation='relu', padding='same')(conv6)

    up7 = concatenate([Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same')(conv6), conv3], axis=3)
    conv7 = Conv2D(128, (3, 3), activation='relu', padding='same')(up7)
    conv7 = Conv2D(128, (3, 3), activation='relu', padding='same')(conv7)

    up8 = concatenate([Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(conv7), conv2], axis=3)
    conv8 = Conv2D(64, (3, 3), activation='relu', padding='same')(up8)
    conv8 = Conv2D(64, (3, 3), activation='relu', padding='same')(conv8)

    up9 = concatenate([Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same')(conv8), conv1], axis=3)
    conv9 = Conv2D(32, (3, 3), activation='relu', padding='same')(up9)
    conv9 = Conv2D(32, (3, 3), activation='relu', padding='same')(conv9)
    conv9 = Conv2D(4, (3,3), activation='relu', padding='same')(conv9)
    
    conv10 = Conv2D(4, (1,1), activation='softmax')(conv9)
    loss_function = 'categorical_crossentropy'
    model = Model(inputs=[inputs], outputs=[conv10])
    
    model.compile(optimizer=Adam(lr=1e-4), loss=loss_function, metrics=[dice_coef_])
    model.summary()
    return model

# %% [markdown]
# # training

# %%
print('Loading and preprocessing train data...')
print('-'*30)
imgs_train, imgs_mask_train = load_train_data()
name = 'model_softmax.h5'

checkpoint = ModelCheckpoint(name, verbose=1, save_best_only=True, save_weights_only=True)
model = get_unet()

imgs_train = imgs_train.astype('float32')
mean = np.mean(imgs_train)  # mean for data centering
std = np.std(imgs_train)  # std for data normalization
imgs_train -= mean
imgs_train /= std
print("normalize")
np.savez_compressed('scaler',mean=mean,std=std)

results = model.fit(imgs_train, imgs_mask_train, batch_size=32, epochs=50, callbacks=[checkpoint]
                   ,shuffle=True,
              validation_split=0.2)
# Out:
# Loading and preprocessing train data...
# ------------------------------
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_35 (InputLayer)           (None, 256, 256, 1)  0
# __________________________________________________________________________________________________
# conv2d_679 (Conv2D)             (None, 256, 256, 32) 320         input_35[0][0]
# __________________________________________________________________________________________________
# conv2d_680 (Conv2D)             (None, 256, 256, 32) 9248        conv2d_679[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_137 (MaxPooling2D (None, 128, 128, 32) 0           conv2d_680[0][0]
# __________________________________________________________________________________________________
# conv2d_681 (Conv2D)             (None, 128, 128, 64) 18496       max_pooling2d_137[0][0]
# __________________________________________________________________________________________________
# conv2d_682 (Conv2D)             (None, 128, 128, 64) 36928       conv2d_681[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_138 (MaxPooling2D (None, 64, 64, 64)   0           conv2d_682[0][0]
# __________________________________________________________________________________________________
# conv2d_683 (Conv2D)             (None, 64, 64, 128)  73856       max_pooling2d_138[0][0]
# __________________________________________________________________________________________________
# conv2d_684 (Conv2D)             (None, 64, 64, 128)  147584      conv2d_683[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_139 (MaxPooling2D (None, 32, 32, 128)  0           conv2d_684[0][0]
# __________________________________________________________________________________________________
# conv2d_685 (Conv2D)             (None, 32, 32, 256)  295168      max_pooling2d_139[0][0]
# __________________________________________________________________________________________________
# conv2d_686 (Conv2D)             (None, 32, 32, 256)  590080      conv2d_685[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_140 (MaxPooling2D (None, 16, 16, 256)  0           conv2d_686[0][0]
# __________________________________________________________________________________________________
# conv2d_687 (Conv2D)             (None, 16, 16, 512)  1180160     max_pooling2d_140[0][0]
# __________________________________________________________________________________________________
# conv2d_688 (Conv2D)             (None, 16, 16, 512)  2359808     conv2d_687[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_137 (Conv2DTra (None, 32, 32, 256)  524544      conv2d_688[0][0]
# __________________________________________________________________________________________________
# concatenate_137 (Concatenate)   (None, 32, 32, 512)  0           conv2d_transpose_137[0][0]
#                                                                  conv2d_686[0][0]
# __________________________________________________________________________________________________
# conv2d_689 (Conv2D)             (None, 32, 32, 256)  1179904     concatenate_137[0][0]
# __________________________________________________________________________________________________
# conv2d_690 (Conv2D)             (None, 32, 32, 256)  590080      conv2d_689[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_138 (Conv2DTra (None, 64, 64, 128)  131200      conv2d_690[0][0]
# __________________________________________________________________________________________________
# concatenate_138 (Concatenate)   (None, 64, 64, 256)  0           conv2d_transpose_138[0][0]
#                                                                  conv2d_684[0][0]
# __________________________________________________________________________________________________
# conv2d_691 (Conv2D)             (None, 64, 64, 128)  295040      concatenate_138[0][0]
# __________________________________________________________________________________________________
# conv2d_692 (Conv2D)             (None, 64, 64, 128)  147584      conv2d_691[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_139 (Conv2DTra (None, 128, 128, 64) 32832       conv2d_692[0][0]
# __________________________________________________________________________________________________
# concatenate_139 (Concatenate)   (None, 128, 128, 128 0           conv2d_transpose_139[0][0]
#                                                                  conv2d_682[0][0]
# __________________________________________________________________________________________________
# conv2d_693 (Conv2D)             (None, 128, 128, 64) 73792       concatenate_139[0][0]
# __________________________________________________________________________________________________
# conv2d_694 (Conv2D)             (None, 128, 128, 64) 36928       conv2d_693[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_140 (Conv2DTra (None, 256, 256, 32) 8224        conv2d_694[0][0]
# __________________________________________________________________________________________________
# concatenate_140 (Concatenate)   (None, 256, 256, 64) 0           conv2d_transpose_140[0][0]
#                                                                  conv2d_680[0][0]
# __________________________________________________________________________________________________
# conv2d_695 (Conv2D)             (None, 256, 256, 32) 18464       concatenate_140[0][0]
# __________________________________________________________________________________________________
# conv2d_696 (Conv2D)             (None, 256, 256, 32) 9248        conv2d_695[0][0]
# __________________________________________________________________________________________________
# conv2d_697 (Conv2D)             (None, 256, 256, 4)  1156        conv2d_696[0][0]
# __________________________________________________________________________________________________
# conv2d_698 (Conv2D)             (None, 256, 256, 4)  20          conv2d_697[0][0]
# ==================================================================================================
# Total params: 7,760,664
# Trainable params: 7,760,664
# Non-trainable params: 0
# __________________________________________________________________________________________________
# normalize
# Train on 200 samples, validate on 50 samples
# Epoch 1/50
# 200/200 [==============================] - 8s 39ms/step - loss: 0.0608 - dice_coef_: 0.0239 - val_loss: 0.0524 - val_dice_coef_: 0.0256
#
# Epoch 00001: val_loss improved from inf to 0.05244, saving model to model_softmax.h5
# Epoch 2/50
# 200/200 [==============================] - 4s 19ms/step - loss: 0.0581 - dice_coef_: 0.0267 - val_loss: 0.0487 - val_dice_coef_: 0.0301
#
# Epoch 00002: val_loss improved from 0.05244 to 0.04870, saving model to model_softmax.h5
# Epoch 3/50
# 200/200 [==============================] - 4s 19ms/step - loss: 0.0579 - dice_coef_: 0.0298 - val_loss: 0.0473 - val_dice_coef_: 0.0325
#
# Epoch 00003: val_loss improved from 0.04870 to 0.04734, saving model to model_softmax.h5
# Epoch 4/50
# 200/200 [==============================] - 4s 19ms/step - loss: 0.0573 - dice_coef_: 0.0302 - val_loss: 0.0471 - val_dice_coef_: 0.0314
#
# Epoch 00004: val_loss improved from 0.04734 to 0.04713, saving model to model_softmax.h5
# Epoch 5/50
# 200/200 [==============================] - 4s 19ms/step - loss: 0.0558 - dice_coef_: 0.0310 - val_loss: 0.0428 - val_dice_coef_: 0.0372
#
# Epoch 00005: val_loss improved from 0.04713 to 0.04278, saving model to model_softmax.h5
# Epoch 6/50
# 200/200 [==============================] - 4s 19ms/step - loss: 0.0524 - dice_coef_: 0.0369 - val_loss: 0.0362 - val_dice_coef_: 0.0417
#
# Epoch 00006: val_loss improved from 0.04278 to 0.03615, saving model to model_softmax.h5
# Epoch 7/50
# 200/200 [==============================] - 4s 19ms/step - loss: 0.0402 - dice_coef_: 0.0483 - val_loss: 0.0219 - val_dice_coef_: 0.0576
#
# Epoch 00007: val_loss improved from 0.03615 to 0.02187, saving model to model_softmax.h5
# Epoch 8/50
# 200/200 [==============================] - 4s 19ms/step - loss: 0.0286 - dice_coef_: 0.0596 - val_loss: 0.0155 - val_dice_coef_: 0.0660
#
# Epoch 00008: val_loss improved from 0.02187 to 0.01546, saving model to model_softmax.h5
# Epoch 9/50
# 200/200 [==============================] - 4s 19ms/step - loss: 0.0242 - dice_coef_: 0.0643 - val_loss: 0.0149 - val_dice_coef_: 0.0670
#
# Epoch 00009: val_loss improved from 0.01546 to 0.01488, saving model to model_softmax.h5
# Epoch 10/50
# 200/200 [==============================] - 4s 19ms/step - loss: 0.0230 - dice_coef_: 0.0652 - val_loss: 0.0144 - val_dice_coef_: 0.0669
#
# Epoch 00010: val_loss improved from 0.01488 to 0.01445, saving model to model_softmax.h5
# Epoch 11/50
# 200/200 [==============================] - 4s 19ms/step - loss: 0.0216 - dice_coef_: 0.0659 - val_loss: 0.0131 - val_dice_coef_: 0.0698
#
# Epoch 00011: val_loss improved from 0.01445 to 0.01311, saving model to model_softmax.h5
# Epoch 12/50
# 200/200 [==============================] - 4s 20ms/step - loss: 0.0223 - dice_coef_: 0.0658 - val_loss: 0.0132 - val_dice_coef_: 0.0699
#
# Epoch 00012: val_loss did not improve from 0.01311
# Epoch 13/50
# 200/200 [==============================] - 4s 20ms/step - loss: 0.0214 - dice_coef_: 0.0663 - val_loss: 0.0129 - val_dice_coef_: 0.0700
#
# Epoch 00013: val_loss improved from 0.01311 to 0.01286, saving model to model_softmax.h5
# Epoch 14/50
# 200/200 [==============================] - 4s 19ms/step - loss: 0.0211 - dice_coef_: 0.0668 - val_loss: 0.0125 - val_dice_coef_: 0.0697
#
# Epoch 00014: val_loss improved from 0.01286 to 0.01247, saving model to model_softmax.h5
# Epoch 15/50
# 200/200 [==============================] - 4s 19ms/step - loss: 0.0203 - dice_coef_: 0.0676 - val_loss: 0.0131 - val_dice_coef_: 0.0685
#
# Epoch 00015: val_loss did not improve from 0.01247
# Epoch 16/50
# 200/200 [==============================] - 4s 19ms/step - loss: 0.0195 - dice_coef_: 0.0679 - val_loss: 0.0124 - val_dice_coef_: 0.0694
#
# Epoch 00016: val_loss improved from 0.01247 to 0.01244, saving model to model_softmax.h5
# Epoch 17/50
# 200/200 [==============================] - 4s 19ms/step - loss: 0.0190 - dice_coef_: 0.0682 - val_loss: 0.0121 - val_dice_coef_: 0.0700
#
# Epoch 00017: val_loss improved from 0.01244 to 0.01209, saving model to model_softmax.h5
# Epoch 18/50
# 200/200 [==============================] - 4s 19ms/step - loss: 0.0189 - dice_coef_: 0.0682 - val_loss: 0.0122 - val_dice_coef_: 0.0698
#
# Epoch 00018: val_loss did not improve from 0.01209
# Epoch 19/50
# 200/200 [==============================] - 4s 19ms/step - loss: 0.0186 - dice_coef_: 0.0683 - val_loss: 0.0119 - val_dice_coef_: 0.0702
#
# Epoch 00019: val_loss improved from 0.01209 to 0.01186, saving model to model_softmax.h5
# Epoch 20/50
# 200/200 [==============================] - 4s 19ms/step - loss: 0.0181 - dice_coef_: 0.0689 - val_loss: 0.0129 - val_dice_coef_: 0.0688
#
# Epoch 00020: val_loss did not improve from 0.01186
# Epoch 21/50
# 200/200 [==============================] - 4s 19ms/step - loss: 0.0180 - dice_coef_: 0.0691 - val_loss: 0.0126 - val_dice_coef_: 0.0692
#
# Epoch 00021: val_loss did not improve from 0.01186
# Epoch 22/50
# 200/200 [==============================] - 4s 19ms/step - loss: 0.0176 - dice_coef_: 0.0693 - val_loss: 0.0121 - val_dice_coef_: 0.0699
#
# Epoch 00022: val_loss did not improve from 0.01186
# Epoch 23/50
# 200/200 [==============================] - 4s 19ms/step - loss: 0.0173 - dice_coef_: 0.0695 - val_loss: 0.0115 - val_dice_coef_: 0.0705
#
# Epoch 00023: val_loss improved from 0.01186 to 0.01154, saving model to model_softmax.h5
# Epoch 24/50
# 200/200 [==============================] - 4s 20ms/step - loss: 0.0174 - dice_coef_: 0.0694 - val_loss: 0.0113 - val_dice_coef_: 0.0708
#
# Epoch 00024: val_loss improved from 0.01154 to 0.01134, saving model to model_softmax.h5
# Epoch 25/50
# 200/200 [==============================] - 4s 19ms/step - loss: 0.0173 - dice_coef_: 0.0694 - val_loss: 0.0113 - val_dice_coef_: 0.0708
#
# Epoch 00025: val_loss improved from 0.01134 to 0.01125, saving model to model_softmax.h5
# Epoch 26/50
# 200/200 [==============================] - 4s 19ms/step - loss: 0.0175 - dice_coef_: 0.0694 - val_loss: 0.0117 - val_dice_coef_: 0.0702
#
# Epoch 00026: val_loss did not improve from 0.01125
# Epoch 27/50
# 200/200 [==============================] - 4s 19ms/step - loss: 0.0171 - dice_coef_: 0.0697 - val_loss: 0.0118 - val_dice_coef_: 0.0701
#
# Epoch 00027: val_loss did not improve from 0.01125
# Epoch 28/50
# 200/200 [==============================] - 4s 19ms/step - loss: 0.0173 - dice_coef_: 0.0696 - val_loss: 0.0132 - val_dice_coef_: 0.0687
#
# Epoch 00028: val_loss did not improve from 0.01125
# Epoch 29/50
# 200/200 [==============================] - 4s 19ms/step - loss: 0.0173 - dice_coef_: 0.0694 - val_loss: 0.0124 - val_dice_coef_: 0.0695
#
# Epoch 00029: val_loss did not improve from 0.01125
# Epoch 30/50
# 200/200 [==============================] - 4s 19ms/step - loss: 0.0170 - dice_coef_: 0.0695 - val_loss: 0.0111 - val_dice_coef_: 0.0707
#
# Epoch 00030: val_loss improved from 0.01125 to 0.01115, saving model to model_softmax.h5
# Epoch 31/50
# 200/200 [==============================] - 4s 19ms/step - loss: 0.0167 - dice_coef_: 0.0698 - val_loss: 0.0116 - val_dice_coef_: 0.0702
#
# Epoch 00031: val_loss did not improve from 0.01115
# Epoch 32/50
# 200/200 [==============================] - 4s 19ms/step - loss: 0.0167 - dice_coef_: 0.0699 - val_loss: 0.0127 - val_dice_coef_: 0.0691
#
# Epoch 00032: val_loss did not improve from 0.01115
# Epoch 33/50
# 200/200 [==============================] - 4s 19ms/step - loss: 0.0169 - dice_coef_: 0.0697 - val_loss: 0.0116 - val_dice_coef_: 0.0703
#
# Epoch 00033: val_loss did not improve from 0.01115
# Epoch 34/50
# 200/200 [==============================] - 4s 19ms/step - loss: 0.0166 - dice_coef_: 0.0698 - val_loss: 0.0109 - val_dice_coef_: 0.0710
#
# Epoch 00034: val_loss improved from 0.01115 to 0.01092, saving model to model_softmax.h5
# Epoch 35/50
# 200/200 [==============================] - 4s 20ms/step - loss: 0.0165 - dice_coef_: 0.0700 - val_loss: 0.0111 - val_dice_coef_: 0.0708
#
# Epoch 00035: val_loss did not improve from 0.01092
# Epoch 36/50
# 200/200 [==============================] - 4s 19ms/step - loss: 0.0164 - dice_coef_: 0.0701 - val_loss: 0.0119 - val_dice_coef_: 0.0700
#
# Epoch 00036: val_loss did not improve from 0.01092
# Epoch 37/50
# 200/200 [==============================] - 4s 19ms/step - loss: 0.0163 - dice_coef_: 0.0701 - val_loss: 0.0115 - val_dice_coef_: 0.0705
#
# Epoch 00037: val_loss did not improve from 0.01092
# Epoch 38/50
# 200/200 [==============================] - 4s 19ms/step - loss: 0.0162 - dice_coef_: 0.0703 - val_loss: 0.0112 - val_dice_coef_: 0.0708
#
# Epoch 00038: val_loss did not improve from 0.01092
# Epoch 39/50
# 200/200 [==============================] - 4s 19ms/step - loss: 0.0160 - dice_coef_: 0.0703 - val_loss: 0.0116 - val_dice_coef_: 0.0706
#
# Epoch 00039: val_loss did not improve from 0.01092
# Epoch 40/50
# 200/200 [==============================] - 4s 20ms/step - loss: 0.0157 - dice_coef_: 0.0706 - val_loss: 0.0112 - val_dice_coef_: 0.0710
#
# Epoch 00040: val_loss did not improve from 0.01092
# Epoch 41/50
# 200/200 [==============================] - 4s 19ms/step - loss: 0.0156 - dice_coef_: 0.0706 - val_loss: 0.0120 - val_dice_coef_: 0.0715
# Epoch 00041: val_loss did not improve from 0.01092
# Epoch 42/50
# 200/200 [==============================] - 4s 19ms/step - loss: 0.0151 - dice_coef_: 0.0714 - val_loss: 0.0116 - val_dice_coef_: 0.0713
#
# Epoch 00042: val_loss did not improve from 0.01092
# Epoch 43/50
# 200/200 [==============================] - 4s 19ms/step - loss: 0.0150 - dice_coef_: 0.0718 - val_loss: 0.0175 - val_dice_coef_: 0.0686
#
# Epoch 00043: val_loss did not improve from 0.01092
# Epoch 44/50
# 200/200 [==============================] - 4s 19ms/step - loss: 0.0160 - dice_coef_: 0.0705 - val_loss: 0.0105 - val_dice_coef_: 0.0718
#
# Epoch 00044: val_loss improved from 0.01092 to 0.01054, saving model to model_softmax.h5
# Epoch 45/50
# 200/200 [==============================] - 4s 19ms/step - loss: 0.0213 - dice_coef_: 0.0657 - val_loss: 0.0108 - val_dice_coef_: 0.0715
#
# Epoch 00045: val_loss did not improve from 0.01054
# Epoch 46/50
# 200/200 [==============================] - 4s 19ms/step - loss: 0.0193 - dice_coef_: 0.0689 - val_loss: 0.0111 - val_dice_coef_: 0.0709
#
# Epoch 00046: val_loss did not improve from 0.01054
# Epoch 47/50
# 200/200 [==============================] - 4s 19ms/step - loss: 0.0157 - dice_coef_: 0.0710 - val_loss: 0.0118 - val_dice_coef_: 0.0718
#
# Epoch 00047: val_loss did not improve from 0.01054
# Epoch 48/50
# 200/200 [==============================] - 4s 19ms/step - loss: 0.0151 - dice_coef_: 0.0714 - val_loss: 0.0120 - val_dice_coef_: 0.0719
#
# Epoch 00048: val_loss did not improve from 0.01054
# Epoch 49/50
# 200/200 [==============================] - 4s 19ms/step - loss: 0.0143 - dice_coef_: 0.0723 - val_loss: 0.0112 - val_dice_coef_: 0.0724
#
# Epoch 00049: val_loss did not improve from 0.01054
# Epoch 50/50
# 200/200 [==============================] - 4s 20ms/step - loss: 0.0138 - dice_coef_: 0.0730 - val_loss: 0.0125 - val_dice_coef_: 0.0726
#
# Epoch 00050: val_loss did not improve from 0.01054

# %% [markdown]
# ## name = 'model_softmax.h5'

# %%
plt.subplot(211)
plt.plot(results.history['loss'], label='train')
plt.plot(results.history['val_loss'], label='val')
plt.title('loss')
plt.legend()

plt.subplot(212)
plt.plot(results.history['dice_coef_'], label='train')
plt.plot(results.history['val_dice_coef_'], label='val')
plt.title('acc')
plt.legend()

# %% [markdown]
# # evaluation

# %%
name
# Out:
# 'model_softmax.h5'

# %%
model = get_unet()
model.load_weights(name)
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_36 (InputLayer)           (None, 256, 256, 1)  0
# __________________________________________________________________________________________________
# conv2d_699 (Conv2D)             (None, 256, 256, 32) 320         input_36[0][0]
# __________________________________________________________________________________________________
# conv2d_700 (Conv2D)             (None, 256, 256, 32) 9248        conv2d_699[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_141 (MaxPooling2D (None, 128, 128, 32) 0           conv2d_700[0][0]
# __________________________________________________________________________________________________
# conv2d_701 (Conv2D)             (None, 128, 128, 64) 18496       max_pooling2d_141[0][0]
# __________________________________________________________________________________________________
# conv2d_702 (Conv2D)             (None, 128, 128, 64) 36928       conv2d_701[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_142 (MaxPooling2D (None, 64, 64, 64)   0           conv2d_702[0][0]
# __________________________________________________________________________________________________
# conv2d_703 (Conv2D)             (None, 64, 64, 128)  73856       max_pooling2d_142[0][0]
# __________________________________________________________________________________________________
# conv2d_704 (Conv2D)             (None, 64, 64, 128)  147584      conv2d_703[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_143 (MaxPooling2D (None, 32, 32, 128)  0           conv2d_704[0][0]
# __________________________________________________________________________________________________
# conv2d_705 (Conv2D)             (None, 32, 32, 256)  295168      max_pooling2d_143[0][0]
# __________________________________________________________________________________________________
# conv2d_706 (Conv2D)             (None, 32, 32, 256)  590080      conv2d_705[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_144 (MaxPooling2D (None, 16, 16, 256)  0           conv2d_706[0][0]
# __________________________________________________________________________________________________
# conv2d_707 (Conv2D)             (None, 16, 16, 512)  1180160     max_pooling2d_144[0][0]
# __________________________________________________________________________________________________
# conv2d_708 (Conv2D)             (None, 16, 16, 512)  2359808     conv2d_707[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_141 (Conv2DTra (None, 32, 32, 256)  524544      conv2d_708[0][0]
# __________________________________________________________________________________________________
# concatenate_141 (Concatenate)   (None, 32, 32, 512)  0           conv2d_transpose_141[0][0]
#                                                                  conv2d_706[0][0]
# __________________________________________________________________________________________________
# conv2d_709 (Conv2D)             (None, 32, 32, 256)  1179904     concatenate_141[0][0]
# __________________________________________________________________________________________________
# conv2d_710 (Conv2D)             (None, 32, 32, 256)  590080      conv2d_709[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_142 (Conv2DTra (None, 64, 64, 128)  131200      conv2d_710[0][0]
# __________________________________________________________________________________________________
# concatenate_142 (Concatenate)   (None, 64, 64, 256)  0           conv2d_transpose_142[0][0]
#                                                                  conv2d_704[0][0]
# __________________________________________________________________________________________________
# conv2d_711 (Conv2D)             (None, 64, 64, 128)  295040      concatenate_142[0][0]
# __________________________________________________________________________________________________
# conv2d_712 (Conv2D)             (None, 64, 64, 128)  147584      conv2d_711[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_143 (Conv2DTra (None, 128, 128, 64) 32832       conv2d_712[0][0]
# __________________________________________________________________________________________________
# concatenate_143 (Concatenate)   (None, 128, 128, 128 0           conv2d_transpose_143[0][0]
#                                                                  conv2d_702[0][0]
# __________________________________________________________________________________________________
# conv2d_713 (Conv2D)             (None, 128, 128, 64) 73792       concatenate_143[0][0]
# __________________________________________________________________________________________________
# conv2d_714 (Conv2D)             (None, 128, 128, 64) 36928       conv2d_713[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_144 (Conv2DTra (None, 256, 256, 32) 8224        conv2d_714[0][0]
# __________________________________________________________________________________________________
# concatenate_144 (Concatenate)   (None, 256, 256, 64) 0           conv2d_transpose_144[0][0]
#                                                                  conv2d_700[0][0]
# __________________________________________________________________________________________________
# conv2d_715 (Conv2D)             (None, 256, 256, 32) 18464       concatenate_144[0][0]
# __________________________________________________________________________________________________
# conv2d_716 (Conv2D)             (None, 256, 256, 32) 9248        conv2d_715[0][0]
# __________________________________________________________________________________________________
# conv2d_717 (Conv2D)             (None, 256, 256, 4)  1156        conv2d_716[0][0]
# __________________________________________________________________________________________________
# conv2d_718 (Conv2D)             (None, 256, 256, 4)  20          conv2d_717[0][0]
# ==================================================================================================
# Total params: 7,760,664
# Trainable params: 7,760,664
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
imgs_train, imgs_mask_train = load_train_data()

# %%
id = 110


test = imgs_train[id,:,:,:]
test -= mean
test /= std
y_pred = model.predict(test.reshape(1,256,256,1))

# %% [markdown]
# # results

# %%
plt.figure(figsize=(20, 15))

for i in range(4):
    plt.subplot(1,4,i+1)
    plt.imshow(imgs_train[id,:,:,0])
    slice_ = y_pred[0,:,:,i]
    x = np.sum(y_pred, axis = 3)[0]
    print(slice_.min(),slice_.max())
    plt.imshow(slice_,vmin=0,vmax=1, alpha=0.8)
plt.show()
# Out:
# 4.987086e-05 1.0
# 5.544229e-14 0.51872927
# 4.1417913e-13 0.75894874
# 2.34131e-10 0.4038112

# %% [markdown]
# # real

# %%
plt.figure(figsize=(20, 15))
for i in range(4):
    plt.subplot(1,4,i+1)
    slice_ = imgs_mask_train[id,:,:,i]
    plt.imshow(imgs_train[id,:,:,0])
    plt.imshow(slice_, alpha=0.78)    
plt.show()

# %% [markdown]
# # image test

# %%
imgs_test = load_test_data()
imgs_test -= mean
imgs_test /= std

# %%
mask_predicts = model.predict(imgs_test)

# %%
idx = 10
plt.figure(figsize=(20, 15))
for i in range(4):
    plt.subplot(1,4,i+1)
    plt.imshow(imgs_test[idx,:,:,0])
    slice_ = mask_predicts[idx,:,:,i]
    plt.imshow(slice_,vmin = slice_.min(), vmax= slice_.max(),cmap='jet', alpha=0.5)
plt.show()

# %%
idx = 50
plt.figure(figsize=(20, 15))
for i in range(4):
    plt.subplot(1,4,i+1)
    plt.imshow(imgs_test[idx,:,:,0])
    slice_ = mask_predicts[idx,:,:,i]
    plt.imshow(slice_,vmin = slice_.min(), vmax= slice_.max(),cmap='jet', alpha=0.5)
plt.show()

# %% [markdown]
# =======
# # 2. dropout and pooling

# %% [markdown]
# https://github.com/hlamba28/UNET-TGS/blob/master/TGS%20UNET.ipynb

# %% [markdown]
# > of “training hard enough”.
#
# > When training a deep neural network, our biggest concern is nearly always overfitting — and in order to combat overfitting, we introduce regularization techniques (discussed in Reason #1 above). We apply regularization in the form of:
#
#     Dropout
#     L2 weight decay
#     Reducing model capacity (i.e., a more shallow model)
#
# >We also tend to be a bit more conservative with our learning rate to ensure our model doesn’t overshoot areas of lower loss in the loss landscape.

# %%
def get_unet_reg(dropout = 0.3):
    inputs = Input((img_rows, img_cols, 1))
    
    conv1 = Conv2D(32, (3, 3), activation='relu', padding='same')(inputs)
    conv1 = Conv2D(32, (3, 3), activation='relu', padding='same')(conv1)
    pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)
    pool1 = Dropout(dropout)(pool1)
    
    conv2 = Conv2D(64, (3, 3), activation='relu', padding='same')(pool1)
    conv2 = Conv2D(64, (3, 3), activation='relu', padding='same')(conv2)
    pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)
   
    
    conv3 = Conv2D(128, (3, 3), activation='relu', padding='same')(pool2)
    conv3 = Conv2D(128, (3, 3), activation='relu', padding='same')(conv3)
    pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)
    pool3 = Dropout(dropout)(pool3)
    
    conv4 = Conv2D(256, (3, 3), activation='relu', padding='same')(pool3)
    conv4 = Conv2D(256, (3, 3), activation='relu', padding='same')(conv4)
    pool4 = MaxPooling2D(pool_size=(2, 2))(conv4)
    
    
    conv5 = Conv2D(512, (3, 3), activation='relu', padding='same')(pool4)
    conv5 = Conv2D(512, (3, 3), activation='relu', padding='same')(conv5)
    up6 = concatenate([Conv2DTranspose(256, (2, 2), strides=(2, 2), padding='same')(conv5), conv4], axis=3)
   

    conv6 = Conv2D(256, (3, 3), activation='relu', padding='same')(up6)
    conv6 = Conv2D(256, (3, 3), activation='relu', padding='same')(conv6)
    up7 = concatenate([Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same')(conv6), conv3], axis=3)
    
    
    conv7 = Conv2D(128, (3, 3), activation='relu', padding='same')(up7)
    conv7 = Conv2D(128, (3, 3), activation='relu', padding='same')(conv7)
    up8 = concatenate([Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(conv7), conv2], axis=3)
    
    
    conv8 = Conv2D(64, (3, 3), activation='relu', padding='same')(up8)
    conv8 = Conv2D(64, (3, 3), activation='relu', padding='same')(conv8)
    up9 = concatenate([Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same')(conv8), conv1], axis=3)
    
    
    conv9 = Conv2D(32, (3, 3), activation='relu', padding='same')(up9)
    conv9 = Conv2D(32, (3, 3), activation='relu', padding='same')(conv9)
    conv10 = Conv2D(4, (1,1), activation='softmax')(conv9)
    
    loss_function = 'categorical_crossentropy'
    model = Model(inputs=[inputs], outputs=[conv10])
    model.compile(optimizer=Adam(lr=1e-5), loss=loss_function, metrics=[dice_coef])
    model.summary()
    return model

# %% [markdown]
# ### Traininng new model

# %%
print('Loading and preprocessing train data...')
print('-'*30)
imgs_train, imgs_mask_train = load_train_data()
name = 'model_softmax_reg_propre.h5'

checkpoint = ModelCheckpoint(name, verbose=1, save_best_only=True, save_weights_only=True)
model = get_unet_reg()

imgs_train = imgs_train.astype('float32')
mean = np.mean(imgs_train)  # mean for data centering
std = np.std(imgs_train)  # std for data normalization
imgs_train -= mean
imgs_train /= std
print("normalize")
np.savez_compressed('scaler',mean=mean,std=std)

results = model.fit(imgs_train, imgs_mask_train, batch_size=32, epochs=40, callbacks=[checkpoint]
                   ,shuffle=True,
              validation_split=0.2)
# Out:
# Loading and preprocessing train data...
# ------------------------------
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            (None, 256, 256, 1)  0
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 256, 256, 32) 320         input_2[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 256, 256, 32) 9248        conv2d_20[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)  (None, 128, 128, 32) 0           conv2d_21[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 128, 128, 32) 0           max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 128, 128, 64) 18496       dropout_3[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 128, 128, 64) 36928       conv2d_22[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_6 (MaxPooling2D)  (None, 64, 64, 64)   0           conv2d_23[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 64, 64, 128)  73856       max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 64, 64, 128)  147584      conv2d_24[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_7 (MaxPooling2D)  (None, 32, 32, 128)  0           conv2d_25[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 32, 32, 128)  0           max_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 32, 32, 256)  295168      dropout_4[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 32, 32, 256)  590080      conv2d_26[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_8 (MaxPooling2D)  (None, 16, 16, 256)  0           conv2d_27[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 16, 16, 512)  1180160     max_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 16, 16, 512)  2359808     conv2d_28[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_5 (Conv2DTrans (None, 32, 32, 256)  524544      conv2d_29[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 32, 32, 512)  0           conv2d_transpose_5[0][0]
#                                                                  conv2d_27[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 32, 32, 256)  1179904     concatenate_5[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 32, 32, 256)  590080      conv2d_30[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_6 (Conv2DTrans (None, 64, 64, 128)  131200      conv2d_31[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 64, 64, 256)  0           conv2d_transpose_6[0][0]
#                                                                  conv2d_25[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 64, 64, 128)  295040      concatenate_6[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 64, 64, 128)  147584      conv2d_32[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_7 (Conv2DTrans (None, 128, 128, 64) 32832       conv2d_33[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 128, 128, 128 0           conv2d_transpose_7[0][0]
#                                                                  conv2d_23[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 128, 128, 64) 73792       concatenate_7[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 128, 128, 64) 36928       conv2d_34[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_8 (Conv2DTrans (None, 256, 256, 32) 8224        conv2d_35[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 256, 256, 64) 0           conv2d_transpose_8[0][0]
#                                                                  conv2d_21[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 256, 256, 32) 18464       concatenate_8[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 256, 256, 32) 9248        conv2d_36[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 256, 256, 4)  132         conv2d_37[0][0]
# ==================================================================================================
# Total params: 7,759,620
# Trainable params: 7,759,620
# Non-trainable params: 0
# __________________________________________________________________________________________________
# normalize
# Train on 200 samples, validate on 50 samples
# Epoch 1/40
# 200/200 [==============================] - 5s 26ms/step - loss: 0.0636 - dice_coef: 0.3672 - val_loss: 0.0597 - val_dice_coef: 0.3947
#
# Epoch 00001: val_loss improved from inf to 0.05965, saving model to model_softmax_reg_propre.h5
# Epoch 2/40
# 200/200 [==============================] - 4s 18ms/step - loss: 0.0635 - dice_coef: 0.2781 - val_loss: 0.0595 - val_dice_coef: 0.3936
#
# Epoch 00002: val_loss improved from 0.05965 to 0.05950, saving model to model_softmax_reg_propre.h5
# Epoch 3/40
# 200/200 [==============================] - 4s 18ms/step - loss: 0.0634 - dice_coef: 0.2315 - val_loss: 0.0593 - val_dice_coef: 0.3926
#
# Epoch 00003: val_loss improved from 0.05950 to 0.05934, saving model to model_softmax_reg_propre.h5
# Epoch 4/40
# 200/200 [==============================] - 4s 18ms/step - loss: 0.0632 - dice_coef: 0.1697 - val_loss: 0.0592 - val_dice_coef: 0.3911
#
# Epoch 00004: val_loss improved from 0.05934 to 0.05916, saving model to model_softmax_reg_propre.h5
# Epoch 5/40
# 200/200 [==============================] - 4s 18ms/step - loss: 0.0631 - dice_coef: 0.1062 - val_loss: 0.0590 - val_dice_coef: 0.3894
#
# Epoch 00005: val_loss improved from 0.05916 to 0.05897, saving model to model_softmax_reg_propre.h5
# Epoch 6/40
# 200/200 [==============================] - 4s 18ms/step - loss: 0.0629 - dice_coef: 0.2783 - val_loss: 0.0587 - val_dice_coef: 0.3875
#
# Epoch 00006: val_loss improved from 0.05897 to 0.05875, saving model to model_softmax_reg_propre.h5
# Epoch 7/40
# 200/200 [==============================] - 4s 18ms/step - loss: 0.0628 - dice_coef: 0.3238 - val_loss: 0.0585 - val_dice_coef: 0.3852
#
# Epoch 00007: val_loss improved from 0.05875 to 0.05851, saving model to model_softmax_reg_propre.h5
# Epoch 8/40
# 200/200 [==============================] - 4s 18ms/step - loss: 0.0626 - dice_coef: 0.2370 - val_loss: 0.0582 - val_dice_coef: 0.3826
#
# Epoch 00008: val_loss improved from 0.05851 to 0.05824, saving model to model_softmax_reg_propre.h5
# Epoch 9/40
# 200/200 [==============================] - 4s 19ms/step - loss: 0.0624 - dice_coef: 0.2837 - val_loss: 0.0579 - val_dice_coef: 0.3790
#
# Epoch 00009: val_loss improved from 0.05824 to 0.05794, saving model to model_softmax_reg_propre.h5
# Epoch 10/40
# 200/200 [==============================] - 4s 18ms/step - loss: 0.0621 - dice_coef: 0.2308 - val_loss: 0.0576 - val_dice_coef: 0.3747
#
# Epoch 00010: val_loss improved from 0.05794 to 0.05760, saving model to model_softmax_reg_propre.h5
# Epoch 11/40
# 200/200 [==============================] - 4s 18ms/step - loss: 0.0619 - dice_coef: 0.1710 - val_loss: 0.0572 - val_dice_coef: 0.3695
#
# Epoch 00011: val_loss improved from 0.05760 to 0.05721, saving model to model_softmax_reg_propre.h5
# Epoch 12/40
# 200/200 [==============================] - 4s 18ms/step - loss: 0.0616 - dice_coef: 0.1794 - val_loss: 0.0567 - val_dice_coef: 0.3625
#
# Epoch 00012: val_loss improved from 0.05721 to 0.05671, saving model to model_softmax_reg_propre.h5
# Epoch 13/40
# 200/200 [==============================] - 4s 18ms/step - loss: 0.0611 - dice_coef: 0.2883 - val_loss: 0.0561 - val_dice_coef: 0.3541
#
# Epoch 00013: val_loss improved from 0.05671 to 0.05614, saving model to model_softmax_reg_propre.h5
# Epoch 14/40
# 200/200 [==============================] - 4s 18ms/step - loss: 0.0607 - dice_coef: 0.3838 - val_loss: 0.0555 - val_dice_coef: 0.3432
#
# Epoch 00014: val_loss improved from 0.05614 to 0.05545, saving model to model_softmax_reg_propre.h5
# Epoch 15/40
# 200/200 [==============================] - 4s 19ms/step - loss: 0.0601 - dice_coef: 0.2593 - val_loss: 0.0546 - val_dice_coef: 0.3295
#
# Epoch 00015: val_loss improved from 0.05545 to 0.05461, saving model to model_softmax_reg_propre.h5
# Epoch 16/40
# 200/200 [==============================] - 4s 19ms/step - loss: 0.0595 - dice_coef: 0.2206 - val_loss: 0.0535 - val_dice_coef: 0.3111
#
# Epoch 00016: val_loss improved from 0.05461 to 0.05347, saving model to model_softmax_reg_propre.h5
# Epoch 17/40
# 200/200 [==============================] - 4s 19ms/step - loss: 0.0586 - dice_coef: 0.2558 - val_loss: 0.0519 - val_dice_coef: 0.2872
#
# Epoch 00017: val_loss improved from 0.05347 to 0.05195, saving model to model_softmax_reg_propre.h5
# Epoch 18/40
# 200/200 [==============================] - 4s 19ms/step - loss: 0.0573 - dice_coef: 0.2530 - val_loss: 0.0499 - val_dice_coef: 0.2564
#
# Epoch 00018: val_loss improved from 0.05195 to 0.04991, saving model to model_softmax_reg_propre.h5
# Epoch 19/40
# 200/200 [==============================] - 4s 18ms/step - loss: 0.0560 - dice_coef: 0.2626 - val_loss: 0.0474 - val_dice_coef: 0.2205
#
# Epoch 00019: val_loss improved from 0.04991 to 0.04736, saving model to model_softmax_reg_propre.h5
# Epoch 20/40
# 200/200 [==============================] - 4s 19ms/step - loss: 0.0549 - dice_coef: 0.1530 - val_loss: 0.0452 - val_dice_coef: 0.1972
#
# Epoch 00020: val_loss improved from 0.04736 to 0.04517, saving model to model_softmax_reg_propre.h5
# Epoch 21/40
# 200/200 [==============================] - 4s 18ms/step - loss: 0.0538 - dice_coef: 0.2052 - val_loss: 0.0440 - val_dice_coef: 0.2011
#
# Epoch 00021: val_loss improved from 0.04517 to 0.04401, saving model to model_softmax_reg_propre.h5
# Epoch 22/40
# 200/200 [==============================] - 4s 19ms/step - loss: 0.0527 - dice_coef: 0.2713 - val_loss: 0.0433 - val_dice_coef: 0.2170
#
# Epoch 00022: val_loss improved from 0.04401 to 0.04327, saving model to model_softmax_reg_propre.h5
# Epoch 23/40
# 200/200 [==============================] - 4s 19ms/step - loss: 0.0512 - dice_coef: 0.1553 - val_loss: 0.0411 - val_dice_coef: 0.2195
#
# Epoch 00023: val_loss improved from 0.04327 to 0.04110, saving model to model_softmax_reg_propre.h5
# Epoch 24/40
# 200/200 [==============================] - 4s 19ms/step - loss: 0.0496 - dice_coef: 0.3088 - val_loss: 0.0385 - val_dice_coef: 0.2251
#
# Epoch 00024: val_loss improved from 0.04110 to 0.03846, saving model to model_softmax_reg_propre.h5
# Epoch 25/40
# 200/200 [==============================] - 4s 19ms/step - loss: 0.0475 - dice_coef: 0.1810 - val_loss: 0.0378 - val_dice_coef: 0.2694
#
# Epoch 00025: val_loss improved from 0.03846 to 0.03781, saving model to model_softmax_reg_propre.h5
# Epoch 26/40
# 200/200 [==============================] - 4s 19ms/step - loss: 0.0446 - dice_coef: 0.2587 - val_loss: 0.0344 - val_dice_coef: 0.3038
#
# Epoch 00026: val_loss improved from 0.03781 to 0.03442, saving model to model_softmax_reg_propre.h5
# Epoch 27/40
# 200/200 [==============================] - 4s 19ms/step - loss: 0.0410 - dice_coef: 0.2287 - val_loss: 0.0297 - val_dice_coef: 0.3515
#
# Epoch 00027: val_loss improved from 0.03442 to 0.02967, saving model to model_softmax_reg_propre.h5
# Epoch 28/40
# 200/200 [==============================] - 4s 19ms/step - loss: 0.0367 - dice_coef: 0.3080 - val_loss: 0.0273 - val_dice_coef: 0.4427
#
# Epoch 00028: val_loss improved from 0.02967 to 0.02735, saving model to model_softmax_reg_propre.h5
# Epoch 29/40
# 200/200 [==============================] - 4s 19ms/step - loss: 0.0331 - dice_coef: 0.2253 - val_loss: 0.0199 - val_dice_coef: 0.5399
#
# Epoch 00029: val_loss improved from 0.02735 to 0.01985, saving model to model_softmax_reg_propre.h5
# Epoch 30/40
# 200/200 [==============================] - 4s 19ms/step - loss: 0.0311 - dice_coef: 0.3769 - val_loss: 0.0223 - val_dice_coef: 0.5636
#
# Epoch 00030: val_loss did not improve from 0.01985
# Epoch 31/40
# 200/200 [==============================] - 4s 19ms/step - loss: 0.0290 - dice_coef: 0.4580 - val_loss: 0.0169 - val_dice_coef: 0.6831
#
# Epoch 00031: val_loss improved from 0.01985 to 0.01694, saving model to model_softmax_reg_propre.h5
# Epoch 32/40
# 200/200 [==============================] - 4s 19ms/step - loss: 0.0274 - dice_coef: 0.3260 - val_loss: 0.0183 - val_dice_coef: 0.6669
#
# Epoch 00032: val_loss did not improve from 0.01694
# Epoch 33/40
# 200/200 [==============================] - 4s 19ms/step - loss: 0.0268 - dice_coef: 0.6943 - val_loss: 0.0162 - val_dice_coef: 0.7530
#
# Epoch 00033: val_loss improved from 0.01694 to 0.01624, saving model to model_softmax_reg_propre.h5
# Epoch 34/40
# 200/200 [==============================] - 4s 19ms/step - loss: 0.0257 - dice_coef: 0.5412 - val_loss: 0.0167 - val_dice_coef: 0.7420
#
# Epoch 00034: val_loss did not improve from 0.01624
# Epoch 35/40
# 200/200 [==============================] - 4s 19ms/step - loss: 0.0256 - dice_coef: 0.6493 - val_loss: 0.0155 - val_dice_coef: 0.8165
#
# Epoch 00035: val_loss improved from 0.01624 to 0.01548, saving model to model_softmax_reg_propre.h5
# Epoch 36/40
# 200/200 [==============================] - 4s 19ms/step - loss: 0.0254 - dice_coef: 0.6464 - val_loss: 0.0159 - val_dice_coef: 0.7890
#
# Epoch 00036: val_loss did not improve from 0.01548
# Epoch 37/40
# 200/200 [==============================] - 4s 19ms/step - loss: 0.0246 - dice_coef: 0.6753 - val_loss: 0.0157 - val_dice_coef: 0.8008
#
# Epoch 00037: val_loss did not improve from 0.01548
# Epoch 38/40
# 200/200 [==============================] - 4s 19ms/step - loss: 0.0244 - dice_coef: 0.5028 - val_loss: 0.0156 - val_dice_coef: 0.7997
#
# Epoch 00038: val_loss did not improve from 0.01548
# Epoch 39/40
# 200/200 [==============================] - 4s 19ms/step - loss: 0.0244 - dice_coef: 0.3260 - val_loss: 0.0154 - val_dice_coef: 0.8106
#
# Epoch 00039: val_loss improved from 0.01548 to 0.01536, saving model to model_softmax_reg_propre.h5
# Epoch 40/40
# 200/200 [==============================] - 4s 19ms/step - loss: 0.0241 - dice_coef: 0.8154 - val_loss: 0.0150 - val_dice_coef: 0.8278
#
# Epoch 00040: val_loss improved from 0.01536 to 0.01497, saving model to model_softmax_reg_propre.h5

# %%
plt.subplot(211)
plt.plot(results.history['loss'], label='train')
plt.plot(results.history['val_loss'], label='val')
plt.title('loss')
plt.legend()

plt.subplot(212)
plt.plot(results.history['dice_coef'], label='train')
plt.plot(results.history['val_dice_coef'], label='val')
plt.title('acc')
plt.legend()

# %%
model.load_weights(name)
imgs_train, imgs_mask_train = load_train_data()

# %%
id = 110

test = imgs_train[id,:,:,:]
test -= mean
test /= std
y_pred = model.predict(test.reshape(1,256,256,1))

# %%
plt.figure(figsize=(20, 15))
for i in range(4):
    plt.subplot(1,4,i+1)
    slice_ = imgs_mask_train[id,:,:,i]
    plt.imshow(imgs_train[id,:,:,0])
    plt.imshow(slice_, alpha=0.7)    
plt.show()

# %%
plt.figure(figsize=(20, 15))

for i in range(4):
    plt.subplot(1,4,i+1)
    plt.imshow(imgs_train[id,:,:,0])
    slice_ = y_pred[0,:,:,i]
    x = np.sum(y_pred, axis = 3)[0]
    print(slice_.min(), slice_.max())
    m = slice_.mean()
    plt.imshow(slice_,vmin=0,vmax=1, alpha=0.7)
plt.show()
# Out:
# 0.1648657 0.99998724
# 8.540753e-06 0.32173994
# 3.6098418e-06 0.35842496
# 1.06076875e-07 0.4193004
