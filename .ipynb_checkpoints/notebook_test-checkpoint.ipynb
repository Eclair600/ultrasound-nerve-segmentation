# %%
import numpy as np
import matplotlib.pyplot as plt
from skimage.transform import resize # from scipy.misc import imresize
from tqdm import tqdm
import nibabel

# %%
def read_train_exam(exam_nb):
    image = nibabel.load('../chaos/train/%02d-T2SPIR-src.nii.gz'%(exam_nb))
    mask = nibabel.load('../chaos/train/%02d-T2SPIR-mask.nii.gz'%(exam_nb))
    return image, mask

def read_test_exam(exam_nb):
    image = nibabel.load('../chaos/test/%02d-T2SPIR-src.nii.gz'%(exam_nb))
    return image

# %%
img_rows,img_cols = 256,256
def preprocess(image):
    #shape (slide,256,256)
    image_ = np.ndarray((image.shape[2],img_rows,img_cols,1))
    for i in range(image.shape[2]):
        image_[i,:,:,0] = resize(image.get_data()[:,:,i],(img_rows,img_cols),mode='reflect',preserve_range=True,
                               anti_aliasing=True)            
    #print(image_.shape)
    return image_

# %%
image_1, mask_1 = read_train_exam(2)

# %%
print("before scale {},{},".format(np.unique(mask_1.get_data()),np.unique(image_1.get_data())))
# Out:
# before scale [0 1 2 3 4],[   0    1    2 ... 1474 1501 1503],

# %%
print("after scale {},{}".format(np.unique(preprocess(mask_1)),np.unique(preprocess(image_1))))
# Out:
# after scale [0.       0.015625 0.015625 ... 3.984375 3.984375 4.      ],[0.00000000e+00 1.56250000e-02 1.56250000e-02 ... 1.45790625e+03
#  1.46843750e+03 1.48428125e+03]

# %%
def mask_to_channels(mask,init,classes):
    #get mask for each class
    img = np.asarray([np.where(mask == i,1,0 ) for i in range(init,classes)])
    img = np.swapaxes(img,0,-1)#new shape (row,col,class)
    print(img.shape)
    return img

# %%
test = mask_1.get_data()[:,:,15]
img = mask_to_channels(test,0,5)
for i in range(0,5):
    plt.subplot(1,5,i+1)
    plt.imshow(img[:,:,i])
plt.show()

# %%
def create_data_train(train_ids = [1,2,3,5,8,10,13,19],background = 0):
    for idx, train_id in tqdm(enumerate(train_ids)):
        image, mask = read_train_exam(train_id)     
        image = preprocess(image)
        mask = preprocess(mask) 
        #transform le mask
        if background:
            #create mask for 5 classess
            mask = mask_to_channels(mask,0,5)[0]
        else:
            mask = mask_to_channels(mask,1,5)[0]            
       
        if idx > 0:
            train_data = np.concatenate((train_data, image),axis=0)
            train_mask = np.concatenate((train_mask, mask),axis=0)
        else:
            train_data = image
            train_mask = mask
    print("Final shape {},{}".format(train_data.shape,train_mask.shape))    
    np.savez_compressed('./dataset/imgs_train_{}'.format(background), imgs=train_data)
    np.savez_compressed('./dataset/imgs_mask_train_{}'.format(background), imgs_mask=train_mask)

# %%
#dataset training without background
create_data_train()
# Out:
# 1it [00:00,  3.35it/s]
# (1, 36, 256, 256, 4)
# 2it [00:00,  3.18it/s]
# (1, 26, 256, 256, 4)
# 3it [00:01,  2.44it/s]
# (1, 30, 256, 256, 4)
# 4it [00:01,  2.46it/s]
# (1, 30, 256, 256, 4)
# 5it [00:02,  2.29it/s]
# (1, 32, 256, 256, 4)
# (1, 36, 256, 256, 4)
# 6it [00:02,  2.14it/s]
# (1, 30, 256, 256, 4)
# 7it [00:03,  1.94it/s]
# (1, 30, 256, 256, 4)
# 8it [00:04,  1.71it/s]
# Final shape (250, 256, 256, 1),(250, 256, 256, 4)

# %%
#dataset training without background
create_data_train(background=1)
# Out:
# 1it [00:00,  3.06it/s]
# (1, 36, 256, 256, 5)
# 2it [00:00,  2.92it/s]
# (1, 26, 256, 256, 5)
# 3it [00:01,  2.61it/s]
# (1, 30, 256, 256, 5)
# 4it [00:01,  2.50it/s]
# (1, 30, 256, 256, 5)
# (1, 32, 256, 256, 5)
# 5it [00:02,  2.23it/s]
# (1, 36, 256, 256, 5)
# 6it [00:02,  2.03it/s]
# (1, 30, 256, 256, 5)
# 7it [00:03,  1.84it/s]
# (1, 30, 256, 256, 5)
# 8it [00:04,  1.68it/s]
# Final shape (250, 256, 256, 1),(250, 256, 256, 5)

# %% [markdown]
# ### plot images

# %%
img = np.load('./dataset/imgs_train_0.npz')['imgs']
img_mask = np.load('./dataset/imgs_mask_train_0.npz')['imgs_mask']

# %%
img[:,:,:].shape
# Out:
# (250, 256, 256, 1)

# %%
img[:,:,:,0].shape
# Out:
# (250, 256, 256)

# %%
#plot random samples from data
def plot_random_images(data,mask,size,id):
    index = np.random.choice(range(data.shape[0]),size)
    plt.figure(figsize=(20, 15))
    for i,x in enumerate(index):
        plt.subplot(1, len(index), i+1)
        plt.imshow(data[x,:,:,0], cmap='gray', interpolation='nearest')
        plt.imshow(mask[x,:,:,id], cmap='jet', alpha=0.5)
    plt.show()

# %%
#plot random samples from training data
print("Training data")
plot_random_images(img,img_mask,5,1)
# Out:
# Training data

# %%
plot_random_images(img,img_mask,5,3)

# %%
print(np.unique(img))
# Out:
# [0.00000000e+00 1.00974196e-28 1.51461294e-28 ... 2.02000000e+03
#  2.04100000e+03 2.04300000e+03]

# %%
imgs_train = img.astype('float32')
mean = np.mean(imgs_train)  # mean for data centering
std = np.std(imgs_train)  # std for data normalization

imgs_train -= mean
imgs_train /= std

# %%
print(np.unique(imgs_train))
# Out:
# [-0.53052306 -0.53049946 -0.53047585 ... 11.664149   11.790925
#  11.8029995 ]

# %% [markdown]
# ### test

# %%
def get_data_test(test_ids = [21,22,32,39]):
    for idx, test_id in tqdm(enumerate(test_ids)):
        image = read_test_exam(test_id)     
        image = preprocess(image)
        print("img {}".format(image.shape))
        if idx > 0:
            test_data = np.concatenate((test_data, image),axis=0)
        else:
            test_data = image
    print("Final shape {}".format(test_data.shape))    
    np.savez_compressed('./dataset/imgs_test', imgs=test_data)

# %%
get_data_test()
# Out:
# 2it [00:00,  8.78it/s]
# img (31, 256, 256, 1)
# img (33, 256, 256, 1)
# 4it [00:00,  8.10it/s]
# img (39, 256, 256, 1)
# img (26, 256, 256, 1)
# Final shape (129, 256, 256, 1)

# %% [markdown]
# # MODEL

# %%
#version tf1
from keras.models import Model
from keras.layers import Input, concatenate, Conv2D, MaxPooling2D, Conv2DTranspose
from keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint
from keras import backend as K


from data import load_train_data, load_test_data

K.set_image_data_format('channels_last')  # TF dimension ordering in this code
# Out:
# Using TensorFlow backend.

# %%
img_rows = 256
img_cols = 256

# %%
smooth = 1.
#batch 32!
def dice_coef_(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)
def dice_coef(y_true, y_pred):
    dice_liver = dice_coef_(y_true[0,:,:,0],y_pred[0,:,:,0])
    dice_rkidney = dice_coef_(y_true[0,:,:,1], y_pred[0,:,:,1])
    dice_lkidney = dice_coef_(y_true[0,:,:,2], y_pred[0,:,:,2])
    dice_spleen = dice_coef_(y_true[0,:,:,3], y_pred[0,:,:,3])
    #return dice_liver + (dice_rkidney+dice_lkidney)+dice_spleen
    return dice_liver + 10*dice_rkidney + 10*dice_lkidney +5*dice_spleen
def dice_coef_loss(y_true, y_pred):  
    return -dice_coef_(y_true, y_pred)

# %%
def get_unet():
    inputs = Input((img_rows, img_cols, 1))
    conv1 = Conv2D(32, (3, 3), activation='relu', padding='same')(inputs)
    conv1 = Conv2D(32, (3, 3), activation='relu', padding='same')(conv1)
    pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)

    conv2 = Conv2D(64, (3, 3), activation='relu', padding='same')(pool1)
    conv2 = Conv2D(64, (3, 3), activation='relu', padding='same')(conv2)
    pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)

    conv3 = Conv2D(128, (3, 3), activation='relu', padding='same')(pool2)
    conv3 = Conv2D(128, (3, 3), activation='relu', padding='same')(conv3)
    pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)

    conv4 = Conv2D(256, (3, 3), activation='relu', padding='same')(pool3)
    conv4 = Conv2D(256, (3, 3), activation='relu', padding='same')(conv4)
    pool4 = MaxPooling2D(pool_size=(2, 2))(conv4)

    conv5 = Conv2D(512, (3, 3), activation='relu', padding='same')(pool4)
    conv5 = Conv2D(512, (3, 3), activation='relu', padding='same')(conv5)

    up6 = concatenate([Conv2DTranspose(256, (2, 2), strides=(2, 2), padding='same')(conv5), conv4], axis=3)
    conv6 = Conv2D(256, (3, 3), activation='relu', padding='same')(up6)
    conv6 = Conv2D(256, (3, 3), activation='relu', padding='same')(conv6)

    up7 = concatenate([Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same')(conv6), conv3], axis=3)
    conv7 = Conv2D(128, (3, 3), activation='relu', padding='same')(up7)
    conv7 = Conv2D(128, (3, 3), activation='relu', padding='same')(conv7)

    up8 = concatenate([Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(conv7), conv2], axis=3)
    conv8 = Conv2D(64, (3, 3), activation='relu', padding='same')(up8)
    conv8 = Conv2D(64, (3, 3), activation='relu', padding='same')(conv8)

    up9 = concatenate([Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same')(conv8), conv1], axis=3)
    conv9 = Conv2D(32, (3, 3), activation='relu', padding='same')(up9)
    conv9 = Conv2D(32, (3, 3), activation='relu', padding='same')(conv9)

    conv10 = Conv2D(4,(1, 1), activation='sigmoid')(conv9)

    model = Model(inputs=[inputs], outputs=[conv10])

    model.compile(optimizer=Adam(lr=1e-5), loss=dice_coef_loss, metrics=[dice_coef])

    return model

# %%
from data import load_train_data, load_test_data

# %% [markdown]
# # training

# %%
print('Loading and preprocessing train data...')
print('-'*30)
imgs_train, imgs_mask_train = load_train_data()
name = 'model_test_dice-80.h5'

checkpoint = ModelCheckpoint(name, verbose=1, save_best_only=True, save_weights_only=True)
model = get_unet()
model.summary()

imgs_train = imgs_train.astype('float32')
mean = np.mean(imgs_train)  # mean for data centering
std = np.std(imgs_train)  # std for data normalization
imgs_train -= mean
imgs_train /= std
print("normalize")
np.savez_compressed('scaler',mean=mean,std=std)

results = model.fit(imgs_train, imgs_mask_train, batch_size=32, epochs=100, callbacks=[checkpoint]
                   ,shuffle=True,
              validation_split=0.2)
# Out:
# Loading and preprocessing train data...
# ------------------------------
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_9 (InputLayer)            (None, 256, 256, 1)  0
# __________________________________________________________________________________________________
# conv2d_153 (Conv2D)             (None, 256, 256, 32) 320         input_9[0][0]
# __________________________________________________________________________________________________
# conv2d_154 (Conv2D)             (None, 256, 256, 32) 9248        conv2d_153[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_33 (MaxPooling2D) (None, 128, 128, 32) 0           conv2d_154[0][0]
# __________________________________________________________________________________________________
# conv2d_155 (Conv2D)             (None, 128, 128, 64) 18496       max_pooling2d_33[0][0]
# __________________________________________________________________________________________________
# conv2d_156 (Conv2D)             (None, 128, 128, 64) 36928       conv2d_155[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_34 (MaxPooling2D) (None, 64, 64, 64)   0           conv2d_156[0][0]
# __________________________________________________________________________________________________
# conv2d_157 (Conv2D)             (None, 64, 64, 128)  73856       max_pooling2d_34[0][0]
# __________________________________________________________________________________________________
# conv2d_158 (Conv2D)             (None, 64, 64, 128)  147584      conv2d_157[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_35 (MaxPooling2D) (None, 32, 32, 128)  0           conv2d_158[0][0]
# __________________________________________________________________________________________________
# conv2d_159 (Conv2D)             (None, 32, 32, 256)  295168      max_pooling2d_35[0][0]
# __________________________________________________________________________________________________
# conv2d_160 (Conv2D)             (None, 32, 32, 256)  590080      conv2d_159[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_36 (MaxPooling2D) (None, 16, 16, 256)  0           conv2d_160[0][0]
# __________________________________________________________________________________________________
# conv2d_161 (Conv2D)             (None, 16, 16, 512)  1180160     max_pooling2d_36[0][0]
# __________________________________________________________________________________________________
# conv2d_162 (Conv2D)             (None, 16, 16, 512)  2359808     conv2d_161[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_33 (Conv2DTran (None, 32, 32, 256)  524544      conv2d_162[0][0]
# __________________________________________________________________________________________________
# concatenate_33 (Concatenate)    (None, 32, 32, 512)  0           conv2d_transpose_33[0][0]
#                                                                  conv2d_160[0][0]
# __________________________________________________________________________________________________
# conv2d_163 (Conv2D)             (None, 32, 32, 256)  1179904     concatenate_33[0][0]
# __________________________________________________________________________________________________
# conv2d_164 (Conv2D)             (None, 32, 32, 256)  590080      conv2d_163[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_34 (Conv2DTran (None, 64, 64, 128)  131200      conv2d_164[0][0]
# __________________________________________________________________________________________________
# concatenate_34 (Concatenate)    (None, 64, 64, 256)  0           conv2d_transpose_34[0][0]
#                                                                  conv2d_158[0][0]
# __________________________________________________________________________________________________
# conv2d_165 (Conv2D)             (None, 64, 64, 128)  295040      concatenate_34[0][0]
# __________________________________________________________________________________________________
# conv2d_166 (Conv2D)             (None, 64, 64, 128)  147584      conv2d_165[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_35 (Conv2DTran (None, 128, 128, 64) 32832       conv2d_166[0][0]
# __________________________________________________________________________________________________
# concatenate_35 (Concatenate)    (None, 128, 128, 128 0           conv2d_transpose_35[0][0]
#                                                                  conv2d_156[0][0]
# __________________________________________________________________________________________________
# conv2d_167 (Conv2D)             (None, 128, 128, 64) 73792       concatenate_35[0][0]
# __________________________________________________________________________________________________
# conv2d_168 (Conv2D)             (None, 128, 128, 64) 36928       conv2d_167[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_36 (Conv2DTran (None, 256, 256, 32) 8224        conv2d_168[0][0]
# __________________________________________________________________________________________________
# concatenate_36 (Concatenate)    (None, 256, 256, 64) 0           conv2d_transpose_36[0][0]
#                                                                  conv2d_154[0][0]
# __________________________________________________________________________________________________
# conv2d_169 (Conv2D)             (None, 256, 256, 32) 18464       concatenate_36[0][0]
# __________________________________________________________________________________________________
# conv2d_170 (Conv2D)             (None, 256, 256, 32) 9248        conv2d_169[0][0]
# __________________________________________________________________________________________________
# conv2d_171 (Conv2D)             (None, 256, 256, 4)  132         conv2d_170[0][0]
# ==================================================================================================
# Total params: 7,759,620
# Trainable params: 7,759,620
# Non-trainable params: 0
# __________________________________________________________________________________________________
# normalize
# Train on 200 samples, validate on 50 samples
# Epoch 1/100
# 200/200 [==============================] - 5s 27ms/step - loss: -0.0230 - dice_coef: 0.2406 - val_loss: -0.0218 - val_dice_coef: 0.4405
#
# Epoch 00001: val_loss improved from inf to -0.02178, saving model to model_test_dice-80.h5
# Epoch 2/100
# 200/200 [==============================] - 3s 17ms/step - loss: -0.0231 - dice_coef: 0.1585 - val_loss: -0.0219 - val_dice_coef: 0.4425
#
# Epoch 00002: val_loss improved from -0.02178 to -0.02192, saving model to model_test_dice-80.h5
# Epoch 3/100
# 200/200 [==============================] - 3s 17ms/step - loss: -0.0232 - dice_coef: 0.1535 - val_loss: -0.0221 - val_dice_coef: 0.4446
#
# Epoch 00003: val_loss improved from -0.02192 to -0.02206, saving model to model_test_dice-80.h5
# Epoch 4/100
# 200/200 [==============================] - 3s 17ms/step - loss: -0.0234 - dice_coef: 0.3095 - val_loss: -0.0222 - val_dice_coef: 0.4464
# Epoch 00004: val_loss improved from -0.02206 to -0.02221, saving model to model_test_dice-80.h5
# Epoch 5/100
# 200/200 [==============================] - 3s 17ms/step - loss: -0.0235 - dice_coef: 0.2309 - val_loss: -0.0224 - val_dice_coef: 0.4483
#
# Epoch 00005: val_loss improved from -0.02221 to -0.02236, saving model to model_test_dice-80.h5
# Epoch 6/100
# 200/200 [==============================] - 3s 17ms/step - loss: -0.0236 - dice_coef: 0.2498 - val_loss: -0.0225 - val_dice_coef: 0.4502
#
# Epoch 00006: val_loss improved from -0.02236 to -0.02252, saving model to model_test_dice-80.h5
# Epoch 7/100
# 200/200 [==============================] - 3s 17ms/step - loss: -0.0238 - dice_coef: 0.1469 - val_loss: -0.0227 - val_dice_coef: 0.4523
#
# Epoch 00007: val_loss improved from -0.02252 to -0.02269, saving model to model_test_dice-80.h5
# Epoch 8/100
# 200/200 [==============================] - 3s 17ms/step - loss: -0.0240 - dice_coef: 0.3663 - val_loss: -0.0229 - val_dice_coef: 0.4546
#
# Epoch 00008: val_loss improved from -0.02269 to -0.02287, saving model to model_test_dice-80.h5
# Epoch 9/100
# 200/200 [==============================] - 3s 17ms/step - loss: -0.0241 - dice_coef: 0.2859 - val_loss: -0.0231 - val_dice_coef: 0.4572
#
# Epoch 00009: val_loss improved from -0.02287 to -0.02305, saving model to model_test_dice-80.h5
# Epoch 10/100
# 200/200 [==============================] - 3s 17ms/step - loss: -0.0243 - dice_coef: 0.3251 - val_loss: -0.0232 - val_dice_coef: 0.4600
#
# Epoch 00010: val_loss improved from -0.02305 to -0.02325, saving model to model_test_dice-80.h5
# Epoch 11/100
# 200/200 [==============================] - 3s 17ms/step - loss: -0.0244 - dice_coef: 0.3126 - val_loss: -0.0234 - val_dice_coef: 0.4632
#
# Epoch 00011: val_loss improved from -0.02325 to -0.02345, saving model to model_test_dice-80.h5
# Epoch 12/100
# 200/200 [==============================] - 3s 17ms/step - loss: -0.0246 - dice_coef: 0.2349 - val_loss: -0.0237 - val_dice_coef: 0.4668
#
# Epoch 00012: val_loss improved from -0.02345 to -0.02367, saving model to model_test_dice-80.h5
# Epoch 13/100
# 200/200 [==============================] - 3s 17ms/step - loss: -0.0248 - dice_coef: 0.3516 - val_loss: -0.0239 - val_dice_coef: 0.4707
#
# Epoch 00013: val_loss improved from -0.02367 to -0.02391, saving model to model_test_dice-80.h5
# Epoch 14/100
# 200/200 [==============================] - 3s 17ms/step - loss: -0.0250 - dice_coef: 0.3716 - val_loss: -0.0242 - val_dice_coef: 0.4751
#
# Epoch 00014: val_loss improved from -0.02391 to -0.02417, saving model to model_test_dice-80.h5
# Epoch 15/100
# 200/200 [==============================] - 4s 18ms/step - loss: -0.0253 - dice_coef: 0.3644 - val_loss: -0.0245 - val_dice_coef: 0.4800
#
# Epoch 00015: val_loss improved from -0.02417 to -0.02447, saving model to model_test_dice-80.h5
# Epoch 16/100
# 200/200 [==============================] - 3s 17ms/step - loss: -0.0255 - dice_coef: 0.1672 - val_loss: -0.0248 - val_dice_coef: 0.4854
#
# Epoch 00016: val_loss improved from -0.02447 to -0.02481, saving model to model_test_dice-80.h5
# Epoch 17/100
# 200/200 [==============================] - 3s 17ms/step - loss: -0.0258 - dice_coef: 0.2065 - val_loss: -0.0252 - val_dice_coef: 0.4912
#
# Epoch 00017: val_loss improved from -0.02481 to -0.02521, saving model to model_test_dice-80.h5
# Epoch 18/100
# 200/200 [==============================] - 3s 17ms/step - loss: -0.0263 - dice_coef: 0.1158 - val_loss: -0.0257 - val_dice_coef: 0.4982
#
# Epoch 00018: val_loss improved from -0.02521 to -0.02570, saving model to model_test_dice-80.h5
# Epoch 19/100
# 200/200 [==============================] - 3s 17ms/step - loss: -0.0267 - dice_coef: 0.3908 - val_loss: -0.0263 - val_dice_coef: 0.5065
#
# Epoch 00019: val_loss improved from -0.02570 to -0.02630, saving model to model_test_dice-80.h5
# Epoch 20/100
# 200/200 [==============================] - 3s 17ms/step - loss: -0.0273 - dice_coef: 0.2697 - val_loss: -0.0270 - val_dice_coef: 0.5167
#
# Epoch 00020: val_loss improved from -0.02630 to -0.02702, saving model to model_test_dice-80.h5
# Epoch 21/100
# 200/200 [==============================] - 3s 17ms/step - loss: -0.0280 - dice_coef: 0.2279 - val_loss: -0.0279 - val_dice_coef: 0.5288
#
# Epoch 00021: val_loss improved from -0.02702 to -0.02788, saving model to model_test_dice-80.h5
# Epoch 22/100
# 200/200 [==============================] - 3s 17ms/step - loss: -0.0288 - dice_coef: 0.3712 - val_loss: -0.0289 - val_dice_coef: 0.5434
#
# Epoch 00022: val_loss improved from -0.02788 to -0.02894, saving model to model_test_dice-80.h5
# Epoch 23/100
# 200/200 [==============================] - 3s 17ms/step - loss: -0.0298 - dice_coef: 0.2427 - val_loss: -0.0302 - val_dice_coef: 0.5609
#
# Epoch 00023: val_loss improved from -0.02894 to -0.03021, saving model to model_test_dice-80.h5
# Epoch 24/100
# 200/200 [==============================] - 3s 17ms/step - loss: -0.0310 - dice_coef: 0.1317 - val_loss: -0.0317 - val_dice_coef: 0.5816
#
# Epoch 00024: val_loss improved from -0.03021 to -0.03174, saving model to model_test_dice-80.h5
# Epoch 25/100
# 200/200 [==============================] - 3s 17ms/step - loss: -0.0325 - dice_coef: 0.6014 - val_loss: -0.0333 - val_dice_coef: 0.6051
#
# Epoch 00025: val_loss improved from -0.03174 to -0.03335, saving model to model_test_dice-80.h5
# Epoch 26/100
# 200/200 [==============================] - 3s 17ms/step - loss: -0.0340 - dice_coef: 0.3373 - val_loss: -0.0346 - val_dice_coef: 0.6329
#
# Epoch 00026: val_loss improved from -0.03335 to -0.03455, saving model to model_test_dice-80.h5
# Epoch 27/100
# 200/200 [==============================] - 3s 17ms/step - loss: -0.0351 - dice_coef: 0.1437 - val_loss: -0.0351 - val_dice_coef: 0.6594
#
# Epoch 00027: val_loss improved from -0.03455 to -0.03505, saving model to model_test_dice-80.h5
# Epoch 28/100
# 200/200 [==============================] - 4s 18ms/step - loss: -0.0358 - dice_coef: 0.0867 - val_loss: -0.0354 - val_dice_coef: 0.6846
#
# Epoch 00028: val_loss improved from -0.03505 to -0.03538, saving model to model_test_dice-80.h5
# Epoch 29/100
# 200/200 [==============================] - 3s 17ms/step - loss: -0.0363 - dice_coef: 0.2376 - val_loss: -0.0358 - val_dice_coef: 0.6992
#
# Epoch 00029: val_loss improved from -0.03538 to -0.03579, saving model to model_test_dice-80.h5
# Epoch 30/100
# 200/200 [==============================] - 3s 17ms/step - loss: -0.0367 - dice_coef: 0.3135 - val_loss: -0.0361 - val_dice_coef: 0.7093
#
# Epoch 00030: val_loss improved from -0.03579 to -0.03606, saving model to model_test_dice-80.h5
# Epoch 31/100
# 200/200 [==============================] - 3s 17ms/step - loss: -0.0370 - dice_coef: 0.1578 - val_loss: -0.0363 - val_dice_coef: 0.7171
#
# Epoch 00031: val_loss improved from -0.03606 to -0.03627, saving model to model_test_dice-80.h5
# Epoch 32/100
# 200/200 [==============================] - 4s 18ms/step - loss: -0.0373 - dice_coef: 0.5583 - val_loss: -0.0365 - val_dice_coef: 0.7237
#
# Epoch 00032: val_loss improved from -0.03627 to -0.03646, saving model to model_test_dice-80.h5
# Epoch 33/100
# 200/200 [==============================] - 3s 17ms/step - loss: -0.0375 - dice_coef: 0.1253 - val_loss: -0.0366 - val_dice_coef: 0.7294
#
# Epoch 00033: val_loss improved from -0.03646 to -0.03664, saving model to model_test_dice-80.h5
# Epoch 34/100
# 200/200 [==============================] - 3s 17ms/step - loss: -0.0377 - dice_coef: 0.2264 - val_loss: -0.0369 - val_dice_coef: 0.7341
#
# Epoch 00034: val_loss improved from -0.03664 to -0.03688, saving model to model_test_dice-80.h5
# Epoch 35/100
# 200/200 [==============================] - 3s 17ms/step - loss: -0.0379 - dice_coef: 0.3414 - val_loss: -0.0372 - val_dice_coef: 0.7373
#
# Epoch 00035: val_loss improved from -0.03688 to -0.03715, saving model to model_test_dice-80.h5
# Epoch 36/100
# 200/200 [==============================] - 3s 17ms/step - loss: -0.0381 - dice_coef: 0.4352 - val_loss: -0.0374 - val_dice_coef: 0.7475
#
# Epoch 00036: val_loss improved from -0.03715 to -0.03737, saving model to model_test_dice-80.h5
# Epoch 37/100
# 200/200 [==============================] - 4s 18ms/step - loss: -0.0384 - dice_coef: 0.3500 - val_loss: -0.0377 - val_dice_coef: 0.7593
#
# Epoch 00037: val_loss improved from -0.03737 to -0.03767, saving model to model_test_dice-80.h5
# Epoch 38/100
# 200/200 [==============================] - 3s 17ms/step - loss: -0.0389 - dice_coef: 0.5294 - val_loss: -0.0380 - val_dice_coef: 0.7753
#
# Epoch 00038: val_loss improved from -0.03767 to -0.03805, saving model to model_test_dice-80.h5
# Epoch 39/100
# 200/200 [==============================] - 3s 17ms/step - loss: -0.0392 - dice_coef: 0.4156 - val_loss: -0.0383 - val_dice_coef: 0.7913
#
# Epoch 00039: val_loss improved from -0.03805 to -0.03826, saving model to model_test_dice-80.h5
# Epoch 40/100
# 200/200 [==============================] - 3s 17ms/step - loss: -0.0396 - dice_coef: 0.4413 - val_loss: -0.0384 - val_dice_coef: 0.8017
#
# Epoch 00040: val_loss improved from -0.03826 to -0.03838, saving model to model_test_dice-80.h5
# Epoch 41/100
# 200/200 [==============================] - 4s 18ms/step - loss: -0.0399 - dice_coef: 0.4548 - val_loss: -0.0389 - val_dice_coef: 0.8140
#
# Epoch 00041: val_loss improved from -0.03838 to -0.03889, saving model to model_test_dice-80.h5
# Epoch 42/100
# 200/200 [==============================] - 3s 17ms/step - loss: -0.0403 - dice_coef: 0.7667 - val_loss: -0.0393 - val_dice_coef: 0.8224
#
# Epoch 00042: val_loss improved from -0.03889 to -0.03928, saving model to model_test_dice-80.h5
# Epoch 43/100
# 200/200 [==============================] - 3s 17ms/step - loss: -0.0407 - dice_coef: 0.5084 - val_loss: -0.0396 - val_dice_coef: 0.8438
#
# Epoch 00043: val_loss improved from -0.03928 to -0.03965, saving model to model_test_dice-80.h5
# Epoch 44/100
# 200/200 [==============================] - 4s 18ms/step - loss: -0.0415 - dice_coef: 0.5078 - val_loss: -0.0405 - val_dice_coef: 0.8903
#
# Epoch 00044: val_loss improved from -0.03965 to -0.04047, saving model to model_test_dice-80.h5
# Epoch 45/100
# 200/200 [==============================] - 3s 17ms/step - loss: -0.0428 - dice_coef: 0.6001 - val_loss: -0.0413 - val_dice_coef: 0.9640
#
# Epoch 00045: val_loss improved from -0.04047 to -0.04127, saving model to model_test_dice-80.h5
# Epoch 46/100
# 200/200 [==============================] - 4s 18ms/step - loss: -0.0452 - dice_coef: 0.5844 - val_loss: -0.0457 - val_dice_coef: 1.1361
#
# Epoch 00046: val_loss improved from -0.04127 to -0.04567, saving model to model_test_dice-80.h5
# Epoch 47/100
# 200/200 [==============================] - 3s 17ms/step - loss: -0.0494 - dice_coef: 0.7854 - val_loss: -0.0507 - val_dice_coef: 1.4174
#
# Epoch 00047: val_loss improved from -0.04567 to -0.05067, saving model to model_test_dice-80.h5
# Epoch 48/100
# 200/200 [==============================] - 4s 18ms/step - loss: -0.0567 - dice_coef: 0.8028 - val_loss: -0.0625 - val_dice_coef: 1.8610
#
# Epoch 00048: val_loss improved from -0.05067 to -0.06252, saving model to model_test_dice-80.h5
# Epoch 49/100
# 200/200 [==============================] - 4s 18ms/step - loss: -0.0701 - dice_coef: 1.2961 - val_loss: -0.0877 - val_dice_coef: 2.5779
#
# Epoch 00049: val_loss improved from -0.06252 to -0.08765, saving model to model_test_dice-80.h5
# Epoch 50/100
# 200/200 [==============================] - 4s 18ms/step - loss: -0.1008 - dice_coef: 1.6788 - val_loss: -0.1427 - val_dice_coef: 5.1392
#
# Epoch 00050: val_loss improved from -0.08765 to -0.14273, saving model to model_test_dice-80.h5
# Epoch 51/100
# 200/200 [==============================] - 4s 18ms/step - loss: -0.1538 - dice_coef: 2.1929 - val_loss: -0.2273 - val_dice_coef: 5.2557
#
# Epoch 00051: val_loss improved from -0.14273 to -0.22732, saving model to model_test_dice-80.h5
# Epoch 52/100
# 200/200 [==============================] - 3s 17ms/step - loss: -0.2027 - dice_coef: 1.3401 - val_loss: -0.2912 - val_dice_coef: 3.8164
#
# Epoch 00052: val_loss improved from -0.22732 to -0.29120, saving model to model_test_dice-80.h5
# Epoch 53/100
# 200/200 [==============================] - 3s 17ms/step - loss: -0.2523 - dice_coef: 1.8911 - val_loss: -0.3454 - val_dice_coef: 5.4336
#
# Epoch 00053: val_loss improved from -0.29120 to -0.34545, saving model to model_test_dice-80.h5
# Epoch 54/100
# 200/200 [==============================] - 3s 17ms/step - loss: -0.2951 - dice_coef: 0.4999 - val_loss: -0.3940 - val_dice_coef: 4.9250
#
# Epoch 00054: val_loss improved from -0.34545 to -0.39401, saving model to model_test_dice-80.h5
# Epoch 55/100
# 200/200 [==============================] - 3s 17ms/step - loss: -0.3301 - dice_coef: 1.1901 - val_loss: -0.4320 - val_dice_coef: 3.9810
#
# Epoch 00055: val_loss improved from -0.39401 to -0.43204, saving model to model_test_dice-80.h5
# Epoch 56/100
# 200/200 [==============================] - 4s 18ms/step - loss: -0.3549 - dice_coef: 1.4296 - val_loss: -0.4535 - val_dice_coef: 2.1687
#
# Epoch 00056: val_loss improved from -0.43204 to -0.45346, saving model to model_test_dice-80.h5
# Epoch 57/100
# 200/200 [==============================] - 4s 18ms/step - loss: -0.3528 - dice_coef: 1.0429 - val_loss: -0.4699 - val_dice_coef: 0.4247
#
# Epoch 00057: val_loss improved from -0.45346 to -0.46988, saving model to model_test_dice-80.h5
# Epoch 58/100
# 200/200 [==============================] - 4s 18ms/step - loss: -0.3804 - dice_coef: 1.5042 - val_loss: -0.4801 - val_dice_coef: 0.4432
#
# Epoch 00058: val_loss improved from -0.46988 to -0.48011, saving model to model_test_dice-80.h5
# Epoch 59/100
# 200/200 [==============================] - 4s 18ms/step - loss: -0.3885 - dice_coef: 1.9172 - val_loss: -0.4842 - val_dice_coef: 0.5085
#
# Epoch 00059: val_loss improved from -0.48011 to -0.48421, saving model to model_test_dice-80.h5
# Epoch 60/100
# 200/200 [==============================] - 3s 17ms/step - loss: -0.4060 - dice_coef: 2.3751 - val_loss: -0.5069 - val_dice_coef: 0.5964
#
# Epoch 00060: val_loss improved from -0.48421 to -0.50693, saving model to model_test_dice-80.h5
# Epoch 61/100
# 200/200 [==============================] - 4s 18ms/step - loss: -0.4123 - dice_coef: 1.5739 - val_loss: -0.5212 - val_dice_coef: 0.5879
#
# Epoch 00061: val_loss improved from -0.50693 to -0.52116, saving model to model_test_dice-80.h5
# Epoch 62/100
# 200/200 [==============================] - 4s 18ms/step - loss: -0.4155 - dice_coef: 3.5680 - val_loss: -0.5138 - val_dice_coef: 0.6545
#
# Epoch 00062: val_loss did not improve from -0.52116
# Epoch 63/100
# 200/200 [==============================] - 4s 18ms/step - loss: -0.4150 - dice_coef: 3.3829 - val_loss: -0.5669 - val_dice_coef: 0.7537
#
# Epoch 00063: val_loss improved from -0.52116 to -0.56691, saving model to model_test_dice-80.h5
# Epoch 64/100
# 200/200 [==============================] - 4s 18ms/step - loss: -0.4392 - dice_coef: 3.9279 - val_loss: -0.5867 - val_dice_coef: 0.7987
#
# Epoch 00064: val_loss improved from -0.56691 to -0.58673, saving model to model_test_dice-80.h5
# Epoch 65/100
# 200/200 [==============================] - 3s 17ms/step - loss: -0.4585 - dice_coef: 4.1936 - val_loss: -0.5774 - val_dice_coef: 0.8369
#
# Epoch 00065: val_loss did not improve from -0.58673
# Epoch 66/100
# 200/200 [==============================] - 4s 18ms/step - loss: -0.4659 - dice_coef: 4.4435 - val_loss: -0.6045 - val_dice_coef: 0.9068
#
# Epoch 00066: val_loss improved from -0.58673 to -0.60453, saving model to model_test_dice-80.h5
# Epoch 67/100
# 200/200 [==============================] - 3s 17ms/step - loss: -0.4767 - dice_coef: 5.5830 - val_loss: -0.6111 - val_dice_coef: 0.9668
#
# Epoch 00067: val_loss improved from -0.60453 to -0.61114, saving model to model_test_dice-80.h5
# Epoch 68/100
# 200/200 [==============================] - 4s 18ms/step - loss: -0.4774 - dice_coef: 4.2675 - val_loss: -0.6173 - val_dice_coef: 1.0391
#
# Epoch 00068: val_loss improved from -0.61114 to -0.61730, saving model to model_test_dice-80.h5
# Epoch 69/100
# 200/200 [==============================] - 4s 18ms/step - loss: -0.4884 - dice_coef: 2.1095 - val_loss: -0.6152 - val_dice_coef: 1.0918
#
# Epoch 00069: val_loss did not improve from -0.61730
# Epoch 70/100
# 200/200 [==============================] - 4s 18ms/step - loss: -0.4895 - dice_coef: 4.7915 - val_loss: -0.6247 - val_dice_coef: 1.1319
#
# Epoch 00070: val_loss improved from -0.61730 to -0.62469, saving model to model_test_dice-80.h5
# Epoch 71/100
# 200/200 [==============================] - 3s 17ms/step - loss: -0.4760 - dice_coef: 5.4648 - val_loss: -0.6311 - val_dice_coef: 1.1400
#
# Epoch 00071: val_loss improved from -0.62469 to -0.63106, saving model to model_test_dice-80.h5
# Epoch 72/100
# 200/200 [==============================] - 3s 17ms/step - loss: -0.4970 - dice_coef: 6.0374 - val_loss: -0.6221 - val_dice_coef: 1.1431
#
# Epoch 00072: val_loss did not improve from -0.63106
# Epoch 73/100
# 200/200 [==============================] - 3s 17ms/step - loss: -0.5002 - dice_coef: 7.7488 - val_loss: -0.6410 - val_dice_coef: 1.1723
#
# Epoch 00073: val_loss improved from -0.63106 to -0.64101, saving model to model_test_dice-80.h5
# Epoch 74/100
# 200/200 [==============================] - 4s 19ms/step - loss: -0.5044 - dice_coef: 7.2394 - val_loss: -0.6490 - val_dice_coef: 1.1917
#
# Epoch 00074: val_loss improved from -0.64101 to -0.64901, saving model to model_test_dice-80.h5
# Epoch 75/100
# 200/200 [==============================] - 4s 18ms/step - loss: -0.5081 - dice_coef: 5.8137 - val_loss: -0.6504 - val_dice_coef: 1.2706
#
# Epoch 00075: val_loss improved from -0.64901 to -0.65038, saving model to model_test_dice-80.h5
# Epoch 76/100
# 200/200 [==============================] - 4s 19ms/step - loss: -0.5049 - dice_coef: 5.1565 - val_loss: -0.6563 - val_dice_coef: 1.2145
#
# Epoch 00076: val_loss improved from -0.65038 to -0.65630, saving model to model_test_dice-80.h5
# Epoch 77/100
# 200/200 [==============================] - 4s 19ms/step - loss: -0.5153 - dice_coef: 4.3967 - val_loss: -0.6503 - val_dice_coef: 1.2979
#
# Epoch 00077: val_loss did not improve from -0.65630
# Epoch 78/100
# 200/200 [==============================] - 4s 18ms/step - loss: -0.5184 - dice_coef: 5.7487 - val_loss: -0.6557 - val_dice_coef: 1.3003
#
# Epoch 00078: val_loss did not improve from -0.65630
# Epoch 79/100
# 200/200 [==============================] - 4s 18ms/step - loss: -0.5259 - dice_coef: 5.2342 - val_loss: -0.6599 - val_dice_coef: 1.3032
#
# Epoch 00079: val_loss improved from -0.65630 to -0.65993, saving model to model_test_dice-80.h5
# Epoch 80/100
# 200/200 [==============================] - 4s 18ms/step - loss: -0.5284 - dice_coef: 4.3792 - val_loss: -0.6647 - val_dice_coef: 1.2919
#
# Epoch 00080: val_loss improved from -0.65993 to -0.66468, saving model to model_test_dice-80.h5
# Epoch 81/100
# 200/200 [==============================] - 4s 18ms/step - loss: -0.5232 - dice_coef: 6.6933 - val_loss: -0.6674 - val_dice_coef: 1.3098
#
# Epoch 00081: val_loss improved from -0.66468 to -0.66739, saving model to model_test_dice-80.h5
# Epoch 82/100
# 200/200 [==============================] - 4s 18ms/step - loss: -0.5255 - dice_coef: 5.0192 - val_loss: -0.6470 - val_dice_coef: 1.2936
#
# Epoch 00082: val_loss did not improve from -0.66739
# Epoch 83/100
# 200/200 [==============================] - 4s 18ms/step - loss: -0.5249 - dice_coef: 6.4953 - val_loss: -0.6630 - val_dice_coef: 1.3599
#
# Epoch 00083: val_loss did not improve from -0.66739
# Epoch 84/100
# 200/200 [==============================] - 4s 18ms/step - loss: -0.5350 - dice_coef: 4.4097 - val_loss: -0.6731 - val_dice_coef: 1.3746
#
# Epoch 00084: val_loss improved from -0.66739 to -0.67308, saving model to model_test_dice-80.h5
# Epoch 85/100
# 200/200 [==============================] - 4s 18ms/step - loss: -0.5299 - dice_coef: 5.8397 - val_loss: -0.6747 - val_dice_coef: 1.3543
#
# Epoch 00085: val_loss improved from -0.67308 to -0.67470, saving model to model_test_dice-80.h5
# Epoch 86/100
# 200/200 [==============================] - 4s 18ms/step - loss: -0.5261 - dice_coef: 5.3155 - val_loss: -0.6711 - val_dice_coef: 1.3569
#
# Epoch 00086: val_loss did not improve from -0.67470
# Epoch 87/100
# 200/200 [==============================] - 4s 18ms/step - loss: -0.5414 - dice_coef: 5.5547 - val_loss: -0.6592 - val_dice_coef: 1.2713
#
# Epoch 00087: val_loss did not improve from -0.67470
# Epoch 88/100
# 200/200 [==============================] - 4s 18ms/step - loss: -0.5291 - dice_coef: 7.3046 - val_loss: -0.6625 - val_dice_coef: 1.3103
#
# Epoch 00088: val_loss did not improve from -0.67470
# Epoch 89/100
# 200/200 [==============================] - 4s 18ms/step - loss: -0.5422 - dice_coef: 8.5813 - val_loss: -0.6588 - val_dice_coef: 1.3179
#
# Epoch 00089: val_loss did not improve from -0.67470
# Epoch 90/100
# 200/200 [==============================] - 4s 18ms/step - loss: -0.5302 - dice_coef: 7.3764 - val_loss: -0.6350 - val_dice_coef: 1.2470
#
# Epoch 00090: val_loss did not improve from -0.67470
# Epoch 91/100
# 200/200 [==============================] - 4s 18ms/step - loss: -0.5246 - dice_coef: 1.6591 - val_loss: -0.6749 - val_dice_coef: 1.3192
#
# Epoch 00091: val_loss improved from -0.67470 to -0.67489, saving model to model_test_dice-80.h5
# Epoch 92/100
# 200/200 [==============================] - 4s 18ms/step - loss: -0.5170 - dice_coef: 3.5314 - val_loss: -0.6744 - val_dice_coef: 1.3614
#
# Epoch 00092: val_loss did not improve from -0.67489
# Epoch 93/100
# 200/200 [==============================] - 4s 18ms/step - loss: -0.5150 - dice_coef: 6.4113 - val_loss: -0.6476 - val_dice_coef: 1.2535
#
# Epoch 00093: val_loss did not improve from -0.67489
# Epoch 94/100
# 200/200 [==============================] - 4s 18ms/step - loss: -0.5293 - dice_coef: 8.6122 - val_loss: -0.6552 - val_dice_coef: 1.2931
#
# Epoch 00094: val_loss did not improve from -0.67489
# Epoch 95/100
# 200/200 [==============================] - 4s 18ms/step - loss: -0.5462 - dice_coef: 7.5549 - val_loss: -0.6722 - val_dice_coef: 1.3270
#
# Epoch 00095: val_loss did not improve from -0.67489
# Epoch 96/100
# 200/200 [==============================] - 4s 18ms/step - loss: -0.5350 - dice_coef: 6.0302 - val_loss: -0.6731 - val_dice_coef: 1.3974
#
# Epoch 00096: val_loss did not improve from -0.67489
# Epoch 97/100
# 200/200 [==============================] - 4s 18ms/step - loss: -0.5471 - dice_coef: 4.3088 - val_loss: -0.6840 - val_dice_coef: 1.3710
#
# Epoch 00097: val_loss improved from -0.67489 to -0.68402, saving model to model_test_dice-80.h5
# Epoch 98/100
# 200/200 [==============================] - 4s 18ms/step - loss: -0.5523 - dice_coef: 5.8195 - val_loss: -0.6732 - val_dice_coef: 1.4077
#
# Epoch 00098: val_loss did not improve from -0.68402
# Epoch 99/100
# 200/200 [==============================] - 4s 18ms/step - loss: -0.5543 - dice_coef: 8.2593 - val_loss: -0.6736 - val_dice_coef: 1.3565
#
# Epoch 00099: val_loss did not improve from -0.68402
# Epoch 100/100
# 200/200 [==============================] - 4s 18ms/step - loss: -0.5537 - dice_coef: 6.1811 - val_loss: -0.6838 - val_dice_coef: 1.4101
#
# Epoch 00100: val_loss did not improve from -0.68402

# %% [markdown]
# ## name = 'model_test_dice-80.h5'

# %%
#meme poids
plt.figure(figsize=(8, 8))
plt.title("Learning curve")
plt.plot(results.history["loss"], label="loss")
plt.plot(results.history["val_loss"], label="val_loss")
plt.plot( np.argmin(results.history["val_loss"]), np.min(results.history["val_loss"]), marker="x", color="r", label="best model")
plt.xlabel("Epochs")
plt.ylabel("log_loss")
plt.legend();

# %%
plt.figure(figsize=(8, 8))
plt.title("Learning curve")
plt.plot(results.history["dice_coef"], label="loss")
plt.plot(results.history["val_dice_coef"], label="val_loss")
plt.xlabel("Epochs")
plt.ylabel("log_loss")
plt.legend();

# %% [markdown]
# # evaluation

# %%
model.load_weights(name)

# %%
name
# Out:
# 'model_test_dice-80.h5'

# %%
id = 80

# %%
test = imgs_train[id,:,:,:]

# %%
y_pred = model.predict(test.reshape(1,256,256,1))

# %% [markdown]
# # results

# %%
plt.figure(figsize=(20, 15))

for i in range(4):
    plt.subplot(1,4,i+1)
    plt.imshow(imgs_train[id,:,:,0])
    slice_ = y_pred[0,:,:,i]
    plt.imshow(slice_,vmin = slice_.min(), vmax= slice_.max(),cmap='jet', alpha=0.5)
plt.show()

# %% [markdown]
# # real

# %%
plt.figure(figsize=(20, 15))
for i in range(4):
    plt.subplot(1,4,i+1)
    slice_ = imgs_mask_train[id,:,:,i]
    plt.imshow(imgs_train[id,:,:,0])
    plt.imshow(slice_, cmap='jet', alpha=0.5)    
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# # image test

# %%
imgs_test = load_test_data()
imgs_test -= mean
imgs_test /= std

# %%
mask_predicts = model.predict(imgs_test)

# %%
idx = 10
plt.figure(figsize=(20, 15))
for i in range(4):
    plt.subplot(1,4,i+1)
    plt.imshow(imgs_test[idx,:,:,0])
    slice_ = mask_predicts[idx,:,:,i]
    plt.imshow(slice_,vmin = slice_.min(), vmax= slice_.max(),cmap='jet', alpha=0.5)
plt.show()

# %%
idx = 20
plt.figure(figsize=(20, 15))
for i in range(4):
    plt.subplot(1,4,i+1)
    plt.imshow(imgs_test[idx,:,:,0])
    slice_ = mask_predicts[idx,:,:,i]
    plt.imshow(slice_,vmin = slice_.min(), vmax= slice_.max(),cmap='jet', alpha=0.5)
plt.show()
