# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
from skimage.transform import resize # from scipy.misc import imresize
from tqdm import tqdm
import nibabel

# %%
def read_train_exam(exam_nb):
    image = nibabel.load('../chaos/train/%02d-T2SPIR-src.nii.gz'%(exam_nb))
    mask = nibabel.load('../chaos/train/%02d-T2SPIR-mask.nii.gz'%(exam_nb))
    return image, mask

def read_test_exam(exam_nb):
    image = nibabel.load('../chaos/test/%02d-T2SPIR-src.nii.gz'%(exam_nb))
    return image

# %%
img_rows,img_cols = 256,256
def preprocess(image):
    #shape (slide,256,256)
    image_ = np.ndarray((image.shape[2],img_rows,img_cols,1))
    for i in range(image.shape[2]):
        image_[i,:,:,0] = resize(image.get_data()[:,:,i],(img_rows,img_cols),mode='reflect',preserve_range=True,
                               anti_aliasing=True)            
    #print(image_.shape)
    return image_

# %%
image_1, mask_1 = read_train_exam(2)

# %%
print("before scale {},{},".format(np.unique(mask_1.get_data()),np.unique(image_1.get_data())))
# Out:
# before scale [0 1 2 3 4],[   0    1    2 ... 1474 1501 1503],

# %%
print("after scale {},{}".format(np.unique(preprocess(mask_1)),np.unique(preprocess(image_1))))
# Out:
# after scale [0.       0.015625 0.015625 ... 3.984375 3.984375 4.      ],[0.00000000e+00 1.56250000e-02 1.56250000e-02 ... 1.45790625e+03
#  1.46843750e+03 1.48428125e+03]

# %%
def mask_to_channels(mask,init,classes):
    #get mask for each class
    img = np.asarray([np.where(mask == i,1,0 ) for i in range(init,classes)])
    img = np.swapaxes(img,0,-1)#new shape (row,col,class)
    print(img.shape)
    return img

# %%
test = mask_1.get_data()[:,:,15]
img = mask_to_channels(test,0,5)
for i in range(0,5):
    plt.subplot(1,5,i+1)
    plt.imshow(img[:,:,i])
plt.show()
# Out:
# (320, 320, 5)

# %%
def create_data_train(train_ids,name, background = 0):
    
    for idx, train_id in tqdm(enumerate(train_ids)):
        image, mask = read_train_exam(train_id)     
        image = preprocess(image)
        mask = preprocess(mask) 
        print(train_id)
        #transform le mask
        if background:
            #create mask for 5 classess
            mask = mask_to_channels(mask,0,5)[0]
        else:
            mask = mask_to_channels(mask,1,5)[0]            
       
        if idx > 0:
            train_data = np.concatenate((train_data, image),axis=0)
            train_mask = np.concatenate((train_mask, mask),axis=0)
        else:
            train_data = image
            train_mask = mask
    print("Final shape {},{}".format(train_data.shape,train_mask.shape))    
    np.savez_compressed('./dataset/imgs_{}'.format(name), imgs=train_data)
    np.savez_compressed('./dataset/imgs_mask_{}'.format(name), imgs_mask=train_mask)

# %%
train_sujets = [1,2,3,5,8]
validation_sujets = [10,13,19]

# %%
#dataset training training data
create_data_train(train_sujets,"train_data")
# Out:
# 1it [00:00,  3.25it/s]
# 1
# (1, 36, 256, 256, 4)
# 2it [00:00,  3.11it/s]
# 2
# (1, 26, 256, 256, 4)
# 3it [00:01,  2.68it/s]
# 3
# (1, 30, 256, 256, 4)
# 5
# (1, 30, 256, 256, 4)
# 4it [00:01,  2.58it/s]
# 8
# (1, 32, 256, 256, 4)
# 5it [00:02,  2.28it/s]
# Final shape (154, 256, 256, 1),(154, 256, 256, 4)

# %%
#dataset training validation data
create_data_train(validation_sujets,"validation_data")
# Out:
# 1it [00:00,  3.15it/s]
# 10
# (1, 36, 256, 256, 4)
# 2it [00:00,  2.92it/s]
# 13
# (1, 30, 256, 256, 4)
# 3it [00:01,  2.69it/s]
# 19
# (1, 30, 256, 256, 4)
# Final shape (96, 256, 256, 1),(96, 256, 256, 4)

# %% [markdown]
# ### plot images

# %%
img = np.load('./dataset/imgs_train_data.npz')['imgs']
img_mask = np.load('./dataset/imgs_mask_train_data.npz')['imgs_mask']

# %%
img_mask[:,:,:].shape
# Out:
# (154, 256, 256, 4)

# %%
img[:,:,:,0].shape
# Out:
# (154, 256, 256)

# %%
#plot random samples from data
def plot_random_images(data,mask):
    index = np.random.choice(range(data.shape[0]),1)[0]
    plt.figure(figsize=(20, 15))
    c = mask.shape[3]
    #image
    plt.subplot(1, c + 1, 1)
    plt.imshow(data[index,:,:,0], cmap='gray', interpolation='nearest')
   
    for i in range(c): 
        plt.subplot(1, c + 1, i+2)
        plt.imshow(mask[index,:,:,i])
    plt.show()

# %%
#plot random samples from training data
print("Training data")
plot_random_images(img,img_mask)
# Out:
# Training data

# %%
plot_random_images(img,img_mask)

# %%
print(np.unique(img))
# Out:
# [0.00000000e+00 1.00974196e-28 1.51461294e-28 ... 1.93000000e+03
#  1.93500000e+03 1.97900000e+03]

# %%
imgs_train = img.astype('float32')
mean = np.mean(imgs_train)  # mean for data centering
std = np.std(imgs_train)  # std for data normalization

imgs_train -= mean
imgs_train /= std

# %%
print(np.unique(imgs_train))
# Out:
# [-0.542792   -0.54276794 -0.5427438  ... 11.364295   11.395143
#  11.666599  ]

# %% [markdown]
# # MODEL

# %%
#version tf1
from keras.models import Model
from keras.layers import Input, concatenate,Conv2D, MaxPooling2D, Conv2DTranspose,Dropout
from keras.optimizers import Adam,SGD
from keras.callbacks import ModelCheckpoint
from keras import backend as K

K.set_image_data_format('channels_last')  # TF dimension ordering in this code
# Out:
# Using TensorFlow backend.

# %%
img_rows = 256
img_cols = 256

# %%
smooth = 1.
#batch 32!
def dice_coef_(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)

def dice_coef_loss(y_true, y_pred):  
    return -dice_coef_(y_true, y_pred)

# %%
def get_unet():
    inputs = Input((img_rows, img_cols, 1))
    conv1 = Conv2D(32, (3, 3), activation='relu', padding='same')(inputs)
    conv1 = Conv2D(32, (3, 3), activation='relu', padding='same')(conv1)
    pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)

    conv2 = Conv2D(64, (3, 3), activation='relu', padding='same')(pool1)
    conv2 = Conv2D(64, (3, 3), activation='relu', padding='same')(conv2)
    pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)

    conv3 = Conv2D(128, (3, 3), activation='relu', padding='same')(pool2)
    conv3 = Conv2D(128, (3, 3), activation='relu', padding='same')(conv3)
    pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)

    conv4 = Conv2D(256, (3, 3), activation='relu', padding='same')(pool3)
    conv4 = Conv2D(256, (3, 3), activation='relu', padding='same')(conv4)
    pool4 = MaxPooling2D(pool_size=(2, 2))(conv4)

    conv5 = Conv2D(512, (3, 3), activation='relu', padding='same')(pool4)
    conv5 = Conv2D(512, (3, 3), activation='relu', padding='same')(conv5)

    up6 = concatenate([Conv2DTranspose(256, (2, 2), strides=(2, 2), padding='same')(conv5), conv4], axis=3)
    conv6 = Conv2D(256, (3, 3), activation='relu', padding='same')(up6)
    conv6 = Conv2D(256, (3, 3), activation='relu', padding='same')(conv6)

    up7 = concatenate([Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same')(conv6), conv3], axis=3)
    conv7 = Conv2D(128, (3, 3), activation='relu', padding='same')(up7)
    conv7 = Conv2D(128, (3, 3), activation='relu', padding='same')(conv7)

    up8 = concatenate([Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(conv7), conv2], axis=3)
    conv8 = Conv2D(64, (3, 3), activation='relu', padding='same')(up8)
    conv8 = Conv2D(64, (3, 3), activation='relu', padding='same')(conv8)

    up9 = concatenate([Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same')(conv8), conv1], axis=3)
    conv9 = Conv2D(32, (3, 3), activation='relu', padding='same')(up9)
    conv9 = Conv2D(32, (3, 3), activation='relu', padding='same')(conv9)
    #conv9 = Conv2D(4, (3,3), activation='relu', padding='same')(conv9)    
    conv10 = Conv2D(4, (1,1), activation='sigmoid')(conv9)    
    model = Model(inputs=[inputs], outputs=[conv10])
    
    return model

# %% [markdown]
# # data augmentation

# %%
from keras.preprocessing.image import ImageDataGenerator

# %%
# Load slices
x_val = np.load('./dataset/imgs_validation_data.npz')['imgs'].astype('float32')
y_val =np.load('./dataset/imgs_mask_validation_data.npz')['imgs_mask'].astype('float32')
x_train = np.load('./dataset/imgs_train_data.npz')['imgs'].astype('float32')
y_train = np.load('./dataset/imgs_mask_train_data.npz')['imgs_mask'].astype('float32')

# %%
print(x_train.shape,y_train.shape)
# Out:
# (154, 256, 256, 1) (154, 256, 256, 4)

# %% [markdown]
# For example, if your original dataset has 10,000 images and your batch size is 32, then a reasonable value for steps_per_epoch when fitting a model on the augmented data might be ceil(10,000/32), or 313 batches.

# %%
# create data generator
datagen = ImageDataGenerator(rotation_range=25)
it = datagen.flow(x_train, y_train,batch_size = 32)
# Specify the training configuration (optimizer, loss, metrics)
#checkpointer = ModelCheckpoint(filepath='/weights.hdf5', verbose=1, save_best_only=True)
modelGenerator = get_unet()
#compile
modelGenerator.compile(optimizer=Adam(lr=1e-4), loss=dice_coef_loss, metrics=['accuracy',dice_coef_])
# fit model on the augmented dataset
#250/32 =7,8 (32 batch_size)
steps_per_epoch = len(x_train) // 32
HGenerator = modelGenerator.fit_generator(it, validation_data = (x_val,y_val),
                                          steps_per_epoch= steps_per_epoch, 
                                          epochs=125)
# Out:
# Epoch 1/125
# 4/4 [==============================] - 11s 3s/step - loss: -0.0155 - acc: 0.0223 - dice_coef_: 0.0155 - val_loss: -0.0213 - val_acc: 0.0493 - val_dice_coef_: 0.0213
# Epoch 2/125
# 4/4 [==============================] - 3s 716ms/step - loss: -0.0330 - acc: 0.1009 - dice_coef_: 0.0330 - val_loss: -0.0274 - val_acc: 0.1966 - val_dice_coef_: 0.0274
# Epoch 3/125
# 4/4 [==============================] - 2s 559ms/step - loss: -0.0392 - acc: 0.2799 - dice_coef_: 0.0392 - val_loss: -0.0278 - val_acc: 0.3515 - val_dice_coef_: 0.0278
# Epoch 4/125
# 4/4 [==============================] - 2s 574ms/step - loss: -0.0347 - acc: 0.3997 - dice_coef_: 0.0347 - val_loss: -0.0275 - val_acc: 0.3942 - val_dice_coef_: 0.0275
# Epoch 5/125
# 4/4 [==============================] - 2s 554ms/step - loss: -0.0420 - acc: 0.4238 - dice_coef_: 0.0420 - val_loss: -0.0280 - val_acc: 0.3728 - val_dice_coef_: 0.0280
# Epoch 6/125
# 4/4 [==============================] - 2s 558ms/step - loss: -0.0393 - acc: 0.3659 - dice_coef_: 0.0393 - val_loss: -0.0292 - val_acc: 0.2658 - val_dice_coef_: 0.0292
# Epoch 7/125
# 4/4 [==============================] - 2s 576ms/step - loss: -0.0442 - acc: 0.2131 - dice_coef_: 0.0442 - val_loss: -0.0309 - val_acc: 0.1115 - val_dice_coef_: 0.0309
# Epoch 8/125
# 4/4 [==============================] - 2s 535ms/step - loss: -0.0376 - acc: 0.0706 - dice_coef_: 0.0376 - val_loss: -0.0339 - val_acc: 0.0527 - val_dice_coef_: 0.0339
# Epoch 9/125
# 4/4 [==============================] - 2s 575ms/step - loss: -0.0526 - acc: 0.0633 - dice_coef_: 0.0526 - val_loss: -0.0372 - val_acc: 0.0472 - val_dice_coef_: 0.0372
# Epoch 10/125
# 4/4 [==============================] - 2s 556ms/step - loss: -0.0618 - acc: 0.0972 - dice_coef_: 0.0618 - val_loss: -0.0530 - val_acc: 0.1236 - val_dice_coef_: 0.0530
# Epoch 11/125
# 4/4 [==============================] - 2s 574ms/step - loss: -0.0806 - acc: 0.1829 - dice_coef_: 0.0806 - val_loss: -0.0845 - val_acc: 0.2326 - val_dice_coef_: 0.0845
# Epoch 12/125
# 4/4 [==============================] - 2s 560ms/step - loss: -0.1557 - acc: 0.2819 - dice_coef_: 0.1557 - val_loss: -0.1738 - val_acc: 0.2909 - val_dice_coef_: 0.1738
# Epoch 13/125
# 4/4 [==============================] - 2s 560ms/step - loss: -0.2078 - acc: 0.3723 - dice_coef_: 0.2078 - val_loss: -0.2890 - val_acc: 0.5368 - val_dice_coef_: 0.2890
# Epoch 14/125
# 4/4 [==============================] - 2s 558ms/step - loss: -0.3253 - acc: 0.6067 - dice_coef_: 0.3253 - val_loss: -0.2875 - val_acc: 0.8021 - val_dice_coef_: 0.2875
# Epoch 15/125
# 4/4 [==============================] - 2s 564ms/step - loss: -0.3418 - acc: 0.7954 - dice_coef_: 0.3418 - val_loss: -0.4060 - val_acc: 0.8809 - val_dice_coef_: 0.4060
# Epoch 16/125
# 4/4 [==============================] - 2s 562ms/step - loss: -0.3862 - acc: 0.8959 - dice_coef_: 0.3862 - val_loss: -0.4067 - val_acc: 0.9316 - val_dice_coef_: 0.4067
# Epoch 17/125
# 4/4 [==============================] - 2s 561ms/step - loss: -0.4030 - acc: 0.9323 - dice_coef_: 0.4030 - val_loss: -0.4723 - val_acc: 0.9644 - val_dice_coef_: 0.4723
# Epoch 18/125
# 4/4 [==============================] - 2s 589ms/step - loss: -0.4631 - acc: 0.9597 - dice_coef_: 0.4631 - val_loss: -0.5109 - val_acc: 0.9667 - val_dice_coef_: 0.5109
# Epoch 19/125
# 4/4 [==============================] - 2s 564ms/step - loss: -0.4708 - acc: 0.9600 - dice_coef_: 0.4708 - val_loss: -0.4820 - val_acc: 0.9643 - val_dice_coef_: 0.4820
# Epoch 20/125
# 4/4 [==============================] - 2s 566ms/step - loss: -0.4396 - acc: 0.9522 - dice_coef_: 0.4396 - val_loss: -0.4570 - val_acc: 0.9725 - val_dice_coef_: 0.4570
# Epoch 21/125
# 4/4 [==============================] - 2s 594ms/step - loss: -0.4626 - acc: 0.9591 - dice_coef_: 0.4626 - val_loss: -0.4622 - val_acc: 0.9633 - val_dice_coef_: 0.4622
# Epoch 22/125
# 4/4 [==============================] - 2s 571ms/step - loss: -0.4356 - acc: 0.9546 - dice_coef_: 0.4356 - val_loss: -0.5328 - val_acc: 0.9769 - val_dice_coef_: 0.5328
# Epoch 23/125
# 4/4 [==============================] - 2s 568ms/step - loss: -0.5264 - acc: 0.9703 - dice_coef_: 0.5264 - val_loss: -0.5392 - val_acc: 0.9728 - val_dice_coef_: 0.5392
# Epoch 24/125
# 4/4 [==============================] - 2s 550ms/step - loss: -0.4671 - acc: 0.9584 - dice_coef_: 0.4671 - val_loss: -0.5075 - val_acc: 0.9787 - val_dice_coef_: 0.5075
# Epoch 25/125
# 4/4 [==============================] - 2s 592ms/step - loss: -0.5329 - acc: 0.9676 - dice_coef_: 0.5329 - val_loss: -0.5450 - val_acc: 0.9710 - val_dice_coef_: 0.5450
# Epoch 26/125
# 4/4 [==============================] - 2s 572ms/step - loss: -0.5181 - acc: 0.9607 - dice_coef_: 0.5181 - val_loss: -0.5179 - val_acc: 0.9768 - val_dice_coef_: 0.5179
# Epoch 27/125
# 4/4 [==============================] - 2s 594ms/step - loss: -0.5489 - acc: 0.9599 - dice_coef_: 0.5489 - val_loss: -0.5474 - val_acc: 0.9718 - val_dice_coef_: 0.5474
# Epoch 28/125
# 4/4 [==============================] - 2s 572ms/step - loss: -0.5595 - acc: 0.9647 - dice_coef_: 0.5595 - val_loss: -0.5446 - val_acc: 0.9760 - val_dice_coef_: 0.5446
# Epoch 29/125
# 4/4 [==============================] - 2s 570ms/step - loss: -0.5377 - acc: 0.9593 - dice_coef_: 0.5377 - val_loss: -0.5708 - val_acc: 0.9723 - val_dice_coef_: 0.5708
# Epoch 30/125
# 4/4 [==============================] - 2s 567ms/step - loss: -0.5282 - acc: 0.9617 - dice_coef_: 0.5282 - val_loss: -0.5560 - val_acc: 0.9729 - val_dice_coef_: 0.5560
# Epoch 31/125
# 4/4 [==============================] - 2s 572ms/step - loss: -0.5570 - acc: 0.9577 - dice_coef_: 0.5570 - val_loss: -0.5491 - val_acc: 0.9771 - val_dice_coef_: 0.5491
# Epoch 32/125
# 4/4 [==============================] - 2s 569ms/step - loss: -0.5701 - acc: 0.9648 - dice_coef_: 0.5701 - val_loss: -0.5700 - val_acc: 0.9729 - val_dice_coef_: 0.5700
# Epoch 33/125
# 4/4 [==============================] - 2s 592ms/step - loss: -0.5348 - acc: 0.9623 - dice_coef_: 0.5348 - val_loss: -0.5845 - val_acc: 0.9768 - val_dice_coef_: 0.5845
# Epoch 34/125
# 4/4 [==============================] - 2s 569ms/step - loss: -0.5698 - acc: 0.9637 - dice_coef_: 0.5698 - val_loss: -0.5935 - val_acc: 0.9768 - val_dice_coef_: 0.5935
# Epoch 35/125
# 4/4 [==============================] - 2s 571ms/step - loss: -0.5817 - acc: 0.9647 - dice_coef_: 0.5817 - val_loss: -0.5881 - val_acc: 0.9767 - val_dice_coef_: 0.5881
# Epoch 36/125
# 4/4 [==============================] - 2s 563ms/step - loss: -0.5948 - acc: 0.9665 - dice_coef_: 0.5948 - val_loss: -0.5830 - val_acc: 0.9740 - val_dice_coef_: 0.5830
# Epoch 37/125
# 4/4 [==============================] - 2s 583ms/step - loss: -0.5537 - acc: 0.9638 - dice_coef_: 0.5537 - val_loss: -0.5665 - val_acc: 0.9750 - val_dice_coef_: 0.5665
# Epoch 38/125
# 4/4 [==============================] - 2s 564ms/step - loss: -0.5913 - acc: 0.9649 - dice_coef_: 0.5913 - val_loss: -0.5812 - val_acc: 0.9734 - val_dice_coef_: 0.5812
# Epoch 39/125
# 4/4 [==============================] - 2s 567ms/step - loss: -0.5808 - acc: 0.9626 - dice_coef_: 0.5808 - val_loss: -0.5793 - val_acc: 0.9722 - val_dice_coef_: 0.5793
# Epoch 40/125
# 4/4 [==============================] - 2s 564ms/step - loss: -0.5740 - acc: 0.9578 - dice_coef_: 0.5740 - val_loss: -0.4834 - val_acc: 0.9790 - val_dice_coef_: 0.4834
# Epoch 41/125
# 4/4 [==============================] - 2s 564ms/step - loss: -0.5780 - acc: 0.9627 - dice_coef_: 0.5780 - val_loss: -0.5601 - val_acc: 0.9720 - val_dice_coef_: 0.5601
# Epoch 42/125
# 4/4 [==============================] - 2s 595ms/step - loss: -0.5474 - acc: 0.9603 - dice_coef_: 0.5474 - val_loss: -0.5745 - val_acc: 0.9749 - val_dice_coef_: 0.5745
# Epoch 43/125
# 4/4 [==============================] - 2s 549ms/step - loss: -0.6071 - acc: 0.9637 - dice_coef_: 0.6071 - val_loss: -0.5835 - val_acc: 0.9742 - val_dice_coef_: 0.5835
# Epoch 44/125
# 4/4 [==============================] - 2s 591ms/step - loss: -0.5722 - acc: 0.9523 - dice_coef_: 0.5722 - val_loss: -0.5900 - val_acc: 0.9742 - val_dice_coef_: 0.5900
# Epoch 45/125
# 4/4 [==============================] - 2s 571ms/step - loss: -0.5814 - acc: 0.9612 - dice_coef_: 0.5814 - val_loss: -0.5711 - val_acc: 0.9753 - val_dice_coef_: 0.5711
# Epoch 46/125
# 4/4 [==============================] - 2s 592ms/step - loss: -0.5990 - acc: 0.9686 - dice_coef_: 0.5990 - val_loss: -0.5745 - val_acc: 0.9778 - val_dice_coef_: 0.5745
# Epoch 47/125
# 4/4 [==============================] - 2s 541ms/step - loss: -0.5908 - acc: 0.9671 - dice_coef_: 0.5908 - val_loss: -0.5485 - val_acc: 0.9803 - val_dice_coef_: 0.5485
# Epoch 48/125
# 4/4 [==============================] - 2s 585ms/step - loss: -0.5907 - acc: 0.9663 - dice_coef_: 0.5907 - val_loss: -0.5716 - val_acc: 0.9774 - val_dice_coef_: 0.5716
# Epoch 49/125
# 4/4 [==============================] - 2s 563ms/step - loss: -0.5934 - acc: 0.9628 - dice_coef_: 0.5934 - val_loss: -0.5815 - val_acc: 0.9743 - val_dice_coef_: 0.5815
# Epoch 50/125
# 4/4 [==============================] - 2s 562ms/step - loss: -0.6008 - acc: 0.9624 - dice_coef_: 0.6008 - val_loss: -0.5812 - val_acc: 0.9773 - val_dice_coef_: 0.5812
# Epoch 51/125
# 4/4 [==============================] - 2s 566ms/step - loss: -0.5913 - acc: 0.9649 - dice_coef_: 0.5913 - val_loss: -0.5905 - val_acc: 0.9777 - val_dice_coef_: 0.5905
# Epoch 52/125
# 4/4 [==============================] - 2s 561ms/step - loss: -0.6233 - acc: 0.9654 - dice_coef_: 0.6233 - val_loss: -0.5850 - val_acc: 0.9760 - val_dice_coef_: 0.5850
# Epoch 53/125
# 4/4 [==============================] - 2s 562ms/step - loss: -0.6070 - acc: 0.9683 - dice_coef_: 0.6070 - val_loss: -0.5871 - val_acc: 0.9784 - val_dice_coef_: 0.5871
# Epoch 54/125
# 4/4 [==============================] - 2s 586ms/step - loss: -0.6018 - acc: 0.9611 - dice_coef_: 0.6018 - val_loss: -0.5968 - val_acc: 0.9768 - val_dice_coef_: 0.5968
# Epoch 55/125
# 4/4 [==============================] - 2s 564ms/step - loss: -0.6112 - acc: 0.9658 - dice_coef_: 0.6112 - val_loss: -0.5950 - val_acc: 0.9759 - val_dice_coef_: 0.5950
# Epoch 56/125
# 4/4 [==============================] - 2s 564ms/step - loss: -0.6079 - acc: 0.9650 - dice_coef_: 0.6079 - val_loss: -0.5806 - val_acc: 0.9755 - val_dice_coef_: 0.5806
# Epoch 57/125
# 4/4 [==============================] - 2s 564ms/step - loss: -0.5754 - acc: 0.9645 - dice_coef_: 0.5754 - val_loss: -0.5567 - val_acc: 0.9765 - val_dice_coef_: 0.5567
# Epoch 58/125
# 4/4 [==============================] - 2s 569ms/step - loss: -0.6249 - acc: 0.9646 - dice_coef_: 0.6249 - val_loss: -0.5400 - val_acc: 0.9772 - val_dice_coef_: 0.5400
# Epoch 59/125
# 4/4 [==============================] - 2s 593ms/step - loss: -0.6274 - acc: 0.9668 - dice_coef_: 0.6274 - val_loss: -0.5879 - val_acc: 0.9782 - val_dice_coef_: 0.5879
# Epoch 60/125
# 4/4 [==============================] - 2s 571ms/step - loss: -0.6120 - acc: 0.9618 - dice_coef_: 0.6120 - val_loss: -0.5236 - val_acc: 0.9796 - val_dice_coef_: 0.5236
# Epoch 61/125
# 4/4 [==============================] - 2s 574ms/step - loss: -0.5891 - acc: 0.9650 - dice_coef_: 0.5891 - val_loss: -0.5557 - val_acc: 0.9769 - val_dice_coef_: 0.5557
# Epoch 62/125
# 4/4 [==============================] - 2s 593ms/step - loss: -0.5918 - acc: 0.9660 - dice_coef_: 0.5918 - val_loss: -0.6066 - val_acc: 0.9753 - val_dice_coef_: 0.6066
# Epoch 63/125
# 4/4 [==============================] - 2s 551ms/step - loss: -0.6156 - acc: 0.9595 - dice_coef_: 0.6156 - val_loss: -0.6143 - val_acc: 0.9746 - val_dice_coef_: 0.6143
# Epoch 64/125
# 4/4 [==============================] - 2s 571ms/step - loss: -0.6204 - acc: 0.9619 - dice_coef_: 0.6204 - val_loss: -0.5440 - val_acc: 0.9799 - val_dice_coef_: 0.5440
# Epoch 65/125
# 4/4 [==============================] - 2s 592ms/step - loss: -0.5943 - acc: 0.9682 - dice_coef_: 0.5943 - val_loss: -0.5564 - val_acc: 0.9818 - val_dice_coef_: 0.5564
# Epoch 66/125
# 4/4 [==============================] - 2s 565ms/step - loss: -0.6188 - acc: 0.9682 - dice_coef_: 0.6188 - val_loss: -0.6190 - val_acc: 0.9774 - val_dice_coef_: 0.6190
# Epoch 67/125
# 4/4 [==============================] - 2s 564ms/step - loss: -0.5681 - acc: 0.9670 - dice_coef_: 0.5681 - val_loss: -0.6033 - val_acc: 0.9765 - val_dice_coef_: 0.6033
# Epoch 68/125
# 4/4 [==============================] - 2s 592ms/step - loss: -0.6184 - acc: 0.9634 - dice_coef_: 0.6184 - val_loss: -0.5955 - val_acc: 0.9747 - val_dice_coef_: 0.5955
# Epoch 69/125
# 4/4 [==============================] - 2s 571ms/step - loss: -0.6208 - acc: 0.9559 - dice_coef_: 0.6208 - val_loss: -0.5790 - val_acc: 0.9781 - val_dice_coef_: 0.5790
# Epoch 70/125
# 4/4 [==============================] - 2s 571ms/step - loss: -0.6285 - acc: 0.9643 - dice_coef_: 0.6285 - val_loss: -0.6266 - val_acc: 0.9785 - val_dice_coef_: 0.6266
# Epoch 71/125
# 4/4 [==============================] - 2s 572ms/step - loss: -0.6295 - acc: 0.9683 - dice_coef_: 0.6295 - val_loss: -0.6258 - val_acc: 0.9782 - val_dice_coef_: 0.6258
# Epoch 72/125
# 4/4 [==============================] - 2s 596ms/step - loss: -0.6253 - acc: 0.9680 - dice_coef_: 0.6253 - val_loss: -0.6242 - val_acc: 0.9794 - val_dice_coef_: 0.6242
# Epoch 73/125
# 4/4 [==============================] - 2s 573ms/step - loss: -0.6458 - acc: 0.9673 - dice_coef_: 0.6458 - val_loss: -0.6268 - val_acc: 0.9780 - val_dice_coef_: 0.6268
# Epoch 74/125
# 4/4 [==============================] - 2s 571ms/step - loss: -0.6315 - acc: 0.9675 - dice_coef_: 0.6315 - val_loss: -0.5787 - val_acc: 0.9801 - val_dice_coef_: 0.5787
# Epoch 75/125
# 4/4 [==============================] - 2s 568ms/step - loss: -0.6112 - acc: 0.9635 - dice_coef_: 0.6112 - val_loss: -0.6178 - val_acc: 0.9784 - val_dice_coef_: 0.6178
# Epoch 76/125
# 4/4 [==============================] - 2s 595ms/step - loss: -0.6259 - acc: 0.9678 - dice_coef_: 0.6259 - val_loss: -0.6278 - val_acc: 0.9781 - val_dice_coef_: 0.6278
# Epoch 77/125
# 4/4 [==============================] - 2s 569ms/step - loss: -0.6316 - acc: 0.9625 - dice_coef_: 0.6316 - val_loss: -0.5747 - val_acc: 0.9803 - val_dice_coef_: 0.5747
# Epoch 78/125
# 4/4 [==============================] - 2s 571ms/step - loss: -0.6310 - acc: 0.9683 - dice_coef_: 0.6310 - val_loss: -0.6128 - val_acc: 0.9808 - val_dice_coef_: 0.6128
# Epoch 79/125
# 4/4 [==============================] - 2s 569ms/step - loss: -0.6403 - acc: 0.9714 - dice_coef_: 0.6403 - val_loss: -0.6257 - val_acc: 0.9798 - val_dice_coef_: 0.6257
# Epoch 80/125
# 4/4 [==============================] - 2s 568ms/step - loss: -0.6325 - acc: 0.9649 - dice_coef_: 0.6325 - val_loss: -0.5832 - val_acc: 0.9793 - val_dice_coef_: 0.5832
# Epoch 81/125
# 4/4 [==============================] - 2s 572ms/step - loss: -0.6522 - acc: 0.9662 - dice_coef_: 0.6522 - val_loss: -0.5939 - val_acc: 0.9812 - val_dice_coef_: 0.5939
# Epoch 82/125
# 4/4 [==============================] - 2s 574ms/step - loss: -0.6618 - acc: 0.9666 - dice_coef_: 0.6618 - val_loss: -0.6290 - val_acc: 0.9798 - val_dice_coef_: 0.6290
# Epoch 83/125
# 4/4 [==============================] - 2s 571ms/step - loss: -0.6331 - acc: 0.9675 - dice_coef_: 0.6331 - val_loss: -0.6083 - val_acc: 0.9808 - val_dice_coef_: 0.6083
# Epoch 84/125
# 4/4 [==============================] - 2s 593ms/step - loss: -0.6242 - acc: 0.9706 - dice_coef_: 0.6242 - val_loss: -0.6293 - val_acc: 0.9803 - val_dice_coef_: 0.6293
# Epoch 85/125
# 4/4 [==============================] - 2s 569ms/step - loss: -0.6631 - acc: 0.9664 - dice_coef_: 0.6631 - val_loss: -0.6367 - val_acc: 0.9809 - val_dice_coef_: 0.6367
# Epoch 86/125
# 4/4 [==============================] - 2s 595ms/step - loss: -0.6537 - acc: 0.9691 - dice_coef_: 0.6537 - val_loss: -0.6308 - val_acc: 0.9813 - val_dice_coef_: 0.6308
# Epoch 87/125
# 4/4 [==============================] - 2s 551ms/step - loss: -0.6420 - acc: 0.9705 - dice_coef_: 0.6420 - val_loss: -0.6465 - val_acc: 0.9827 - val_dice_coef_: 0.6465
# Epoch 88/125
# 4/4 [==============================] - 2s 594ms/step - loss: -0.6677 - acc: 0.9716 - dice_coef_: 0.6677 - val_loss: -0.6454 - val_acc: 0.9823 - val_dice_coef_: 0.6454
# Epoch 89/125
# 4/4 [==============================] - 2s 545ms/step - loss: -0.6679 - acc: 0.9675 - dice_coef_: 0.6679 - val_loss: -0.6002 - val_acc: 0.9819 - val_dice_coef_: 0.6002
# Epoch 90/125
# 4/4 [==============================] - 2s 590ms/step - loss: -0.6684 - acc: 0.9701 - dice_coef_: 0.6684 - val_loss: -0.6364 - val_acc: 0.9821 - val_dice_coef_: 0.6364
# Epoch 91/125
# 4/4 [==============================] - 2s 568ms/step - loss: -0.6552 - acc: 0.9684 - dice_coef_: 0.6552 - val_loss: -0.6323 - val_acc: 0.9817 - val_dice_coef_: 0.6323
# Epoch 92/125
# 4/4 [==============================] - 2s 571ms/step - loss: -0.6795 - acc: 0.9676 - dice_coef_: 0.6795 - val_loss: -0.6466 - val_acc: 0.9823 - val_dice_coef_: 0.6466
# Epoch 93/125
# 4/4 [==============================] - 2s 571ms/step - loss: -0.6734 - acc: 0.9696 - dice_coef_: 0.6734 - val_loss: -0.5981 - val_acc: 0.9833 - val_dice_coef_: 0.5981
# Epoch 94/125
# 4/4 [==============================] - 2s 595ms/step - loss: -0.6647 - acc: 0.9677 - dice_coef_: 0.6647 - val_loss: -0.6533 - val_acc: 0.9818 - val_dice_coef_: 0.6533
# Epoch 95/125
# 4/4 [==============================] - 2s 568ms/step - loss: -0.6577 - acc: 0.9699 - dice_coef_: 0.6577 - val_loss: -0.6256 - val_acc: 0.9824 - val_dice_coef_: 0.6256
# Epoch 96/125
# 4/4 [==============================] - 2s 593ms/step - loss: -0.6676 - acc: 0.9686 - dice_coef_: 0.6676 - val_loss: -0.6332 - val_acc: 0.9816 - val_dice_coef_: 0.6332
# Epoch 97/125
# 4/4 [==============================] - 2s 571ms/step - loss: -0.6696 - acc: 0.9684 - dice_coef_: 0.6696 - val_loss: -0.6401 - val_acc: 0.9832 - val_dice_coef_: 0.6401
# Epoch 98/125
# 4/4 [==============================] - 2s 568ms/step - loss: -0.6741 - acc: 0.9698 - dice_coef_: 0.6741 - val_loss: -0.6298 - val_acc: 0.9817 - val_dice_coef_: 0.6298
# Epoch 99/125
# 4/4 [==============================] - 2s 571ms/step - loss: -0.6930 - acc: 0.9688 - dice_coef_: 0.6930 - val_loss: -0.6331 - val_acc: 0.9815 - val_dice_coef_: 0.6331
# Epoch 100/125
# 4/4 [==============================] - 2s 569ms/step - loss: -0.6536 - acc: 0.9671 - dice_coef_: 0.6536 - val_loss: -0.6621 - val_acc: 0.9827 - val_dice_coef_: 0.6621
# Epoch 101/125
# 4/4 [==============================] - 2s 595ms/step - loss: -0.6709 - acc: 0.9661 - dice_coef_: 0.6709 - val_loss: -0.6487 - val_acc: 0.9807 - val_dice_coef_: 0.6487
# Epoch 102/125
# 4/4 [==============================] - 2s 548ms/step - loss: -0.6727 - acc: 0.9677 - dice_coef_: 0.6727 - val_loss: -0.6480 - val_acc: 0.9817 - val_dice_coef_: 0.6480
# Epoch 103/125
# 4/4 [==============================] - 2s 590ms/step - loss: -0.6908 - acc: 0.9679 - dice_coef_: 0.6908 - val_loss: -0.6529 - val_acc: 0.9825 - val_dice_coef_: 0.6529
# Epoch 104/125
# 4/4 [==============================] - 2s 550ms/step - loss: -0.6739 - acc: 0.9674 - dice_coef_: 0.6739 - val_loss: -0.5731 - val_acc: 0.9842 - val_dice_coef_: 0.5731
# Epoch 105/125
# 4/4 [==============================] - 2s 590ms/step - loss: -0.6523 - acc: 0.9670 - dice_coef_: 0.6523 - val_loss: -0.6442 - val_acc: 0.9798 - val_dice_coef_: 0.6442
# Epoch 106/125
# 4/4 [==============================] - 2s 570ms/step - loss: -0.6856 - acc: 0.9682 - dice_coef_: 0.6856 - val_loss: -0.6173 - val_acc: 0.9823 - val_dice_coef_: 0.6173
# Epoch 107/125
# 4/4 [==============================] - 2s 571ms/step - loss: -0.6660 - acc: 0.9689 - dice_coef_: 0.6660 - val_loss: -0.6541 - val_acc: 0.9838 - val_dice_coef_: 0.6541
# Epoch 108/125
# 4/4 [==============================] - 2s 590ms/step - loss: -0.6878 - acc: 0.9665 - dice_coef_: 0.6878 - val_loss: -0.6680 - val_acc: 0.9821 - val_dice_coef_: 0.6680
# Epoch 109/125
# 4/4 [==============================] - 2s 550ms/step - loss: -0.6761 - acc: 0.9675 - dice_coef_: 0.6761 - val_loss: -0.6145 - val_acc: 0.9808 - val_dice_coef_: 0.6145
# Epoch 110/125
# 4/4 [==============================] - 2s 592ms/step - loss: -0.6765 - acc: 0.9658 - dice_coef_: 0.6765 - val_loss: -0.6599 - val_acc: 0.9827 - val_dice_coef_: 0.6599
# Epoch 111/125
# 4/4 [==============================] - 2s 571ms/step - loss: -0.6893 - acc: 0.9694 - dice_coef_: 0.6893 - val_loss: -0.6677 - val_acc: 0.9828 - val_dice_coef_: 0.6677
# Epoch 112/125
# 4/4 [==============================] - 2s 573ms/step - loss: -0.6987 - acc: 0.9638 - dice_coef_: 0.6987 - val_loss: -0.6539 - val_acc: 0.9794 - val_dice_coef_: 0.6539
# Epoch 113/125
# 4/4 [==============================] - 2s 594ms/step - loss: -0.7076 - acc: 0.9612 - dice_coef_: 0.7076 - val_loss: -0.6538 - val_acc: 0.9796 - val_dice_coef_: 0.6538
# Epoch 114/125
# 4/4 [==============================] - 2s 550ms/step - loss: -0.6736 - acc: 0.9625 - dice_coef_: 0.6736 - val_loss: -0.6342 - val_acc: 0.9821 - val_dice_coef_: 0.6342
# Epoch 115/125
# 4/4 [==============================] - 2s 589ms/step - loss: -0.6844 - acc: 0.9612 - dice_coef_: 0.6844 - val_loss: -0.6634 - val_acc: 0.9810 - val_dice_coef_: 0.6634
# Epoch 116/125
# 4/4 [==============================] - 2s 572ms/step - loss: -0.6885 - acc: 0.9609 - dice_coef_: 0.6885 - val_loss: -0.6398 - val_acc: 0.9815 - val_dice_coef_: 0.6398
# Epoch 117/125
# 4/4 [==============================] - 2s 593ms/step - loss: -0.7208 - acc: 0.9658 - dice_coef_: 0.7208 - val_loss: -0.6537 - val_acc: 0.9802 - val_dice_coef_: 0.6537
# Epoch 118/125
# 4/4 [==============================] - 2s 571ms/step - loss: -0.6967 - acc: 0.9644 - dice_coef_: 0.6967 - val_loss: -0.6715 - val_acc: 0.9811 - val_dice_coef_: 0.6715
# Epoch 119/125
# 4/4 [==============================] - 2s 572ms/step - loss: -0.6963 - acc: 0.9612 - dice_coef_: 0.6963 - val_loss: -0.6614 - val_acc: 0.9809 - val_dice_coef_: 0.6614
# Epoch 120/125
# 4/4 [==============================] - 2s 567ms/step - loss: -0.6682 - acc: 0.9651 - dice_coef_: 0.6682 - val_loss: -0.6529 - val_acc: 0.9830 - val_dice_coef_: 0.6529
# Epoch 121/125
# 4/4 [==============================] - 2s 571ms/step - loss: -0.7005 - acc: 0.9627 - dice_coef_: 0.7005 - val_loss: -0.6214 - val_acc: 0.9809 - val_dice_coef_: 0.6214
# Epoch 122/125
# 4/4 [==============================] - 2s 568ms/step - loss: -0.6624 - acc: 0.9641 - dice_coef_: 0.6624 - val_loss: -0.6463 - val_acc: 0.9824 - val_dice_coef_: 0.6463
# Epoch 123/125
# 4/4 [==============================] - 2s 590ms/step - loss: -0.6879 - acc: 0.9616 - dice_coef_: 0.6879 - val_loss: -0.6435 - val_acc: 0.9790 - val_dice_coef_: 0.6435
# Epoch 124/125
# 4/4 [==============================] - 2s 573ms/step - loss: -0.7209 - acc: 0.9661 - dice_coef_: 0.7209 - val_loss: -0.6515 - val_acc: 0.9808 - val_dice_coef_: 0.6515
# Epoch 125/125
# 4/4 [==============================] - 2s 571ms/step - loss: -0.7078 - acc: 0.9608 - dice_coef_: 0.7078 - val_loss: -0.6512 - val_acc: 0.9816 - val_dice_coef_: 0.6512

# %%
plt.subplot(211)
plt.plot(HGenerator.history['loss'], label='train')
plt.plot(HGenerator.history['val_loss'], label='val')
plt.title('loss')
plt.legend()

plt.subplot(212)
plt.plot(HGenerator.history['dice_coef_'], label='train')
plt.plot(HGenerator.history['val_dice_coef_'], label='val')
plt.title('acc')
plt.legend()

# %% [markdown]
# https://github.com/hlamba28/UNET-TGS/blob/master/TGS%20UNET.ipynb

# %%
id = 110


test = x_train[id,:,:,:]
y_pred = modelGenerator.predict(test.reshape(1,256,256,1))

# %% [markdown]
# # results

# %%
plt.figure(figsize=(20, 15))

for i in range(4):
    plt.subplot(1,4,i+1)
    plt.imshow(x_train[id,:,:,0])
    slice_ = y_pred[0,:,:,i]
    x = np.sum(y_pred, axis = 3)[0]
    print(slice_.min(),slice_.max())
    plt.imshow(slice_,vmin=0,vmax=1, alpha=0.8)
plt.show()
# Out:
# 0.0 1.0
# 0.0 9.4302864e-05
# 0.0 0.0002586754
# 0.0 0.0011562918

# %% [markdown]
# # real

# %%
plt.figure(figsize=(20, 15))
for i in range(4):
    plt.subplot(1,4,i+1)
    slice_ = y_train[id,:,:,i]
    plt.imshow(y_train[id,:,:,0])
    plt.imshow(slice_, alpha=0.78)    
plt.show()

# %% [markdown]
# # other OUTPUT

# %%
def get_unet_ch():
    inputs = Input((img_rows, img_cols, 1))
    conv1 = Conv2D(32, (3, 3), activation='relu', padding='same')(inputs)
    conv1 = Conv2D(32, (3, 3), activation='relu', padding='same')(conv1)
    pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)

    conv2 = Conv2D(64, (3, 3), activation='relu', padding='same')(pool1)
    conv2 = Conv2D(64, (3, 3), activation='relu', padding='same')(conv2)
    pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)

    conv3 = Conv2D(128, (3, 3), activation='relu', padding='same')(pool2)
    conv3 = Conv2D(128, (3, 3), activation='relu', padding='same')(conv3)
    pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)

    conv4 = Conv2D(256, (3, 3), activation='relu', padding='same')(pool3)
    conv4 = Conv2D(256, (3, 3), activation='relu', padding='same')(conv4)
    pool4 = MaxPooling2D(pool_size=(2, 2))(conv4)

    conv5 = Conv2D(512, (3, 3), activation='relu', padding='same')(pool4)
    conv5 = Conv2D(512, (3, 3), activation='relu', padding='same')(conv5)

    up6 = concatenate([Conv2DTranspose(256, (2, 2), strides=(2, 2), padding='same')(conv5), conv4], axis=3)
    conv6 = Conv2D(256, (3, 3), activation='relu', padding='same')(up6)
    conv6 = Conv2D(256, (3, 3), activation='relu', padding='same')(conv6)

    up7 = concatenate([Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same')(conv6), conv3], axis=3)
    conv7 = Conv2D(128, (3, 3), activation='relu', padding='same')(up7)
    conv7 = Conv2D(128, (3, 3), activation='relu', padding='same')(conv7)

    up8 = concatenate([Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(conv7), conv2], axis=3)
    conv8 = Conv2D(64, (3, 3), activation='relu', padding='same')(up8)
    conv8 = Conv2D(64, (3, 3), activation='relu', padding='same')(conv8)

    up9 = concatenate([Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same')(conv8), conv1], axis=3)
    conv9 = Conv2D(32, (3, 3), activation='relu', padding='same')(up9)
    conv9 = Conv2D(32, (3, 3), activation='relu', padding='same')(conv9)

    output_layer = Conv2D(4, (1, 1))(conv9)
    output_layer = Activation('softmax')(output_layer)
    
    model = Model(inputs=[inputs], outputs=[output_layer])
    
    return model

# %%
del mm

# %%
from keras.layers import Reshape,Activation
from keras.optimizers import RMSprop

# %%
# create data generator
datagen = ImageDataGenerator(rotation_range=25)
datagen_val = ImageDataGenerator(rotation_range=25)

it = datagen.flow(x_train, y_train,batch_size = 32)
it_val = datagen_val.flow(x_train, y_train,batch_size = 32)

# Specify the training configuration (optimizer, loss, metrics)
#checkpointer = ModelCheckpoint(filepath='/weights.hdf5', verbose=1, save_best_only=True)
mm = get_unet_ch()
#comple
mm.compile(optimizer = RMSprop(lr = 1e-5), loss=['categorical_crossentropy'], 
              metrics=['accuracy',dice_coef_])
# fit model on the augmented dataset
#250/32 =7,8 (32 batch_size)
steps_per_epoch = len(x_train) // 32
H = mm.fit_generator(it, validation_data = (x_val,y_val),
                                          steps_per_epoch= steps_per_epoch, 
                                          epochs=120)
# Out:
# Epoch 1/120
# 9/9 [==============================] - 6s 692ms/step - loss: 0.3473 - acc: 0.4587 - dice_coef_: 0.0257 - val_loss: 0.1709 - val_acc: 0.5563 - val_dice_coef_: 0.0301
# Epoch 2/120
# 9/9 [==============================] - 3s 317ms/step - loss: 0.2285 - acc: 0.5837 - dice_coef_: 0.0428 - val_loss: 0.1520 - val_acc: 0.6175 - val_dice_coef_: 0.0403
# Epoch 3/120
# 9/9 [==============================] - 3s 287ms/step - loss: 0.2427 - acc: 0.6377 - dice_coef_: 0.0574 - val_loss: 0.1471 - val_acc: 0.6605 - val_dice_coef_: 0.0448
# Epoch 4/120
# 9/9 [==============================] - 3s 279ms/step - loss: 0.2214 - acc: 0.6628 - dice_coef_: 0.0546 - val_loss: 0.1452 - val_acc: 0.6652 - val_dice_coef_: 0.0464
# Epoch 5/120
# 9/9 [==============================] - 2s 270ms/step - loss: 0.2141 - acc: 0.6706 - dice_coef_: 0.0577 - val_loss: 0.1436 - val_acc: 0.6687 - val_dice_coef_: 0.0472
# Epoch 6/120
# 9/9 [==============================] - 3s 287ms/step - loss: 0.2385 - acc: 0.6876 - dice_coef_: 0.0712 - val_loss: 0.1421 - val_acc: 0.6838 - val_dice_coef_: 0.0479
# Epoch 7/120
# 9/9 [==============================] - 2s 270ms/step - loss: 0.2085 - acc: 0.6880 - dice_coef_: 0.0616 - val_loss: 0.1390 - val_acc: 0.6715 - val_dice_coef_: 0.0469
# Epoch 8/120
# 9/9 [==============================] - 3s 287ms/step - loss: 0.2049 - acc: 0.6923 - dice_coef_: 0.0569 - val_loss: 0.1356 - val_acc: 0.6628 - val_dice_coef_: 0.0461
# Epoch 9/120
# 9/9 [==============================] - 3s 279ms/step - loss: 0.2104 - acc: 0.6967 - dice_coef_: 0.0636 - val_loss: 0.1331 - val_acc: 0.6703 - val_dice_coef_: 0.0469
# Epoch 10/120
# 9/9 [==============================] - 2s 278ms/step - loss: 0.1918 - acc: 0.6839 - dice_coef_: 0.0592 - val_loss: 0.1286 - val_acc: 0.6453 - val_dice_coef_: 0.0462
# Epoch 11/120
# 9/9 [==============================] - 3s 279ms/step - loss: 0.1852 - acc: 0.6600 - dice_coef_: 0.0588 - val_loss: 0.1260 - val_acc: 0.6041 - val_dice_coef_: 0.0475
# Epoch 12/120
# 9/9 [==============================] - 3s 278ms/step - loss: 0.1822 - acc: 0.6036 - dice_coef_: 0.0589 - val_loss: 0.1216 - val_acc: 0.5234 - val_dice_coef_: 0.0444
# Epoch 13/120
# 9/9 [==============================] - 3s 289ms/step - loss: 0.1850 - acc: 0.5407 - dice_coef_: 0.0701 - val_loss: 0.1195 - val_acc: 0.4637 - val_dice_coef_: 0.0449
# Epoch 14/120
# 9/9 [==============================] - 2s 272ms/step - loss: 0.1650 - acc: 0.4730 - dice_coef_: 0.0536 - val_loss: 0.1197 - val_acc: 0.4596 - val_dice_coef_: 0.0462
# Epoch 15/120
# 9/9 [==============================] - 3s 278ms/step - loss: 0.1652 - acc: 0.4732 - dice_coef_: 0.0580 - val_loss: 0.1153 - val_acc: 0.4377 - val_dice_coef_: 0.0446
# Epoch 16/120
# 9/9 [==============================] - 3s 289ms/step - loss: 0.1564 - acc: 0.4768 - dice_coef_: 0.0608 - val_loss: 0.1147 - val_acc: 0.4530 - val_dice_coef_: 0.0455
# Epoch 17/120
# 9/9 [==============================] - 3s 280ms/step - loss: 0.1726 - acc: 0.4663 - dice_coef_: 0.0537 - val_loss: 0.1099 - val_acc: 0.4707 - val_dice_coef_: 0.0447
# Epoch 18/120
# 9/9 [==============================] - 3s 280ms/step - loss: 0.1589 - acc: 0.4794 - dice_coef_: 0.0581 - val_loss: 0.1045 - val_acc: 0.4447 - val_dice_coef_: 0.0409
# Epoch 19/120
# 9/9 [==============================] - 3s 281ms/step - loss: 0.1521 - acc: 0.4846 - dice_coef_: 0.0538 - val_loss: 0.1013 - val_acc: 0.4575 - val_dice_coef_: 0.0417
# Epoch 20/120
# 9/9 [==============================] - 3s 282ms/step - loss: 0.1425 - acc: 0.4907 - dice_coef_: 0.0569 - val_loss: 0.0975 - val_acc: 0.4794 - val_dice_coef_: 0.0428
# Epoch 21/120
# 9/9 [==============================] - 3s 279ms/step - loss: 0.1411 - acc: 0.4841 - dice_coef_: 0.0538 - val_loss: 0.0955 - val_acc: 0.4835 - val_dice_coef_: 0.0442
# Epoch 22/120
# 9/9 [==============================] - 3s 283ms/step - loss: 0.1346 - acc: 0.4896 - dice_coef_: 0.0553 - val_loss: 0.0886 - val_acc: 0.5037 - val_dice_coef_: 0.0436
# Epoch 23/120
# 9/9 [==============================] - 3s 281ms/step - loss: 0.1272 - acc: 0.4960 - dice_coef_: 0.0516 - val_loss: 0.0822 - val_acc: 0.4954 - val_dice_coef_: 0.0417
# Epoch 24/120
# 9/9 [==============================] - 3s 281ms/step - loss: 0.1164 - acc: 0.5175 - dice_coef_: 0.0544 - val_loss: 0.0779 - val_acc: 0.5267 - val_dice_coef_: 0.0435
# Epoch 25/120
# 9/9 [==============================] - 3s 281ms/step - loss: 0.1008 - acc: 0.5192 - dice_coef_: 0.0485 - val_loss: 0.0732 - val_acc: 0.5229 - val_dice_coef_: 0.0426
# Epoch 26/120
# 9/9 [==============================] - 3s 290ms/step - loss: 0.1062 - acc: 0.5486 - dice_coef_: 0.0583 - val_loss: 0.0698 - val_acc: 0.5530 - val_dice_coef_: 0.0414
# Epoch 27/120
# 9/9 [==============================] - 3s 281ms/step - loss: 0.0961 - acc: 0.5600 - dice_coef_: 0.0563 - val_loss: 0.0658 - val_acc: 0.6082 - val_dice_coef_: 0.0464
# Epoch 28/120
# 9/9 [==============================] - 3s 281ms/step - loss: 0.0780 - acc: 0.5723 - dice_coef_: 0.0521 - val_loss: 0.0641 - val_acc: 0.6233 - val_dice_coef_: 0.0472
# Epoch 29/120
# 9/9 [==============================] - 3s 289ms/step - loss: 0.0858 - acc: 0.5798 - dice_coef_: 0.0544 - val_loss: 0.0603 - val_acc: 0.5450 - val_dice_coef_: 0.0409
# Epoch 30/120
# 9/9 [==============================] - 3s 284ms/step - loss: 0.0832 - acc: 0.5842 - dice_coef_: 0.0609 - val_loss: 0.0561 - val_acc: 0.5625 - val_dice_coef_: 0.0440
# Epoch 31/120
# 9/9 [==============================] - 3s 286ms/step - loss: 0.0790 - acc: 0.5754 - dice_coef_: 0.0581 - val_loss: 0.0526 - val_acc: 0.5732 - val_dice_coef_: 0.0460
# Epoch 32/120
# 9/9 [==============================] - 3s 285ms/step - loss: 0.0685 - acc: 0.5748 - dice_coef_: 0.0597 - val_loss: 0.0497 - val_acc: 0.5648 - val_dice_coef_: 0.0461
# Epoch 33/120
# 9/9 [==============================] - 3s 290ms/step - loss: 0.0675 - acc: 0.5704 - dice_coef_: 0.0604 - val_loss: 0.0499 - val_acc: 0.5271 - val_dice_coef_: 0.0438
# Epoch 34/120
# 9/9 [==============================] - 3s 290ms/step - loss: 0.0650 - acc: 0.5675 - dice_coef_: 0.0653 - val_loss: 0.0460 - val_acc: 0.5369 - val_dice_coef_: 0.0467
# Epoch 35/120
# 9/9 [==============================] - 3s 291ms/step - loss: 0.0563 - acc: 0.5509 - dice_coef_: 0.0542 - val_loss: 0.0449 - val_acc: 0.5823 - val_dice_coef_: 0.0505
# Epoch 36/120
# 9/9 [==============================] - 3s 291ms/step - loss: 0.0630 - acc: 0.5629 - dice_coef_: 0.0687 - val_loss: 0.0414 - val_acc: 0.5417 - val_dice_coef_: 0.0504
# Epoch 37/120
# 9/9 [==============================] - 3s 298ms/step - loss: 0.0592 - acc: 0.5368 - dice_coef_: 0.0650 - val_loss: 0.0399 - val_acc: 0.5598 - val_dice_coef_: 0.0521
# Epoch 38/120
# 9/9 [==============================] - 3s 289ms/step - loss: 0.0526 - acc: 0.5505 - dice_coef_: 0.0631 - val_loss: 0.0463 - val_acc: 0.4603 - val_dice_coef_: 0.0432
# Epoch 39/120
# 9/9 [==============================] - 3s 289ms/step - loss: 0.0503 - acc: 0.5343 - dice_coef_: 0.0658 - val_loss: 0.0359 - val_acc: 0.5253 - val_dice_coef_: 0.0523
# Epoch 40/120
# 9/9 [==============================] - 3s 288ms/step - loss: 0.0537 - acc: 0.5288 - dice_coef_: 0.0636 - val_loss: 0.0359 - val_acc: 0.5052 - val_dice_coef_: 0.0515
# Epoch 41/120
# 9/9 [==============================] - 3s 290ms/step - loss: 0.0484 - acc: 0.5300 - dice_coef_: 0.0655 - val_loss: 0.0337 - val_acc: 0.5086 - val_dice_coef_: 0.0518
# Epoch 42/120
# 9/9 [==============================] - 3s 291ms/step - loss: 0.0546 - acc: 0.5287 - dice_coef_: 0.0709 - val_loss: 0.0338 - val_acc: 0.5247 - val_dice_coef_: 0.0535
# Epoch 43/120
# 9/9 [==============================] - 3s 290ms/step - loss: 0.0439 - acc: 0.5225 - dice_coef_: 0.0643 - val_loss: 0.0330 - val_acc: 0.5489 - val_dice_coef_: 0.0544
# Epoch 44/120
# 9/9 [==============================] - 3s 288ms/step - loss: 0.0494 - acc: 0.5293 - dice_coef_: 0.0787 - val_loss: 0.0297 - val_acc: 0.5053 - val_dice_coef_: 0.0534
# Epoch 45/120
# 9/9 [==============================] - 3s 298ms/step - loss: 0.0420 - acc: 0.5197 - dice_coef_: 0.0625 - val_loss: 0.0318 - val_acc: 0.5468 - val_dice_coef_: 0.0544
# Epoch 46/120
# 9/9 [==============================] - 3s 290ms/step - loss: 0.0468 - acc: 0.5244 - dice_coef_: 0.0695 - val_loss: 0.0291 - val_acc: 0.4895 - val_dice_coef_: 0.0526
# Epoch 47/120
# 9/9 [==============================] - 3s 280ms/step - loss: 0.0433 - acc: 0.5240 - dice_coef_: 0.0690 - val_loss: 0.0274 - val_acc: 0.5201 - val_dice_coef_: 0.0548
# Epoch 48/120
# 9/9 [==============================] - 3s 293ms/step - loss: 0.0420 - acc: 0.5281 - dice_coef_: 0.0700 - val_loss: 0.0265 - val_acc: 0.5231 - val_dice_coef_: 0.0544
# Epoch 49/120
# 9/9 [==============================] - 3s 297ms/step - loss: 0.0434 - acc: 0.5326 - dice_coef_: 0.0695 - val_loss: 0.0261 - val_acc: 0.5213 - val_dice_coef_: 0.0542
# Epoch 50/120
# 9/9 [==============================] - 3s 289ms/step - loss: 0.0392 - acc: 0.5386 - dice_coef_: 0.0738 - val_loss: 0.0254 - val_acc: 0.5360 - val_dice_coef_: 0.0560
# Epoch 51/120
# 9/9 [==============================] - 3s 290ms/step - loss: 0.0393 - acc: 0.5413 - dice_coef_: 0.0750 - val_loss: 0.0238 - val_acc: 0.5286 - val_dice_coef_: 0.0559
# Epoch 52/120
# 9/9 [==============================] - 3s 291ms/step - loss: 0.0366 - acc: 0.5420 - dice_coef_: 0.0693 - val_loss: 0.0229 - val_acc: 0.5267 - val_dice_coef_: 0.0557
# Epoch 53/120
# 9/9 [==============================] - 3s 290ms/step - loss: 0.0397 - acc: 0.5471 - dice_coef_: 0.0749 - val_loss: 0.0278 - val_acc: 0.5830 - val_dice_coef_: 0.0565
# Epoch 54/120
# 9/9 [==============================] - 3s 298ms/step - loss: 0.0370 - acc: 0.5593 - dice_coef_: 0.0734 - val_loss: 0.0248 - val_acc: 0.5672 - val_dice_coef_: 0.0568
# Epoch 55/120
# 9/9 [==============================] - 3s 281ms/step - loss: 0.0340 - acc: 0.5484 - dice_coef_: 0.0687 - val_loss: 0.0213 - val_acc: 0.5547 - val_dice_coef_: 0.0573
# Epoch 56/120
# 9/9 [==============================] - 3s 289ms/step - loss: 0.0360 - acc: 0.5673 - dice_coef_: 0.0737 - val_loss: 0.0232 - val_acc: 0.5150 - val_dice_coef_: 0.0553
# Epoch 57/120
# 9/9 [==============================] - 3s 299ms/step - loss: 0.0362 - acc: 0.5493 - dice_coef_: 0.0763 - val_loss: 0.0259 - val_acc: 0.6048 - val_dice_coef_: 0.0569
# Epoch 58/120
# 9/9 [==============================] - 3s 288ms/step - loss: 0.0317 - acc: 0.5727 - dice_coef_: 0.0784 - val_loss: 0.0201 - val_acc: 0.5662 - val_dice_coef_: 0.0577
# Epoch 59/120
# 9/9 [==============================] - 3s 290ms/step - loss: 0.0336 - acc: 0.5689 - dice_coef_: 0.0717 - val_loss: 0.0201 - val_acc: 0.5437 - val_dice_coef_: 0.0573
# Epoch 60/120
# 9/9 [==============================] - 3s 289ms/step - loss: 0.0330 - acc: 0.5715 - dice_coef_: 0.0724 - val_loss: 0.0212 - val_acc: 0.5203 - val_dice_coef_: 0.0555
# Epoch 61/120
# 9/9 [==============================] - 3s 291ms/step - loss: 0.0313 - acc: 0.5699 - dice_coef_: 0.0769 - val_loss: 0.0205 - val_acc: 0.5457 - val_dice_coef_: 0.0574
# Epoch 62/120
# 9/9 [==============================] - 3s 291ms/step - loss: 0.0294 - acc: 0.5667 - dice_coef_: 0.0675 - val_loss: 0.0250 - val_acc: 0.6254 - val_dice_coef_: 0.0567
# Epoch 63/120
# 9/9 [==============================] - 3s 290ms/step - loss: 0.0321 - acc: 0.5841 - dice_coef_: 0.0795 - val_loss: 0.0180 - val_acc: 0.5562 - val_dice_coef_: 0.0575
# Epoch 64/120
# 9/9 [==============================] - 3s 298ms/step - loss: 0.0289 - acc: 0.5807 - dice_coef_: 0.0766 - val_loss: 0.0187 - val_acc: 0.5870 - val_dice_coef_: 0.0579
# Epoch 65/120
# 9/9 [==============================] - 3s 289ms/step - loss: 0.0301 - acc: 0.5811 - dice_coef_: 0.0777 - val_loss: 0.0182 - val_acc: 0.5456 - val_dice_coef_: 0.0570
# Epoch 66/120
# 9/9 [==============================] - 3s 289ms/step - loss: 0.0280 - acc: 0.5750 - dice_coef_: 0.0815 - val_loss: 0.0218 - val_acc: 0.6099 - val_dice_coef_: 0.0580
# Epoch 67/120
# 9/9 [==============================] - 3s 289ms/step - loss: 0.0278 - acc: 0.5961 - dice_coef_: 0.0663 - val_loss: 0.0171 - val_acc: 0.5704 - val_dice_coef_: 0.0579
# Epoch 68/120
# 9/9 [==============================] - 3s 280ms/step - loss: 0.0304 - acc: 0.5851 - dice_coef_: 0.0832 - val_loss: 0.0176 - val_acc: 0.6039 - val_dice_coef_: 0.0582
# Epoch 69/120
# 9/9 [==============================] - 3s 298ms/step - loss: 0.0259 - acc: 0.5938 - dice_coef_: 0.0738 - val_loss: 0.0164 - val_acc: 0.5691 - val_dice_coef_: 0.0580
# Epoch 70/120
# 9/9 [==============================] - 3s 288ms/step - loss: 0.0273 - acc: 0.5883 - dice_coef_: 0.0792 - val_loss: 0.0174 - val_acc: 0.5676 - val_dice_coef_: 0.0570
# Epoch 71/120
# 9/9 [==============================] - 3s 299ms/step - loss: 0.0267 - acc: 0.5919 - dice_coef_: 0.0803 - val_loss: 0.0166 - val_acc: 0.6109 - val_dice_coef_: 0.0584
# Epoch 72/120
# 9/9 [==============================] - 3s 281ms/step - loss: 0.0254 - acc: 0.5872 - dice_coef_: 0.0728 - val_loss: 0.0192 - val_acc: 0.6439 - val_dice_coef_: 0.0580
# Epoch 73/120
# 9/9 [==============================] - 3s 292ms/step - loss: 0.0265 - acc: 0.6064 - dice_coef_: 0.0823 - val_loss: 0.0206 - val_acc: 0.6392 - val_dice_coef_: 0.0579
# Epoch 74/120
# 9/9 [==============================] - 3s 288ms/step - loss: 0.0241 - acc: 0.5974 - dice_coef_: 0.0684 - val_loss: 0.0166 - val_acc: 0.6156 - val_dice_coef_: 0.0586
# Epoch 75/120
# 9/9 [==============================] - 3s 299ms/step - loss: 0.0273 - acc: 0.6085 - dice_coef_: 0.0844 - val_loss: 0.0156 - val_acc: 0.5963 - val_dice_coef_: 0.0587
# Epoch 76/120
# 9/9 [==============================] - 3s 289ms/step - loss: 0.0210 - acc: 0.6143 - dice_coef_: 0.0753 - val_loss: 0.0155 - val_acc: 0.5951 - val_dice_coef_: 0.0586
# Epoch 77/120
# 9/9 [==============================] - 3s 289ms/step - loss: 0.0248 - acc: 0.6119 - dice_coef_: 0.0829 - val_loss: 0.0175 - val_acc: 0.6001 - val_dice_coef_: 0.0587
# Epoch 78/120
# 9/9 [==============================] - 3s 290ms/step - loss: 0.0236 - acc: 0.6112 - dice_coef_: 0.0801 - val_loss: 0.0151 - val_acc: 0.6018 - val_dice_coef_: 0.0589
# Epoch 79/120
# 9/9 [==============================] - 3s 290ms/step - loss: 0.0222 - acc: 0.6079 - dice_coef_: 0.0752 - val_loss: 0.0146 - val_acc: 0.6159 - val_dice_coef_: 0.0590
# Epoch 80/120
# 9/9 [==============================] - 3s 289ms/step - loss: 0.0234 - acc: 0.6132 - dice_coef_: 0.0819 - val_loss: 0.0147 - val_acc: 0.6320 - val_dice_coef_: 0.0591
# Epoch 81/120
# 9/9 [==============================] - 3s 289ms/step - loss: 0.0219 - acc: 0.6245 - dice_coef_: 0.0862 - val_loss: 0.0157 - val_acc: 0.5834 - val_dice_coef_: 0.0581
# Epoch 82/120
# 9/9 [==============================] - 3s 300ms/step - loss: 0.0199 - acc: 0.6133 - dice_coef_: 0.0742 - val_loss: 0.0154 - val_acc: 0.6425 - val_dice_coef_: 0.0594
# Epoch 83/120
# 9/9 [==============================] - 3s 283ms/step - loss: 0.0230 - acc: 0.6171 - dice_coef_: 0.0766 - val_loss: 0.0151 - val_acc: 0.6194 - val_dice_coef_: 0.0591
# Epoch 84/120
# 9/9 [==============================] - 3s 290ms/step - loss: 0.0178 - acc: 0.6129 - dice_coef_: 0.0853 - val_loss: 0.0184 - val_acc: 0.6315 - val_dice_coef_: 0.0590
# Epoch 85/120
# 9/9 [==============================] - 3s 299ms/step - loss: 0.0218 - acc: 0.6139 - dice_coef_: 0.0812 - val_loss: 0.0205 - val_acc: 0.5953 - val_dice_coef_: 0.0566
# Epoch 86/120
# 9/9 [==============================] - 3s 290ms/step - loss: 0.0199 - acc: 0.6132 - dice_coef_: 0.0838 - val_loss: 0.0142 - val_acc: 0.5906 - val_dice_coef_: 0.0590
# Epoch 87/120
# 9/9 [==============================] - 3s 290ms/step - loss: 0.0192 - acc: 0.6189 - dice_coef_: 0.0835 - val_loss: 0.0145 - val_acc: 0.6084 - val_dice_coef_: 0.0590
# Epoch 88/120
# 9/9 [==============================] - 3s 289ms/step - loss: 0.0187 - acc: 0.6195 - dice_coef_: 0.0801 - val_loss: 0.0199 - val_acc: 0.5776 - val_dice_coef_: 0.0564
# Epoch 89/120
# 9/9 [==============================] - 3s 291ms/step - loss: 0.0185 - acc: 0.6080 - dice_coef_: 0.0819 - val_loss: 0.0141 - val_acc: 0.6322 - val_dice_coef_: 0.0597
# Epoch 90/120
# 9/9 [==============================] - 3s 290ms/step - loss: 0.0189 - acc: 0.6144 - dice_coef_: 0.0840 - val_loss: 0.0152 - val_acc: 0.6332 - val_dice_coef_: 0.0596
# Epoch 91/120
# 9/9 [==============================] - 3s 290ms/step - loss: 0.0186 - acc: 0.6243 - dice_coef_: 0.0863 - val_loss: 0.0165 - val_acc: 0.5988 - val_dice_coef_: 0.0583
# Epoch 92/120
# 9/9 [==============================] - 3s 290ms/step - loss: 0.0182 - acc: 0.6099 - dice_coef_: 0.0766 - val_loss: 0.0143 - val_acc: 0.5962 - val_dice_coef_: 0.0590
# Epoch 93/120
# 9/9 [==============================] - 3s 290ms/step - loss: 0.0188 - acc: 0.6238 - dice_coef_: 0.0883 - val_loss: 0.0136 - val_acc: 0.6266 - val_dice_coef_: 0.0599
# Epoch 94/120
# 9/9 [==============================] - 3s 299ms/step - loss: 0.0169 - acc: 0.6212 - dice_coef_: 0.0776 - val_loss: 0.0131 - val_acc: 0.6337 - val_dice_coef_: 0.0599
# Epoch 95/120
# 9/9 [==============================] - 3s 282ms/step - loss: 0.0179 - acc: 0.6224 - dice_coef_: 0.0834 - val_loss: 0.0161 - val_acc: 0.6518 - val_dice_coef_: 0.0593
# Epoch 96/120
# 9/9 [==============================] - 3s 300ms/step - loss: 0.0174 - acc: 0.6309 - dice_coef_: 0.0864 - val_loss: 0.0125 - val_acc: 0.6171 - val_dice_coef_: 0.0601
# Epoch 97/120
# 9/9 [==============================] - 3s 280ms/step - loss: 0.0158 - acc: 0.6259 - dice_coef_: 0.0840 - val_loss: 0.0124 - val_acc: 0.6287 - val_dice_coef_: 0.0602
# Epoch 98/120
# 9/9 [==============================] - 3s 299ms/step - loss: 0.0173 - acc: 0.6272 - dice_coef_: 0.0890 - val_loss: 0.0126 - val_acc: 0.6120 - val_dice_coef_: 0.0601
# Epoch 99/120
# 9/9 [==============================] - 3s 289ms/step - loss: 0.0154 - acc: 0.6155 - dice_coef_: 0.0799 - val_loss: 0.0127 - val_acc: 0.6258 - val_dice_coef_: 0.0604
# Epoch 100/120
# 9/9 [==============================] - 3s 291ms/step - loss: 0.0168 - acc: 0.6240 - dice_coef_: 0.0839 - val_loss: 0.0120 - val_acc: 0.6180 - val_dice_coef_: 0.0602
# Epoch 101/120
# 9/9 [==============================] - 3s 288ms/step - loss: 0.0164 - acc: 0.6214 - dice_coef_: 0.0862 - val_loss: 0.0117 - val_acc: 0.6388 - val_dice_coef_: 0.0606
# Epoch 102/120
# 9/9 [==============================] - 3s 290ms/step - loss: 0.0165 - acc: 0.6252 - dice_coef_: 0.0814 - val_loss: 0.0150 - val_acc: 0.6189 - val_dice_coef_: 0.0595
# Epoch 103/120
# 9/9 [==============================] - 3s 298ms/step - loss: 0.0134 - acc: 0.6184 - dice_coef_: 0.0852 - val_loss: 0.0135 - val_acc: 0.6470 - val_dice_coef_: 0.0603
# Epoch 104/120
# 9/9 [==============================] - 3s 281ms/step - loss: 0.0183 - acc: 0.6344 - dice_coef_: 0.0884 - val_loss: 0.0133 - val_acc: 0.6301 - val_dice_coef_: 0.0600
# Epoch 105/120
# 9/9 [==============================] - 3s 289ms/step - loss: 0.0120 - acc: 0.6238 - dice_coef_: 0.0797 - val_loss: 0.0131 - val_acc: 0.6572 - val_dice_coef_: 0.0605
# Epoch 106/120
# 9/9 [==============================] - 3s 300ms/step - loss: 0.0173 - acc: 0.6256 - dice_coef_: 0.0888 - val_loss: 0.0127 - val_acc: 0.6390 - val_dice_coef_: 0.0606
# Epoch 107/120
# 9/9 [==============================] - 3s 281ms/step - loss: 0.0147 - acc: 0.6323 - dice_coef_: 0.0932 - val_loss: 0.0115 - val_acc: 0.6273 - val_dice_coef_: 0.0608
# Epoch 108/120
# 9/9 [==============================] - 3s 299ms/step - loss: 0.0133 - acc: 0.6145 - dice_coef_: 0.0788 - val_loss: 0.0133 - val_acc: 0.6495 - val_dice_coef_: 0.0607
# Epoch 109/120
# 9/9 [==============================] - 3s 292ms/step - loss: 0.0125 - acc: 0.6255 - dice_coef_: 0.0887 - val_loss: 0.0128 - val_acc: 0.6252 - val_dice_coef_: 0.0607
# Epoch 110/120
# 9/9 [==============================] - 3s 288ms/step - loss: 0.0158 - acc: 0.6135 - dice_coef_: 0.0886 - val_loss: 0.0113 - val_acc: 0.6101 - val_dice_coef_: 0.0609
# Epoch 111/120
# 9/9 [==============================] - 3s 290ms/step - loss: 0.0139 - acc: 0.6109 - dice_coef_: 0.0866 - val_loss: 0.0142 - val_acc: 0.6004 - val_dice_coef_: 0.0599
# Epoch 112/120
# 9/9 [==============================] - 3s 299ms/step - loss: 0.0122 - acc: 0.6139 - dice_coef_: 0.0804 - val_loss: 0.0118 - val_acc: 0.6114 - val_dice_coef_: 0.0609
# Epoch 113/120
# 9/9 [==============================] - 3s 281ms/step - loss: 0.0151 - acc: 0.6277 - dice_coef_: 0.0913 - val_loss: 0.0141 - val_acc: 0.6211 - val_dice_coef_: 0.0600
# Epoch 114/120
# 9/9 [==============================] - 3s 291ms/step - loss: 0.0134 - acc: 0.6255 - dice_coef_: 0.0877 - val_loss: 0.0125 - val_acc: 0.6411 - val_dice_coef_: 0.0608
# Epoch 115/120
# 9/9 [==============================] - 3s 290ms/step - loss: 0.0160 - acc: 0.6278 - dice_coef_: 0.0906 - val_loss: 0.0114 - val_acc: 0.6334 - val_dice_coef_: 0.0611
# Epoch 116/120
# 9/9 [==============================] - 3s 301ms/step - loss: 0.0135 - acc: 0.6168 - dice_coef_: 0.0820 - val_loss: 0.0162 - val_acc: 0.6049 - val_dice_coef_: 0.0588
# Epoch 117/120
# 9/9 [==============================] - 3s 290ms/step - loss: 0.0111 - acc: 0.6178 - dice_coef_: 0.0841 - val_loss: 0.0116 - val_acc: 0.6396 - val_dice_coef_: 0.0612
# Epoch 118/120
# 9/9 [==============================] - 3s 289ms/step - loss: 0.0140 - acc: 0.6177 - dice_coef_: 0.0858 - val_loss: 0.0110 - val_acc: 0.6392 - val_dice_coef_: 0.0613
# Epoch 119/120
# 9/9 [==============================] - 3s 291ms/step - loss: 0.0143 - acc: 0.6246 - dice_coef_: 0.0883 - val_loss: 0.0111 - val_acc: 0.6182 - val_dice_coef_: 0.0610
# Epoch 120/120
# 9/9 [==============================] - 3s 289ms/step - loss: 0.0127 - acc: 0.6288 - dice_coef_: 0.0884 - val_loss: 0.0110 - val_acc: 0.6232 - val_dice_coef_: 0.0612

# %%
plt.subplot(211)
plt.plot(H.history['loss'], label='train')
plt.plot(H.history['val_loss'], label='val')
plt.title('loss')
plt.legend()

plt.subplot(212)
plt.plot(H.history['dice_coef_'], label='train')
plt.plot(H.history['val_dice_coef_'], label='val')
plt.title('acc')
plt.legend()

# %%
def get_predict(id,model):
    test = x_train[id,:,:,:]
    return model.predict(test.reshape(1,256,256,1))

# %%
id = 70
y_pred = get_predict(id,mm)

# %%
y_pred.shape
# Out:
# (1, 256, 256, 4)

# %% [markdown]
# # results

# %%
plt.figure(figsize=(20, 15))

for i in range(4):
    plt.subplot(1,4,i+1)
    plt.imshow(x_train[id,:,:,0])
    slice_ = y_pred[0,:,:,i]
    x = np.sum(y_pred, axis = 3)[0]
    print(slice_.min(),slice_.max())
    plt.imshow(slice_,vmin=0,vmax=1, alpha=0.8)
plt.show()
# Out:
# 3.26888e-24 1.0
# 3.780579e-20 1.0
# 1.4259072e-31 1.0
# 2.3270346e-34 1.0

# %% [markdown]
# mm.compile(optimizer = RMSprop(lr = 1e-5), loss=['categorical_crossentropy'],
#               metrics=['accuracy',dice_coef_])
# # fit model on the augmented dataset
# #250/32 =7,8 (32 batch_size)
# steps_per_epoch = len(x_train) // 16
# H = mm.fit_generator(it, validation_data = (x_val,y_val),
#                                           steps_per_epoch= steps_per_epoch,
#                                           epochs=120)

# %%
plt.figure(figsize=(20, 15))

for i in range(4):
    plt.subplot(1,4,i+1)
    plt.imshow(x_train[id,:,:,0])
    slice_ = y_pred[0,:,:,i]
    x = np.sum(y_pred, axis = 3)[0]
    print(slice_.min(),slice_.max())
    plt.imshow(slice_,vmin=0,vmax=1, alpha=0.8)
plt.show()
# Out:
# 5.390363e-13 1.0
# 3.2095865e-16 0.9999882
# 1.8785873e-22 0.9999994
# 1.6487673e-20 0.99999964

# %% [markdown]
# # real

# %%
plt.figure(figsize=(20, 15))
for i in range(4):
    plt.subplot(1,4,i+1)
    slice_ = y_train[id,:,:,i]
    plt.imshow(y_train[id,:,:,0])
    plt.imshow(slice_, alpha=0.78)    
plt.show()

# %%
H_ = model_.fit_generator(it, validation_data = (x_val,y_val),
                                          steps_per_epoch= steps_per_epoch, 
                                          epochs=40)
# Out:
# Epoch 1/40
# 4/4 [==============================] - 2s 603ms/step - loss: 9.1564e-04 - acc: 0.5946 - dice_coef_: 0.0981 - val_loss: 0.0108 - val_acc: 0.5854 - val_dice_coef_: 0.0659
# Epoch 2/40
# 4/4 [==============================] - 2s 572ms/step - loss: 0.0011 - acc: 0.5950 - dice_coef_: 0.0955 - val_loss: 0.0222 - val_acc: 0.6116 - val_dice_coef_: 0.0643
# Epoch 3/40
# 4/4 [==============================] - 2s 590ms/step - loss: 0.0013 - acc: 0.6132 - dice_coef_: 0.0966 - val_loss: 0.0099 - val_acc: 0.6094 - val_dice_coef_: 0.0664
# Epoch 4/40
# 4/4 [==============================] - 2s 575ms/step - loss: 0.0011 - acc: 0.6083 - dice_coef_: 0.0961 - val_loss: 0.0119 - val_acc: 0.6041 - val_dice_coef_: 0.0662
# Epoch 5/40
# 4/4 [==============================] - 2s 565ms/step - loss: 0.0011 - acc: 0.6128 - dice_coef_: 0.0978 - val_loss: 0.0174 - val_acc: 0.6005 - val_dice_coef_: 0.0653
# Epoch 6/40
# 4/4 [==============================] - 2s 572ms/step - loss: 7.2712e-04 - acc: 0.5892 - dice_coef_: 0.0920 - val_loss: 0.0121 - val_acc: 0.5957 - val_dice_coef_: 0.0663
# Epoch 7/40
# 4/4 [==============================] - 2s 571ms/step - loss: 7.1716e-04 - acc: 0.6039 - dice_coef_: 0.1043 - val_loss: 0.0160 - val_acc: 0.5991 - val_dice_coef_: 0.0652
# Epoch 8/40
# 4/4 [==============================] - 2s 571ms/step - loss: 8.7138e-04 - acc: 0.6031 - dice_coef_: 0.0906 - val_loss: 0.0179 - val_acc: 0.6113 - val_dice_coef_: 0.0653
# Epoch 9/40
# 4/4 [==============================] - 2s 594ms/step - loss: 5.1595e-04 - acc: 0.6152 - dice_coef_: 0.0965 - val_loss: 0.0135 - val_acc: 0.6030 - val_dice_coef_: 0.0660
# Epoch 10/40
# 4/4 [==============================] - 2s 572ms/step - loss: 6.9807e-04 - acc: 0.6153 - dice_coef_: 0.1026 - val_loss: 0.0182 - val_acc: 0.6159 - val_dice_coef_: 0.0654
# Epoch 11/40
# 4/4 [==============================] - 2s 598ms/step - loss: 9.9928e-04 - acc: 0.6203 - dice_coef_: 0.0951 - val_loss: 0.0133 - val_acc: 0.6235 - val_dice_coef_: 0.0664
# Epoch 12/40
# 4/4 [==============================] - 2s 570ms/step - loss: 7.9443e-04 - acc: 0.6170 - dice_coef_: 0.1063 - val_loss: 0.0120 - val_acc: 0.6113 - val_dice_coef_: 0.0665
# Epoch 13/40
# 4/4 [==============================] - 2s 572ms/step - loss: 6.2562e-04 - acc: 0.6095 - dice_coef_: 0.0898 - val_loss: 0.0153 - val_acc: 0.5884 - val_dice_coef_: 0.0658
# Epoch 14/40
# 4/4 [==============================] - 2s 572ms/step - loss: 8.4231e-04 - acc: 0.5958 - dice_coef_: 0.1004 - val_loss: 0.0239 - val_acc: 0.6043 - val_dice_coef_: 0.0650
# Epoch 15/40
# 4/4 [==============================] - 2s 568ms/step - loss: 9.7083e-04 - acc: 0.5925 - dice_coef_: 0.0929 - val_loss: 0.0161 - val_acc: 0.5943 - val_dice_coef_: 0.0655
# Epoch 16/40
# 4/4 [==============================] - 2s 573ms/step - loss: 6.8992e-04 - acc: 0.6091 - dice_coef_: 0.0960 - val_loss: 0.0125 - val_acc: 0.6023 - val_dice_coef_: 0.0664
# Epoch 17/40
# 4/4 [==============================] - 2s 600ms/step - loss: 6.6096e-04 - acc: 0.6032 - dice_coef_: 0.1001 - val_loss: 0.0173 - val_acc: 0.6239 - val_dice_coef_: 0.0658
# Epoch 18/40
# 4/4 [==============================] - 2s 558ms/step - loss: 7.7039e-04 - acc: 0.6316 - dice_coef_: 0.0993 - val_loss: 0.0138 - val_acc: 0.5884 - val_dice_coef_: 0.0660
# Epoch 19/40
# 4/4 [==============================] - 2s 598ms/step - loss: 0.0014 - acc: 0.5892 - dice_coef_: 0.0894 - val_loss: 0.0227 - val_acc: 0.6092 - val_dice_coef_: 0.0654
# Epoch 20/40
# 4/4 [==============================] - 2s 574ms/step - loss: 0.0018 - acc: 0.5857 - dice_coef_: 0.1000 - val_loss: 0.0141 - val_acc: 0.6019 - val_dice_coef_: 0.0662
# Epoch 21/40
# 4/4 [==============================] - 2s 575ms/step - loss: 8.9287e-04 - acc: 0.6136 - dice_coef_: 0.1015 - val_loss: 0.0121 - val_acc: 0.5981 - val_dice_coef_: 0.0662
# Epoch 22/40
# 4/4 [==============================] - 2s 577ms/step - loss: 0.0010 - acc: 0.5952 - dice_coef_: 0.0906 - val_loss: 0.0188 - val_acc: 0.6216 - val_dice_coef_: 0.0651
# Epoch 23/40
# 4/4 [==============================] - 2s 599ms/step - loss: 5.5668e-04 - acc: 0.6286 - dice_coef_: 0.0948 - val_loss: 0.0142 - val_acc: 0.6146 - val_dice_coef_: 0.0657
# Epoch 24/40
# 4/4 [==============================] - 2s 577ms/step - loss: 6.9432e-04 - acc: 0.6160 - dice_coef_: 0.0992 - val_loss: 0.0163 - val_acc: 0.6272 - val_dice_coef_: 0.0656
# Epoch 25/40
# 4/4 [==============================] - 2s 573ms/step - loss: 5.9514e-04 - acc: 0.6188 - dice_coef_: 0.0980 - val_loss: 0.0121 - val_acc: 0.6069 - val_dice_coef_: 0.0662
# Epoch 26/40
# 4/4 [==============================] - 2s 601ms/step - loss: 5.2292e-04 - acc: 0.6119 - dice_coef_: 0.0949 - val_loss: 0.0147 - val_acc: 0.6206 - val_dice_coef_: 0.0661
# Epoch 27/40
# 4/4 [==============================] - 2s 554ms/step - loss: 4.4581e-04 - acc: 0.6157 - dice_coef_: 0.0995 - val_loss: 0.0120 - val_acc: 0.5986 - val_dice_coef_: 0.0665
# Epoch 28/40
# 4/4 [==============================] - 2s 585ms/step - loss: 3.5205e-04 - acc: 0.6037 - dice_coef_: 0.0933 - val_loss: 0.0157 - val_acc: 0.6110 - val_dice_coef_: 0.0661
# Epoch 29/40
# 4/4 [==============================] - 2s 582ms/step - loss: 4.4546e-04 - acc: 0.6114 - dice_coef_: 0.1083 - val_loss: 0.0143 - val_acc: 0.5958 - val_dice_coef_: 0.0660
# Epoch 30/40
# 4/4 [==============================] - 2s 606ms/step - loss: 3.1257e-04 - acc: 0.5963 - dice_coef_: 0.0918 - val_loss: 0.0167 - val_acc: 0.6027 - val_dice_coef_: 0.0661
# Epoch 31/40
# 4/4 [==============================] - 2s 592ms/step - loss: 5.0588e-04 - acc: 0.5989 - dice_coef_: 0.0983 - val_loss: 0.0133 - val_acc: 0.5954 - val_dice_coef_: 0.0665
# Epoch 32/40
# 4/4 [==============================] - 2s 592ms/step - loss: 4.1777e-04 - acc: 0.6031 - dice_coef_: 0.0918 - val_loss: 0.0185 - val_acc: 0.6186 - val_dice_coef_: 0.0659
# Epoch 33/40
# 4/4 [==============================] - 2s 615ms/step - loss: 3.8726e-04 - acc: 0.6165 - dice_coef_: 0.1083 - val_loss: 0.0139 - val_acc: 0.5980 - val_dice_coef_: 0.0664
# Epoch 34/40
# 4/4 [==============================] - 2s 593ms/step - loss: 3.9444e-04 - acc: 0.6132 - dice_coef_: 0.0959 - val_loss: 0.0160 - val_acc: 0.6182 - val_dice_coef_: 0.0663
# Epoch 35/40
# 4/4 [==============================] - 2s 591ms/step - loss: 3.1997e-04 - acc: 0.6118 - dice_coef_: 0.0910 - val_loss: 0.0124 - val_acc: 0.6011 - val_dice_coef_: 0.0667
# Epoch 36/40
# 4/4 [==============================] - 2s 592ms/step - loss: 2.4810e-04 - acc: 0.6068 - dice_coef_: 0.0969 - val_loss: 0.0162 - val_acc: 0.6019 - val_dice_coef_: 0.0659
# Epoch 37/40
# 4/4 [==============================] - 2s 612ms/step - loss: 3.7648e-04 - acc: 0.6022 - dice_coef_: 0.0960 - val_loss: 0.0152 - val_acc: 0.5948 - val_dice_coef_: 0.0664
# Epoch 38/40
# 4/4 [==============================] - 2s 592ms/step - loss: 3.4227e-04 - acc: 0.5999 - dice_coef_: 0.0971 - val_loss: 0.0156 - val_acc: 0.5949 - val_dice_coef_: 0.0663
# Epoch 39/40
# 4/4 [==============================] - 2s 595ms/step - loss: 3.1642e-04 - acc: 0.6021 - dice_coef_: 0.1017 - val_loss: 0.0188 - val_acc: 0.6041 - val_dice_coef_: 0.0658
# Epoch 40/40
# 4/4 [==============================] - 2s 584ms/step - loss: 3.2232e-04 - acc: 0.6140 - dice_coef_: 0.0954 - val_loss: 0.0141 - val_acc: 0.6049 - val_dice_coef_: 0.0666

# %%
plt.subplot(211)
plt.plot(H_.history['loss'], label='train')
plt.plot(H_.history['val_loss'], label='val')
plt.title('loss')
plt.legend()

plt.subplot(212)
plt.plot(H_.history['dice_coef_'], label='train')
plt.plot(H_.history['val_dice_coef_'], label='val')
plt.title('acc')
plt.legend()

# %%
id = 110


test = x_train[id,:,:,:]
y_pred = model_.predict(test.reshape(1,256,256,1))

# %% [markdown]
# # results

# %%
plt.figure(figsize=(20, 15))

for i in range(4):
    plt.subplot(1,4,i+1)
    plt.imshow(x_train[id,:,:,0])
    slice_ = y_pred[0,:,:,i]
    x = np.sum(y_pred, axis = 3)[0]
    print(slice_.min(),slice_.max())
    plt.imshow(slice_,vmin=0,vmax=1, alpha=0.8)
plt.show()
# Out:
# 2.1086617e-34 1.0
# 0.0 1.0
# 0.0 1.0
# 0.0 1.0
