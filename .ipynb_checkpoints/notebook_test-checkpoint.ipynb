# %%
import numpy as np
import matplotlib.pyplot as plt
from skimage.transform import resize # from scipy.misc import imresize
from tqdm import tqdm
import nibabel

# %%
def read_train_exam(exam_nb):
    image = nibabel.load('../chaos/train/%02d-T2SPIR-src.nii.gz'%(exam_nb))
    mask = nibabel.load('../chaos/train/%02d-T2SPIR-mask.nii.gz'%(exam_nb))
    return image, mask

def read_test_exam(exam_nb):
    image = nibabel.load('../chaos/test/%02d-T2SPIR-src.nii.gz'%(exam_nb))
    return image

# %%
img_rows,img_cols = 256,256
def preprocess(image):
    #shape (slide,256,256)
    image_ = np.ndarray((image.shape[2],img_rows,img_cols,1))
    for i in range(image.shape[2]):
        image_[i,:,:,0] = resize(image.get_data()[:,:,i],(img_rows,img_cols),mode='reflect',preserve_range=True,
                               anti_aliasing=True)            
    #print(image_.shape)
    return image_

# %%
image_1, mask_1 = read_train_exam(2)

# %%
print("before scale {},{},".format(np.unique(mask_1.get_data()),np.unique(image_1.get_data())))
# Out:
# before scale [0 1 2 3 4],[   0    1    2 ... 1474 1501 1503],

# %%
print("after scale {},{}".format(np.unique(preprocess(mask_1)),np.unique(preprocess(image_1))))
# Out:
# after scale [0.       0.015625 0.015625 ... 3.984375 3.984375 4.      ],[0.00000000e+00 1.56250000e-02 1.56250000e-02 ... 1.45790625e+03
#  1.46843750e+03 1.48428125e+03]

# %%
def mask_to_channels(mask,init,classes):
    #get mask for each class
    img = np.asarray([np.where(mask == i,1,0 ) for i in range(init,classes)])
    img = np.swapaxes(img,0,-1)#new shape (row,col,class)
    print(img.shape)
    return img

# %%
test = mask_1.get_data()[:,:,15]
img = mask_to_channels(test,0,5)
for i in range(0,5):
    plt.subplot(1,5,i+1)
    plt.imshow(img[:,:,i])
plt.show()

# %%
def create_data_train(train_ids = [1,2,3,5,8,10,13,19],background = 0):
    for idx, train_id in tqdm(enumerate(train_ids)):
        image, mask = read_train_exam(train_id)     
        image = preprocess(image)
        mask = preprocess(mask) 
        #transform le mask
        if background:
            #create mask for 5 classess
            mask = mask_to_channels(mask,0,5)[0]
        else:
            mask = mask_to_channels(mask,1,5)[0]            
       
        if idx > 0:
            train_data = np.concatenate((train_data, image),axis=0)
            train_mask = np.concatenate((train_mask, mask),axis=0)
        else:
            train_data = image
            train_mask = mask
    print("Final shape {},{}".format(train_data.shape,train_mask.shape))    
    np.savez_compressed('./dataset/imgs_train_{}'.format(background), imgs=train_data)
    np.savez_compressed('./dataset/imgs_mask_train_{}'.format(background), imgs_mask=train_mask)

# %%
#dataset training without background
create_data_train()
# Out:
# 1it [00:00,  3.35it/s]
# (1, 36, 256, 256, 4)
# 2it [00:00,  3.18it/s]
# (1, 26, 256, 256, 4)
# 3it [00:01,  2.44it/s]
# (1, 30, 256, 256, 4)
# 4it [00:01,  2.46it/s]
# (1, 30, 256, 256, 4)
# 5it [00:02,  2.29it/s]
# (1, 32, 256, 256, 4)
# (1, 36, 256, 256, 4)
# 6it [00:02,  2.14it/s]
# (1, 30, 256, 256, 4)
# 7it [00:03,  1.94it/s]
# (1, 30, 256, 256, 4)
# 8it [00:04,  1.71it/s]
# Final shape (250, 256, 256, 1),(250, 256, 256, 4)

# %%
#dataset training without background
create_data_train(background=1)
# Out:
# 1it [00:00,  3.06it/s]
# (1, 36, 256, 256, 5)
# 2it [00:00,  2.92it/s]
# (1, 26, 256, 256, 5)
# 3it [00:01,  2.61it/s]
# (1, 30, 256, 256, 5)
# 4it [00:01,  2.50it/s]
# (1, 30, 256, 256, 5)
# (1, 32, 256, 256, 5)
# 5it [00:02,  2.23it/s]
# (1, 36, 256, 256, 5)
# 6it [00:02,  2.03it/s]
# (1, 30, 256, 256, 5)
# 7it [00:03,  1.84it/s]
# (1, 30, 256, 256, 5)
# 8it [00:04,  1.68it/s]
# Final shape (250, 256, 256, 1),(250, 256, 256, 5)

# %% [markdown]
# ### plot images

# %%
img = np.load('./dataset/imgs_train_0.npz')['imgs']
img_mask = np.load('./dataset/imgs_mask_train_0.npz')['imgs_mask']

# %%
img[:,:,:].shape
# Out:
# (250, 256, 256, 1)

# %%
img[:,:,:,0].shape
# Out:
# (250, 256, 256)

# %%
#plot random samples from data
def plot_random_images(data,mask,size,id):
    index = np.random.choice(range(data.shape[0]),size)
    plt.figure(figsize=(20, 15))
    for i,x in enumerate(index):
        plt.subplot(1, len(index), i+1)
        plt.imshow(data[x,:,:,0], cmap='gray', interpolation='nearest')
        plt.imshow(mask[x,:,:,id], cmap='jet', alpha=0.5)
    plt.show()

# %%
#plot random samples from training data
print("Training data")
plot_random_images(img,img_mask,5,1)
# Out:
# Training data

# %%
plot_random_images(img,img_mask,5,3)

# %%
print(np.unique(img))
# Out:
# [0.00000000e+00 1.00974196e-28 1.51461294e-28 ... 2.02000000e+03
#  2.04100000e+03 2.04300000e+03]

# %%
imgs_train = img.astype('float32')
mean = np.mean(imgs_train)  # mean for data centering
std = np.std(imgs_train)  # std for data normalization

imgs_train -= mean
imgs_train /= std

# %%
print(np.unique(imgs_train))
# Out:
# [-0.53052306 -0.53049946 -0.53047585 ... 11.664149   11.790925
#  11.8029995 ]

# %% [markdown]
# ### test

# %%
def get_data_test(test_ids = [21,22,32,39]):
    for idx, test_id in tqdm(enumerate(test_ids)):
        image = read_test_exam(test_id)     
        image = preprocess(image)
        print("img {}".format(image.shape))
        if idx > 0:
            test_data = np.concatenate((test_data, image),axis=0)
        else:
            test_data = image
    print("Final shape {}".format(test_data.shape))    
    np.savez_compressed('./dataset/imgs_test', imgs=test_data)

# %%
get_data_test()
# Out:
# 2it [00:00,  8.78it/s]
# img (31, 256, 256, 1)
# img (33, 256, 256, 1)
# 4it [00:00,  8.10it/s]
# img (39, 256, 256, 1)
# img (26, 256, 256, 1)
# Final shape (129, 256, 256, 1)

# %% [markdown]
# # MODEL

# %%
#version tf1
from keras.models import Model
from keras.layers import Input, concatenate, Conv2D, MaxPooling2D, Conv2DTranspose
from keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint
from keras import backend as K


from data import load_train_data, load_test_data

K.set_image_data_format('channels_last')  # TF dimension ordering in this code
# Out:
# Using TensorFlow backend.

# %%
img_rows = 256
img_cols = 256

# %%
smooth = 1.
#batch 32!
def dice_coef_(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)
def dice_coef(y_true, y_pred):
    dice_liver = dice_coef_(y_true[0,:,:,0],y_pred[0,:,:,0])
    dice_rkidney = dice_coef_(y_true[0,:,:,1], y_pred[0,:,:,1])
    dice_lkidney = dice_coef_(y_true[0,:,:,2], y_pred[0,:,:,2])
    dice_spleen = dice_coef_(y_true[0,:,:,3], y_pred[0,:,:,3])
    #return dice_liver + (dice_rkidney+dice_lkidney)+dice_spleen
    return dice_liver + 10*dice_rkidney + 10*dice_lkidney +5*dice_spleen
def dice_coef_loss(y_true, y_pred):  
    return -dice_coef_(y_true, y_pred)

# %%
def get_unet():
    inputs = Input((img_rows, img_cols, 1))
    conv1 = Conv2D(32, (3, 3), activation='relu', padding='same')(inputs)
    conv1 = Conv2D(32, (3, 3), activation='relu', padding='same')(conv1)
    pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)

    conv2 = Conv2D(64, (3, 3), activation='relu', padding='same')(pool1)
    conv2 = Conv2D(64, (3, 3), activation='relu', padding='same')(conv2)
    pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)

    conv3 = Conv2D(128, (3, 3), activation='relu', padding='same')(pool2)
    conv3 = Conv2D(128, (3, 3), activation='relu', padding='same')(conv3)
    pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)

    conv4 = Conv2D(256, (3, 3), activation='relu', padding='same')(pool3)
    conv4 = Conv2D(256, (3, 3), activation='relu', padding='same')(conv4)
    pool4 = MaxPooling2D(pool_size=(2, 2))(conv4)

    conv5 = Conv2D(512, (3, 3), activation='relu', padding='same')(pool4)
    conv5 = Conv2D(512, (3, 3), activation='relu', padding='same')(conv5)

    up6 = concatenate([Conv2DTranspose(256, (2, 2), strides=(2, 2), padding='same')(conv5), conv4], axis=3)
    conv6 = Conv2D(256, (3, 3), activation='relu', padding='same')(up6)
    conv6 = Conv2D(256, (3, 3), activation='relu', padding='same')(conv6)

    up7 = concatenate([Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same')(conv6), conv3], axis=3)
    conv7 = Conv2D(128, (3, 3), activation='relu', padding='same')(up7)
    conv7 = Conv2D(128, (3, 3), activation='relu', padding='same')(conv7)

    up8 = concatenate([Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(conv7), conv2], axis=3)
    conv8 = Conv2D(64, (3, 3), activation='relu', padding='same')(up8)
    conv8 = Conv2D(64, (3, 3), activation='relu', padding='same')(conv8)

    up9 = concatenate([Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same')(conv8), conv1], axis=3)
    conv9 = Conv2D(32, (3, 3), activation='relu', padding='same')(up9)
    conv9 = Conv2D(32, (3, 3), activation='relu', padding='same')(conv9)
    conv9 = Conv2D(4, (3,3), activation='relu', padding='same')(conv9)
    
    conv10 = Conv2D(4, (1,1), activation='softmax')(conv9)
    loss_function = 'categorical_crossentropy'
    model = Model(inputs=[inputs], outputs=[conv10])
    model.compile(optimizer=Adam(lr=1e-4), loss=loss_function, metrics=[dice_coef_])
    model.summary()
    return model

# %%
from data import load_train_data, load_test_data

# %% [markdown]
# # training

# %%
print('Loading and preprocessing train data...')
print('-'*30)
imgs_train, imgs_mask_train = load_train_data()
name = 'model_softmax.h5'

checkpoint = ModelCheckpoint(name, verbose=1, save_best_only=True, save_weights_only=True)
model = get_unet()

imgs_train = imgs_train.astype('float32')
mean = np.mean(imgs_train)  # mean for data centering
std = np.std(imgs_train)  # std for data normalization
imgs_train -= mean
imgs_train /= std
print("normalize")
np.savez_compressed('scaler',mean=mean,std=std)

results = model.fit(imgs_train, imgs_mask_train, batch_size=32, epochs=100, callbacks=[checkpoint]
                   ,shuffle=True,
              validation_split=0.2)
# Out:
# Loading and preprocessing train data...
# ------------------------------
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_7 (InputLayer)            (None, 256, 256, 1)  0
# __________________________________________________________________________________________________
# conv2d_121 (Conv2D)             (None, 256, 256, 32) 320         input_7[0][0]
# __________________________________________________________________________________________________
# conv2d_122 (Conv2D)             (None, 256, 256, 32) 9248        conv2d_121[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_25 (MaxPooling2D) (None, 128, 128, 32) 0           conv2d_122[0][0]
# __________________________________________________________________________________________________
# conv2d_123 (Conv2D)             (None, 128, 128, 64) 18496       max_pooling2d_25[0][0]
# __________________________________________________________________________________________________
# conv2d_124 (Conv2D)             (None, 128, 128, 64) 36928       conv2d_123[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_26 (MaxPooling2D) (None, 64, 64, 64)   0           conv2d_124[0][0]
# __________________________________________________________________________________________________
# conv2d_125 (Conv2D)             (None, 64, 64, 128)  73856       max_pooling2d_26[0][0]
# __________________________________________________________________________________________________
# conv2d_126 (Conv2D)             (None, 64, 64, 128)  147584      conv2d_125[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_27 (MaxPooling2D) (None, 32, 32, 128)  0           conv2d_126[0][0]
# __________________________________________________________________________________________________
# conv2d_127 (Conv2D)             (None, 32, 32, 256)  295168      max_pooling2d_27[0][0]
# __________________________________________________________________________________________________
# conv2d_128 (Conv2D)             (None, 32, 32, 256)  590080      conv2d_127[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_28 (MaxPooling2D) (None, 16, 16, 256)  0           conv2d_128[0][0]
# __________________________________________________________________________________________________
# conv2d_129 (Conv2D)             (None, 16, 16, 512)  1180160     max_pooling2d_28[0][0]
# __________________________________________________________________________________________________
# conv2d_130 (Conv2D)             (None, 16, 16, 512)  2359808     conv2d_129[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_25 (Conv2DTran (None, 32, 32, 256)  524544      conv2d_130[0][0]
# __________________________________________________________________________________________________
# concatenate_25 (Concatenate)    (None, 32, 32, 512)  0           conv2d_transpose_25[0][0]
#                                                                  conv2d_128[0][0]
# __________________________________________________________________________________________________
# conv2d_131 (Conv2D)             (None, 32, 32, 256)  1179904     concatenate_25[0][0]
# __________________________________________________________________________________________________
# conv2d_132 (Conv2D)             (None, 32, 32, 256)  590080      conv2d_131[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_26 (Conv2DTran (None, 64, 64, 128)  131200      conv2d_132[0][0]
# __________________________________________________________________________________________________
# concatenate_26 (Concatenate)    (None, 64, 64, 256)  0           conv2d_transpose_26[0][0]
#                                                                  conv2d_126[0][0]
# __________________________________________________________________________________________________
# conv2d_133 (Conv2D)             (None, 64, 64, 128)  295040      concatenate_26[0][0]
# __________________________________________________________________________________________________
# conv2d_134 (Conv2D)             (None, 64, 64, 128)  147584      conv2d_133[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_27 (Conv2DTran (None, 128, 128, 64) 32832       conv2d_134[0][0]
# __________________________________________________________________________________________________
# concatenate_27 (Concatenate)    (None, 128, 128, 128 0           conv2d_transpose_27[0][0]
#                                                                  conv2d_124[0][0]
# __________________________________________________________________________________________________
# conv2d_135 (Conv2D)             (None, 128, 128, 64) 73792       concatenate_27[0][0]
# __________________________________________________________________________________________________
# conv2d_136 (Conv2D)             (None, 128, 128, 64) 36928       conv2d_135[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_28 (Conv2DTran (None, 256, 256, 32) 8224        conv2d_136[0][0]
# __________________________________________________________________________________________________
# concatenate_28 (Concatenate)    (None, 256, 256, 64) 0           conv2d_transpose_28[0][0]
#                                                                  conv2d_122[0][0]
# __________________________________________________________________________________________________
# conv2d_137 (Conv2D)             (None, 256, 256, 32) 18464       concatenate_28[0][0]
# __________________________________________________________________________________________________
# conv2d_138 (Conv2D)             (None, 256, 256, 32) 9248        conv2d_137[0][0]
# __________________________________________________________________________________________________
# conv2d_139 (Conv2D)             (None, 256, 256, 4)  1156        conv2d_138[0][0]
# __________________________________________________________________________________________________
# conv2d_140 (Conv2D)             (None, 256, 256, 4)  20          conv2d_139[0][0]
# ==================================================================================================
# Total params: 7,760,664
# Trainable params: 7,760,664
# Non-trainable params: 0
# __________________________________________________________________________________________________
# normalize
# Train on 200 samples, validate on 50 samples
# Epoch 1/100
# 200/200 [==============================] - 6s 29ms/step - loss: 0.0641 - dice_coef_: 0.0220 - val_loss: 0.0602 - val_dice_coef_: 0.0207
#
# Epoch 00001: val_loss improved from inf to 0.06018, saving model to model_softmax.h5
# Epoch 2/100
# 200/200 [==============================] - 4s 19ms/step - loss: 0.0640 - dice_coef_: 0.0221 - val_loss: 0.0601 - val_dice_coef_: 0.0207
#
# Epoch 00002: val_loss improved from 0.06018 to 0.06006, saving model to model_softmax.h5
# Epoch 3/100
# 200/200 [==============================] - 4s 19ms/step - loss: 0.0638 - dice_coef_: 0.0221 - val_loss: 0.0595 - val_dice_coef_: 0.0210
#
# Epoch 00003: val_loss improved from 0.06006 to 0.05952, saving model to model_softmax.h5
# Epoch 4/100
# 200/200 [==============================] - 4s 19ms/step - loss: 0.0634 - dice_coef_: 0.0224 - val_loss: 0.0588 - val_dice_coef_: 0.0214
#
# Epoch 00004: val_loss improved from 0.05952 to 0.05883, saving model to model_softmax.h5
# Epoch 5/100
# 200/200 [==============================] - 4s 19ms/step - loss: 0.0629 - dice_coef_: 0.0228 - val_loss: 0.0579 - val_dice_coef_: 0.0221
#
# Epoch 00005: val_loss improved from 0.05883 to 0.05795, saving model to model_softmax.h5
# Epoch 6/100
# 200/200 [==============================] - 4s 19ms/step - loss: 0.0625 - dice_coef_: 0.0233 - val_loss: 0.0573 - val_dice_coef_: 0.0226
#
# Epoch 00006: val_loss improved from 0.05795 to 0.05734, saving model to model_softmax.h5
# Epoch 7/100
# 200/200 [==============================] - 4s 19ms/step - loss: 0.0624 - dice_coef_: 0.0236 - val_loss: 0.0570 - val_dice_coef_: 0.0229
#
# Epoch 00007: val_loss improved from 0.05734 to 0.05705, saving model to model_softmax.h5
# Epoch 8/100
# 200/200 [==============================] - 4s 18ms/step - loss: 0.0623 - dice_coef_: 0.0239 - val_loss: 0.0567 - val_dice_coef_: 0.0231
#
# Epoch 00008: val_loss improved from 0.05705 to 0.05671, saving model to model_softmax.h5
# Epoch 9/100
# 200/200 [==============================] - 4s 19ms/step - loss: 0.0620 - dice_coef_: 0.0237 - val_loss: 0.0568 - val_dice_coef_: 0.0228
#
# Epoch 00009: val_loss did not improve from 0.05671
# Epoch 10/100
# 200/200 [==============================] - 4s 19ms/step - loss: 0.0615 - dice_coef_: 0.0241 - val_loss: 0.0552 - val_dice_coef_: 0.0240
#
# Epoch 00010: val_loss improved from 0.05671 to 0.05524, saving model to model_softmax.h5
# Epoch 11/100
# 200/200 [==============================] - 4s 19ms/step - loss: 0.0600 - dice_coef_: 0.0251 - val_loss: 0.0510 - val_dice_coef_: 0.0269
#
# Epoch 00011: val_loss improved from 0.05524 to 0.05102, saving model to model_softmax.h5
# Epoch 12/100
# 200/200 [==============================] - 4s 19ms/step - loss: 0.0549 - dice_coef_: 0.0285 - val_loss: 0.0467 - val_dice_coef_: 0.0288
#
# Epoch 00012: val_loss improved from 0.05102 to 0.04672, saving model to model_softmax.h5
# Epoch 13/100
# 200/200 [==============================] - 4s 19ms/step - loss: 0.0503 - dice_coef_: 0.0309 - val_loss: 0.0423 - val_dice_coef_: 0.0320
#
# Epoch 00013: val_loss improved from 0.04672 to 0.04232, saving model to model_softmax.h5
# Epoch 14/100
# 200/200 [==============================] - 4s 19ms/step - loss: 0.0483 - dice_coef_: 0.0323 - val_loss: 0.0414 - val_dice_coef_: 0.0325
#
# Epoch 00014: val_loss improved from 0.04232 to 0.04143, saving model to model_softmax.h5
# Epoch 15/100
# 200/200 [==============================] - 4s 19ms/step - loss: 0.0459 - dice_coef_: 0.0338 - val_loss: 0.0393 - val_dice_coef_: 0.0342
#
# Epoch 00015: val_loss improved from 0.04143 to 0.03933, saving model to model_softmax.h5
# Epoch 16/100
# 200/200 [==============================] - 4s 19ms/step - loss: 0.0436 - dice_coef_: 0.0354 - val_loss: 0.0384 - val_dice_coef_: 0.0350
#
# Epoch 00016: val_loss improved from 0.03933 to 0.03843, saving model to model_softmax.h5
# Epoch 17/100
# 200/200 [==============================] - 4s 19ms/step - loss: 0.0425 - dice_coef_: 0.0363 - val_loss: 0.0378 - val_dice_coef_: 0.0358
#
# Epoch 00017: val_loss improved from 0.03843 to 0.03780, saving model to model_softmax.h5
# Epoch 18/100
# 200/200 [==============================] - 4s 19ms/step - loss: 0.0416 - dice_coef_: 0.0374 - val_loss: 0.0365 - val_dice_coef_: 0.0369
#
# Epoch 00018: val_loss improved from 0.03780 to 0.03655, saving model to model_softmax.h5
# Epoch 19/100
# 200/200 [==============================] - 4s 19ms/step - loss: 0.0404 - dice_coef_: 0.0387 - val_loss: 0.0342 - val_dice_coef_: 0.0398
#
# Epoch 00019: val_loss improved from 0.03655 to 0.03424, saving model to model_softmax.h5
# Epoch 20/100
# 200/200 [==============================] - 4s 19ms/step - loss: 0.0383 - dice_coef_: 0.0416 - val_loss: 0.0301 - val_dice_coef_: 0.0475
#
# Epoch 00020: val_loss improved from 0.03424 to 0.03010, saving model to model_softmax.h5
# Epoch 21/100
# 200/200 [==============================] - 4s 20ms/step - loss: 0.0369 - dice_coef_: 0.0466 - val_loss: 0.0299 - val_dice_coef_: 0.0471
#
# Epoch 00021: val_loss improved from 0.03010 to 0.02986, saving model to model_softmax.h5
# Epoch 22/100
# 200/200 [==============================] - 4s 19ms/step - loss: 0.0361 - dice_coef_: 0.0466 - val_loss: 0.0300 - val_dice_coef_: 0.0466
#
# Epoch 00022: val_loss did not improve from 0.02986
# Epoch 23/100
# 200/200 [==============================] - 4s 19ms/step - loss: 0.0353 - dice_coef_: 0.0477 - val_loss: 0.0286 - val_dice_coef_: 0.0484
#
# Epoch 00023: val_loss improved from 0.02986 to 0.02860, saving model to model_softmax.h5
# Epoch 24/100
# 200/200 [==============================] - 4s 19ms/step - loss: 0.0347 - dice_coef_: 0.0480 - val_loss: 0.0274 - val_dice_coef_: 0.0499
#
# Epoch 00024: val_loss improved from 0.02860 to 0.02742, saving model to model_softmax.h5
# Epoch 25/100
# 200/200 [==============================] - 4s 19ms/step - loss: 0.0339 - dice_coef_: 0.0491 - val_loss: 0.0279 - val_dice_coef_: 0.0492
#
# Epoch 00025: val_loss did not improve from 0.02742
# Epoch 26/100
# 200/200 [==============================] - 4s 20ms/step - loss: 0.0340 - dice_coef_: 0.0489 - val_loss: 0.0272 - val_dice_coef_: 0.0506
#
# Epoch 00026: val_loss improved from 0.02742 to 0.02722, saving model to model_softmax.h5
# Epoch 27/100
# 200/200 [==============================] - 4s 19ms/step - loss: 0.0332 - dice_coef_: 0.0502 - val_loss: 0.0267 - val_dice_coef_: 0.0508
#
# Epoch 00027: val_loss improved from 0.02722 to 0.02670, saving model to model_softmax.h5
# Epoch 28/100
# 200/200 [==============================] - 4s 20ms/step - loss: 0.0327 - dice_coef_: 0.0500 - val_loss: 0.0262 - val_dice_coef_: 0.0516
#
# Epoch 00028: val_loss improved from 0.02670 to 0.02621, saving model to model_softmax.h5
# Epoch 29/100
# 200/200 [==============================] - 4s 20ms/step - loss: 0.0322 - dice_coef_: 0.0506 - val_loss: 0.0261 - val_dice_coef_: 0.0515
#
# Epoch 00029: val_loss improved from 0.02621 to 0.02609, saving model to model_softmax.h5
# Epoch 30/100
# 200/200 [==============================] - 4s 19ms/step - loss: 0.0319 - dice_coef_: 0.0513 - val_loss: 0.0269 - val_dice_coef_: 0.0504
#
# Epoch 00030: val_loss did not improve from 0.02609
# Epoch 31/100
# 200/200 [==============================] - 4s 19ms/step - loss: 0.0319 - dice_coef_: 0.0511 - val_loss: 0.0271 - val_dice_coef_: 0.0499
#
# Epoch 00031: val_loss did not improve from 0.02609
# Epoch 32/100
# 200/200 [==============================] - 4s 19ms/step - loss: 0.0317 - dice_coef_: 0.0513 - val_loss: 0.0262 - val_dice_coef_: 0.0507
#
# Epoch 00032: val_loss did not improve from 0.02609
# Epoch 33/100
# 200/200 [==============================] - 4s 19ms/step - loss: 0.0310 - dice_coef_: 0.0519 - val_loss: 0.0258 - val_dice_coef_: 0.0512
#
# Epoch 00033: val_loss improved from 0.02609 to 0.02584, saving model to model_softmax.h5
# Epoch 34/100
# 200/200 [==============================] - 4s 19ms/step - loss: 0.0306 - dice_coef_: 0.0521 - val_loss: 0.0245 - val_dice_coef_: 0.0528
#
# Epoch 00034: val_loss improved from 0.02584 to 0.02453, saving model to model_softmax.h5
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-89-8495db81e742> in <module>
#      17 results = model.fit(imgs_train, imgs_mask_train, batch_size=32, epochs=100, callbacks=[checkpoint]
#      18                    ,shuffle=True,
# ---> 19               validation_split=0.2)
#
# /opt/campux/virtualenv/deeplearning/lib/python3.6/site-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#    1037                                         initial_epoch=initial_epoch,
#    1038                                         steps_per_epoch=steps_per_epoch,
# -> 1039                                         validation_steps=validation_steps)
#    1040
#    1041     def evaluate(self, x=None, y=None,
#
# /opt/campux/virtualenv/deeplearning/lib/python3.6/site-packages/keras/engine/training_arrays.py in fit_loop(model, f, ins, out_labels, batch_size, epochs, verbose, callbacks, val_f, val_ins, shuffle, callback_metrics, initial_epoch, steps_per_epoch, validation_steps)
#     215                         for l, o in zip(out_labels, val_outs):
#     216                             epoch_logs['val_' + l] = o
# --> 217         callbacks.on_epoch_end(epoch, epoch_logs)
#     218         if callback_model.stop_training:
#     219             break
#
# /opt/campux/virtualenv/deeplearning/lib/python3.6/site-packages/keras/callbacks.py in on_epoch_end(self, epoch, logs)
#      77         logs = logs or {}
#      78         for callback in self.callbacks:
# ---> 79             callback.on_epoch_end(epoch, logs)
#      80
#      81     def on_batch_begin(self, batch, logs=None):
#
# /opt/campux/virtualenv/deeplearning/lib/python3.6/site-packages/keras/callbacks.py in on_epoch_end(self, epoch, logs)
#     442                         self.best = current
#     443                         if self.save_weights_only:
# --> 444                             self.model.save_weights(filepath, overwrite=True)
#     445                         else:
#     446                             self.model.save(filepath, overwrite=True)
#
# /opt/campux/virtualenv/deeplearning/lib/python3.6/site-packages/keras/engine/network.py in save_weights(self, filepath, overwrite)
#    1120         with h5py.File(filepath, 'w') as f:
#    1121             saving.save_weights_to_hdf5_group(f, self.layers)
# -> 1122             f.flush()
#    1123
#    1124     def load_weights(self, filepath, by_name=False,
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# /opt/campux/virtualenv/deeplearning/lib/python3.6/site-packages/h5py/_hl/files.py in __exit__(self, *args)
#     358     def __exit__(self, *args):
#     359         if self.id:
# --> 360             self.close()
#     361
#     362     @with_phil
#
# /opt/campux/virtualenv/deeplearning/lib/python3.6/site-packages/h5py/_hl/files.py in close(self)
#     340                 for id_ in file_list:
#     341                     while id_.valid:
# --> 342                         h5i.dec_ref(id_)
#     343
#     344                 self.id.close()
#
# KeyboardInterrupt:

# %% [markdown]
# ## name = 'model_softmax.h5'

# %%
plt.subplot(211)
plt.plot(results.history['loss'], label='train')
plt.plot(results.history['val_loss'], label='val')
plt.title('loss')
plt.legend()

plt.subplot(212)
plt.plot(results.history['dice_coef_'], label='train')
plt.plot(results.history['val_dice_coef_'], label='val')
plt.title('acc')
plt.legend()

# %% [markdown]
# # evaluation

# %%
name
# Out:
# 'model_softmax.h5'

# %%
imgs_train, imgs_mask_train = load_train_data()

# %%
model = get_unet()
model.load_weights(name)
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_6 (InputLayer)            (None, 256, 256, 1)  0
# __________________________________________________________________________________________________
# conv2d_101 (Conv2D)             (None, 256, 256, 32) 320         input_6[0][0]
# __________________________________________________________________________________________________
# conv2d_102 (Conv2D)             (None, 256, 256, 32) 9248        conv2d_101[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_21 (MaxPooling2D) (None, 128, 128, 32) 0           conv2d_102[0][0]
# __________________________________________________________________________________________________
# conv2d_103 (Conv2D)             (None, 128, 128, 64) 18496       max_pooling2d_21[0][0]
# __________________________________________________________________________________________________
# conv2d_104 (Conv2D)             (None, 128, 128, 64) 36928       conv2d_103[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_22 (MaxPooling2D) (None, 64, 64, 64)   0           conv2d_104[0][0]
# __________________________________________________________________________________________________
# conv2d_105 (Conv2D)             (None, 64, 64, 128)  73856       max_pooling2d_22[0][0]
# __________________________________________________________________________________________________
# conv2d_106 (Conv2D)             (None, 64, 64, 128)  147584      conv2d_105[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_23 (MaxPooling2D) (None, 32, 32, 128)  0           conv2d_106[0][0]
# __________________________________________________________________________________________________
# conv2d_107 (Conv2D)             (None, 32, 32, 256)  295168      max_pooling2d_23[0][0]
# __________________________________________________________________________________________________
# conv2d_108 (Conv2D)             (None, 32, 32, 256)  590080      conv2d_107[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_24 (MaxPooling2D) (None, 16, 16, 256)  0           conv2d_108[0][0]
# __________________________________________________________________________________________________
# conv2d_109 (Conv2D)             (None, 16, 16, 512)  1180160     max_pooling2d_24[0][0]
# __________________________________________________________________________________________________
# conv2d_110 (Conv2D)             (None, 16, 16, 512)  2359808     conv2d_109[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_21 (Conv2DTran (None, 32, 32, 256)  524544      conv2d_110[0][0]
# __________________________________________________________________________________________________
# concatenate_21 (Concatenate)    (None, 32, 32, 512)  0           conv2d_transpose_21[0][0]
#                                                                  conv2d_108[0][0]
# __________________________________________________________________________________________________
# conv2d_111 (Conv2D)             (None, 32, 32, 256)  1179904     concatenate_21[0][0]
# __________________________________________________________________________________________________
# conv2d_112 (Conv2D)             (None, 32, 32, 256)  590080      conv2d_111[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_22 (Conv2DTran (None, 64, 64, 128)  131200      conv2d_112[0][0]
# __________________________________________________________________________________________________
# concatenate_22 (Concatenate)    (None, 64, 64, 256)  0           conv2d_transpose_22[0][0]
#                                                                  conv2d_106[0][0]
# __________________________________________________________________________________________________
# conv2d_113 (Conv2D)             (None, 64, 64, 128)  295040      concatenate_22[0][0]
# __________________________________________________________________________________________________
# conv2d_114 (Conv2D)             (None, 64, 64, 128)  147584      conv2d_113[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_23 (Conv2DTran (None, 128, 128, 64) 32832       conv2d_114[0][0]
# __________________________________________________________________________________________________
# concatenate_23 (Concatenate)    (None, 128, 128, 128 0           conv2d_transpose_23[0][0]
#                                                                  conv2d_104[0][0]
# __________________________________________________________________________________________________
# conv2d_115 (Conv2D)             (None, 128, 128, 64) 73792       concatenate_23[0][0]
# __________________________________________________________________________________________________
# conv2d_116 (Conv2D)             (None, 128, 128, 64) 36928       conv2d_115[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_24 (Conv2DTran (None, 256, 256, 32) 8224        conv2d_116[0][0]
# __________________________________________________________________________________________________
# concatenate_24 (Concatenate)    (None, 256, 256, 64) 0           conv2d_transpose_24[0][0]
#                                                                  conv2d_102[0][0]
# __________________________________________________________________________________________________
# conv2d_117 (Conv2D)             (None, 256, 256, 32) 18464       concatenate_24[0][0]
# __________________________________________________________________________________________________
# conv2d_118 (Conv2D)             (None, 256, 256, 32) 9248        conv2d_117[0][0]
# __________________________________________________________________________________________________
# conv2d_119 (Conv2D)             (None, 256, 256, 4)  1156        conv2d_118[0][0]
# __________________________________________________________________________________________________
# conv2d_120 (Conv2D)             (None, 256, 256, 4)  20          conv2d_119[0][0]
# ==================================================================================================
# Total params: 7,760,664
# Trainable params: 7,760,664
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
id = 80


test = imgs_train[id,:,:,:]
test -= mean
test /= std
y_pred = model.predict(test.reshape(1,256,256,1))

# %% [markdown]
# # results

# %%
plt.figure(figsize=(20, 15))

for i in range(4):
    plt.subplot(1,4,i+1)
    plt.imshow(imgs_train[id,:,:,0])
    slice_ = y_pred[0,:,:,i]
    print(slice_.min(), slice_.max())
    m = slice_.mean()
    plt.imshow(slice_>0.5, alpha=0.7)
plt.show()
# Out:
# 0.0001498433 1.0
# 2.2137097e-12 0.96801376
# 7.939751e-12 0.646692
# 7.213462e-36 0.903739

# %% [markdown]
# # real

# %%
plt.figure(figsize=(20, 15))
for i in range(4):
    plt.subplot(1,4,i+1)
    slice_ = imgs_mask_train[id,:,:,i]
    plt.imshow(imgs_train[id,:,:,0])
    plt.imshow(slice_, alpha=0.7)    
plt.show()

# %% [markdown]
# # image test

# %%
imgs_test = load_test_data()
imgs_test -= mean
imgs_test /= std

# %%
mask_predicts = model.predict(imgs_test)

# %%
idx = 10
plt.figure(figsize=(20, 15))
for i in range(4):
    plt.subplot(1,4,i+1)
    plt.imshow(imgs_test[idx,:,:,0])
    slice_ = mask_predicts[idx,:,:,i]
    plt.imshow(slice_,vmin = slice_.min(), vmax= slice_.max(),cmap='jet', alpha=0.5)
plt.show()

# %%
idx = 20
plt.figure(figsize=(20, 15))
for i in range(4):
    plt.subplot(1,4,i+1)
    plt.imshow(imgs_test[idx,:,:,0])
    slice_ = mask_predicts[idx,:,:,i]
    plt.imshow(slice_,vmin = slice_.min(), vmax= slice_.max(),cmap='jet', alpha=0.5)
plt.show()
